# %% [markdown]
# # Pre-Processing to Match Annotated Data
# - Ultimate goal: Match everything as closely as possible (even if it doesn't always make sense to)

# %% [markdown]
# ## Imports

# %%
import os
import pandas as pd
import time
import numpy as np
from collections import deque

# %% [markdown]
# # Gold Data (Annotated by Partner)

# %% [markdown]
# ## Renaming `gold_data` columns

# %%
import pandas as pd
# gold_data = pd.read_csv("data/gold_labels_with_files.csv") # with partner annotations
gold_data = pd.read_csv('data/allard_labels_with_text.csv') # allard annotations

# making new names for the columns in gold_data

new_names = {
    'Timestamp': 'timestamp',
    'Email Address': 'email_address',
    'What is the file number of the case?': 'file_number_gold',
    'What was the date of the hearing? [mm/dd/yyyy]': 'hearing_date',
    'What was the date of the decision? [mm/dd/yyyy]': 'decision_date',
    'Who was the member adjudicating the decision?': 'adjudicating_member',
    'What was the location of the landlord tenant board?': 'ltb_location',
    'Did the decision state the landlord was represented?': 'landlord_represented',
    'Did the decision state the landlord attended the hearing?': 'landlord_attended_hearing',
    'Did the decision state the tenant was represented?': 'tenant_represented',
    'Did the decision state the tenant attended the hearing?': 'tenant_attended_hearing',
    'Did the decision state the landlord was a not-for-profit landlord (e.g. Toronto Community Housing)?': 'landlord_nonprofit',
    'Did the decision state the tenant was collecting a subsidy?': 'tenant_collecting_subsidy',
    'What was the outcome of the case?': 'case_outcome',
    'What was the length of the tenancy, or in other words, how long had the tenants lived at the residence in question? ': 'tenancy_length',
    'What was the monthly rent?': 'monthly_rent',
    'What was the amount of the rental deposit? ': 'rental_deposit',
    'If any rent increases occurred, what was the rent after the increase(s)?': 'rent_after_increase',
    'If any rent increases occurred, when did the rent increase(s) come into effect? ': 'rent_increase_effect_date',
    'What was the total amount of arrears?': 'total_arrears',
    'Over how many months did the arrears accumulate? ': 'arrears_duration',
    'If the tenant made a payment on the arrears after the eviction notice was served and/or prior to the hearing, what was the amount of the payment? ': 'arrears_payment_amount',
    'Did the decision mention a history of arrears by the tenant separate from the arrears in the current claim (more than one period of arrears, recurrently coming in and out of arrears, arrears with previous landlord, etc.)?': 'tenant_arrears_history_mentioned',
    'If the tenant had a history of arrears, did the decision mention a history of the tenant making payments on those arrears (separate from any payments made in response to the present eviction notice/hearing)?': 'tenant_arrears_payment_history_mentioned',
    'How frequently were rent payments made late?': 'rent_payments_late_frequency',
    'Did the member find the tenant had or seemed to have the ability to pay rent, but chose not do so?': 'tenant_ability_to_pay_rent',
    'What were the specific mental, medical, or physical conditions of the tenant, if any? ': 'tenant_conditions',
    'Did the decision state that the tenant had children living with them?': 'tenant_children_present',
    'How many total children did the tenant have living with them? ': 'total_children',
    'How many total children aged 17 or younger did the tenant have living with them?': 'children_17_or_younger',
    'How many total children aged 13 or younger did the tenant have living with them? ': 'children_13_or_younger',
    'How many total children aged 4 or younger did the tenant have living with them?': 'children_4_or_younger',
    'Did the decision state any of the children had mental, medical or physical conditions?': 'children_conditions_mentioned',
    'If yes to the previous question, did the decision state these conditions would make moving particularly burdensome?': 'conditions_making_moving_burdensome',
    'Was the tenant employed at the time of the hearing?': 'tenant_employed',
    'If the tenant was not employed, did the decision state the tenant was receiving any form of government assistance (e.g. OW, childcare benefits, ODSP, OSAP)?': 'tenant_government_assistance',
    'If the tenant was employed, did the decision state any doubts about the stability of employment e.g. lack of guaranteed hours, contract work, etc.?': 'employment_stability_doubts',
    'Did the member find the tenant had sufficient income to pay rent?': 'sufficient_income_to_pay_rent',
    'What was the total income of the tenant’s household? ': 'total_household_income',
    'Did the decision mention the tenant lost their job leading up to or during the period of the hearing?': 'tenant_job_loss_mentioned',
    'Did the decision mention any other extenuating circumstances experienced by the tenant leading up to or during the period of the claim (e.g. hospitalization, death in the family, etc.)?': 'tenant_extenuating_circumstances',
    'Did the tenant propose a payment plan?': 'tenant_proposed_payment_plan',
    'If the tenant did propose a payment plan, did the member accept the proposed payment plan?': 'accepted_proposed_payment_plan',
    'If a payment plan was ordered, what was the length of the payment plan? ': 'payment_plan_length',
    'Did the decision mention the tenant’s difficulty finding alternative housing for any reason e.g.physical limitations, reliance on social assistance, etc.?': 'tenant_difficulty_finding_housing',
    'If yes to the previous question, which of the following were applicable to the tenant?': 'applicable_difficulty_reasons',
    'Did the decision state the tenant was given prior notice for the eviction?': 'tenant_prior_notice_given',
    'If the tenant was given prior notice for the eviction, how much notice was given?': 'prior_notice_duration',
    'Did the decisions state postponement would result in the tenant accruing additional arrears?': 'postponement_additional_arrears',
    'Which other specific applications of the landlord or the tenant were mentioned?': 'mentioned_applications',
    'Did the decision mention the validity of an N4 eviction notice?': 'validity_of_N4_notice_mentioned',
    'Were there detail(s) in the decision not captured by this questionnaire that should be included?': 'additional_details_in_decision',
    'Exec Review': 'executive_review',
    'Review Status': 'review_status'
}

gold_data = gold_data.rename(columns = new_names)
# sorting by file_number -- so that ordering of the new data annotations can match this and be more easily compared
gold_data = gold_data.sort_values(by = ['case number'], ascending = True).reset_index(drop = True)
gold_data.columns
# Out:
# Index(['case number', 'adjudicating_member', 'ltb_location',
#        'landlord_represented', 'landlord_attended_hearing',
#        'tenant_represented', 'tenant_attended_hearing', 'landlord_nonprofit',
#        'tenant_collecting_subsidy', 'case_outcome',
#        'What was the length of the tenancy', 'monthly_rent',
#        'rental deposit amount', 'was there an rent increases', 'total_arrears',
#        'Over how many months did the arrears accumulate?',
#        'Does the tenant made a payment on the arrears after the eviction notice',
#        'tenant_arrears_history_mentioned', 'tenant_ability_to_pay_rent',
#        'What were the specific mental, medical, or physical conditions of the tenant, if any?',
#        'tenant_children_present', 'tenant_employed',
#        'tenant_government_assistance', 'employment_stability_doubts',
#        'sufficient_income_to_pay_rent', 'tenant_job_loss_mentioned',
#        'tenant_extenuating_circumstances', 'tenant_difficulty_finding_housing',
#        'tenant_prior_notice_given', 'postponement_additional_arrears',
#        'validity_of_N4_notice_mentioned', 'Payment Plan', 'L1 present?',
#        'L2 present?', 'L3 present?', 'L4 present?', 'L8 present?',
#        'L9 present?', 'N5 present?', 'N6 present?', 'N7 present?',
#        'N8 present?', 'T1 present?', 'T2 present?', 'T3 present?',
#        'T5 present?', 'T6 present?', 'raw_file_text', 'raw_file_name'],
#       dtype='object')

# %%
from dateutil.parser import parse

def convert_to_datetime(date_str):
    # Parse date using dateutil.parser.parse
    dt = parse(date_str)
    
    # Format date with strftime in the format 'MM/DD/YYYY'
    return dt.strftime('%m/%d/%Y')

gold_data['hearing_date'] = gold_data['hearing_date'].apply(lambda x: convert_to_datetime(x))
gold_data['decision_date'] = gold_data['decision_date'].apply(lambda x: convert_to_datetime(x))
gold_data['hearing_date']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hearing_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb Cell 7 in <cell line: 10>()
#       <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#W6sZmlsZQ%3D%3D?line=6'>7</a>     # Format date with strftime in the format 'MM/DD/YYYY'
#       <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#W6sZmlsZQ%3D%3D?line=7'>8</a>     return dt.strftime('%m/%d/%Y')
# ---> <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#W6sZmlsZQ%3D%3D?line=9'>10</a> gold_data['hearing_date'] = gold_data['hearing_date'].apply(lambda x: convert_to_datetime(x))
#      <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#W6sZmlsZQ%3D%3D?line=10'>11</a> gold_data['decision_date'] = gold_data['decision_date'].apply(lambda x: convert_to_datetime(x))
#      <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#W6sZmlsZQ%3D%3D?line=11'>12</a> gold_data['hearing_date']
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'hearing_date'

# %% [markdown]
# # Silver Data
# - Only 678 of 702 case files match

# %%
# # formatted_cases_path = "/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/scraping/45k_formatted_cases/"
# folder_path = "./raw_case_files/"

# # def create_master_dictionary(directory):
# master_dict = {}
# master_dict['raw_file_name'] = []
# master_dict['raw_file_text'] = []

# # Iterate over .txt files in the folder
# for file_name in os.listdir(folder_path):
#     file_path = os.path.join(folder_path, file_name)
    
#     # Check if the file is a .txt file
#     if os.path.isfile(file_path) and file_name.endswith('.txt'):
        
#         # Read the contents of the .txt file
#         with open(file_path, 'r') as file:
#             contents = file.read()
            
#             # Append the contents to the list in the master_dict
#             master_dict['raw_file_name'].append(file_name)
#             master_dict['raw_file_text'].append(contents)
# # master_dict

# %%
# for key, value in master_dict.items():
#     print(key, len(value))

# silver_data = pd.DataFrame.from_dict(master_dict)
# print(silver_data.shape)
# silver_data.head()

# %%
# matched_files = []
# print(len(silver_data))
# for silver_fn in silver_data.raw_file_name.unique().tolist():
#     if silver_fn[:-4] in gold_data.file_number.unique().tolist():
#         # print(silver_fn)
#         matched_files.append(silver_fn)

# silver_data = silver_data[silver_data.raw_file_name.isin(matched_files)]
# print(len(silver_data))
# silver_data = silver_data.sort_values(by = ['raw_file_name'], ascending = True).reset_index(drop = True)
# silver_data

# %% [markdown]
# ## Creating `silver_data` df from `gold_data` raw text

# %%
silver_data = gold_data.copy()
silver_data = silver_data.drop(columns = [col for col in silver_data.columns if col not in ['raw_file_name', 'raw_file_text']])
silver_data
# Out:
#                                          raw_file_text        raw_file_name
# 0    Metadata:\nDate:\t2017-01-18\nFile number:\t\n...     CEL-62600-16.txt
# 1    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-62852-16.txt
# 2    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-63024-16.txt
# 3    Metadata:\nDate:\t2017-01-20\nFile number:\t\n...     CEL-63056-16.txt
# 4    Metadata:\nDate:\t2017-02-03\nFile number:\t\n...     CEL-63193-16.txt
# ..                                                 ...                  ...
# 667  Metadata:\nDate:\t2018-12-13\nFile number:\t\n...  TSL-98918-18-RV.txt
# 668  Metadata:\nDate:\t2018-11-23\nFile number:\t\n...     TSL-99691-18.txt
# 669  Metadata:\nDate:\t2018-11-29\nFile number:\t\n...     TSL-99824-18.txt
# 670  Metadata:\nDate:\t2018-12-12\nFile number:\t\n...     TSL-99900-18.txt
# 671  Metadata:\nDate:\t2018-11-20\nFile number:\t\n...     TSL-99965-18.txt
#
# [672 rows x 2 columns]

# %%
gold_data = gold_data.rename(columns = {'case number': 'file_number',
                                        'board_location': 'ltb_location'})
gold_data.columns.tolist()
# Out:
# ['file_number',
#  'adjudicating_member',
#  'ltb_location',
#  'landlord_represented',
#  'landlord_attended_hearing',
#  'tenant_represented',
#  'tenant_attended_hearing',
#  'landlord_nonprofit',
#  'tenant_collecting_subsidy',
#  'case_outcome',
#  'What was the length of the tenancy',
#  'monthly_rent',
#  'rental deposit amount',
#  'was there an rent increases',
#  'total_arrears',
#  'Over how many months did the arrears accumulate?',
#  'Does the tenant made a payment on the arrears after the eviction notice',
#  'tenant_arrears_history_mentioned',
#  'tenant_ability_to_pay_rent',
#  'What were the specific mental, medical, or physical conditions of the tenant, if any?',
#  'tenant_children_present',
#  'tenant_employed',
#  'tenant_government_assistance',
#  'employment_stability_doubts',
#  'sufficient_income_to_pay_rent',
#  'tenant_job_loss_mentioned',
#  'tenant_extenuating_circumstances',
#  'tenant_difficulty_finding_housing',
#  'tenant_prior_notice_given',
#  'postponement_additional_arrears',
#  'validity_of_N4_notice_mentioned',
#  'Payment Plan',
#  'L1 present?',
#  'L2 present?',
#  'L3 present?',
#  'L4 present?',
#  'L8 present?',
#  'L9 present?',
#  'N5 present?',
#  'N6 present?',
#  'N7 present?',
#  'N8 present?',
#  'T1 present?',
#  'T2 present?',
#  'T3 present?',
#  'T5 present?',
#  'T6 present?',
#  'raw_file_text',
#  'raw_file_name']

# %% [markdown]
# # ALL CASE FILES

# %%
# all_cases_master = pd.read_csv("large_files/44k_cases_pproc_filenums.csv")
# all_cases_master

# %%
# all_cases_master['file_numbers_from_file_name'] = all_cases_master.raw_file_name.apply(lambda x: x.split(".txt")[0])
# all_cases_master

# %% [markdown]
# # `get_nulls()`
# - for checking df after each addition to it

# %%
def get_nulls(df, col, return_index = False):
    # returns a list of the indices of null values in a column of a dataframe
    null_rows = silver_data[silver_data[col].isnull()] # df of all rows with null ltb_location
    nulls_inds = null_rows.index.tolist()

    if return_index:
        return nulls_inds
    else:
        return null_rows
    
get_nulls(silver_data, 'raw_file_text', return_index = False)
# Out:
# Empty DataFrame
# Columns: [raw_file_text, raw_file_name]
# Index: []

# %% [markdown]
# # General Cleaning
# - Removing unnecessary lines (blank)
# - Removing unnecessary characters (extra whitespaces and underscores)
# - Separating metadata and content

# %%
import re

def general_cleaning(raw_file_str: str):
    # gets rid of tabs, non-breaking spaces, leading/trailing whitespace, removes empty lines, and "\xa0"
    generally_cleaned_list = [line.replace("\t", " ").replace("\xa0", "").strip() for line in raw_file_str.split('\n') if line.strip() != '']
    return generally_cleaned_list

def remove_whitespace_and_underscores(string):
    # Remove consecutive whitespace
    string = re.sub(r'\s+', ' ', string)

    # Remove more than three consecutive underscores
    string = re.sub(r'_+', '', string)

    return string.strip()

def separate_file_sections(text_list):
    metadata_list = []
    content_list = []

    is_metadata = True
    is_content = False

    for line in text_list:
        if line.strip() == 'Metadata:':
            is_metadata = True
            is_content = False
        elif line.strip() == 'Content:':
            is_metadata = False
            is_content = True
        elif is_metadata:
            metadata_list.append(remove_whitespace_and_underscores(line))
        elif is_content:
            content_list.append(remove_whitespace_and_underscores(line))

    return metadata_list, content_list

def merge_numerical_entries(strings_list):
    """
    Turns something like
        [..., '3.',
        'The tenant took occupancy of the rental unit in or about the beginning of December 2016.', ...]
    into
        [..., '3. The tenant took occupancy of the rental unit in or about the beginning of December 2016.', ...]
    
    """
    for i in range(len(strings_list) - 2, -1, -1):
        if re.fullmatch(r'\d+\.', strings_list[i]):
            strings_list[i] += ' ' + strings_list[i + 1]
            del strings_list[i + 1]
    return strings_list

def move_trailing_numbers(strings_list):
    """
    Turns something like
        [..., 'Credibility of the Parties 4.',
        'The Landlord said about two to three months ago he ...', ...]
    into
        [..., 'Credibility of the Parties',
        '4. The Landlord said about two to three months ago he...', ...]
    
    """
    for i in range(len(strings_list) - 1, -1, -1):
        match = re.search(r'\s+(\d{2}\.)$', strings_list[i])
        if match:
            number = match.group(1)
            strings_list[i] = re.sub(r'\s+\d{1,2}\.$', '', strings_list[i])
            strings_list[i + 1] = number + ' ' + strings_list[i + 1]
    return strings_list

import re

def remove_end_tag_and_restructure(metadata_list: list):

    cleaned_str = " ".join(metadata_list)

    # this doesn't add any meaning to the case details we need to extract, and instead just adds noise to the extraction process + adds extra unnecessary tokens
    if cleaned_str.find("If you have any questions about this order") > (len(cleaned_str) - 500):
        cleaned_str = cleaned_str[: cleaned_str.find("If you have any questions about this order")].strip() # ending tag removed
    
    # otherwise just do everything else
    cleaned_str = cleaned_str.replace(". ", ".\n")
    # cleaned_str = cleaned_str.replace(". ", ".\n") # deprecated by regex approach
    # trimmed_list = [line.strip() for line in re.split(r'(?<!\d)\. ', cleaned_str) if line.strip() != ''] # deprecated by regex approach
    cleaned_str = re.sub(r'(?<!\d)\. ', "\n", cleaned_str)
    trimmed_list = [line.strip() for line in cleaned_str.split('\n') if line.strip() != '']
    trimmed_list = merge_numerical_entries(trimmed_list)
    trimmed_list = move_trailing_numbers(trimmed_list)
    return trimmed_list

file_name = "CEL-74519-18.txt"
# row of this particular case
case_file_ind = silver_data.loc[silver_data['raw_file_name'] == file_name].index.tolist()[0]
test_text = silver_data.loc[206, "raw_file_text"]#.item()

metadata, content = separate_file_sections(general_cleaning(test_text))
remove_end_tag_and_restructure(content)
# Out:
# ['Order under Section 69 Residential Tenancies Act, 2006 File Number: TEL-05033-19 M.',
#  'M.',
#  "(the 'Landlord') applied for an order to terminate the tenancy and evict T.",
#  "O'G.",
#  "(the 'Tenant') because the Tenant did not pay the rent that the Tenant owes.",
#  'This application was heard in Peterborough on October 24, 2019.',
#  'The Landlord and the Tenant attended the hearing.',
#  'The Landlord was represented by G.',
#  'G..',
#  'The Tenant spoke to Tenant Duty Counsel prior the hearing.',
#  'Determinations: 1.',
#  'By way of background, this tenancy began in January 2015; the monthly rent is $1,300.00 and is due on the first of each month.',
#  '2. The Tenant has not paid the total rent the Tenant was required to pay for the period from January 1, 2015 to October 31, 2019.',
#  'Because of the arrears, the Landlord served a Notice of Termination effective September 22, 2019.',
#  '3. Since the application was filed, the Tenant made no payments towards the arrears.',
#  '4. The arrears and costs owing to October 31, 2019 total $14,735.00.',
#  '5. The Landlord collected a rent deposit of $1,300.00 from the Tenant and this deposit is still being held by the Landlord.',
#  '6. Interest on the rent deposit is owing to the Tenant for the period from December 30, 2014 to September 22, 2019.',
#  '7. Since the date of the hearing the rent has come due for the months of November 2019 through to February 2020.',
#  '8. The Landlord seeks a standard, voidable, eleven-day order.',
#  'TENANT’S EVIDENCE 9.',
#  'The Tenant does not dispute the amount outstanding as claimed by the Landlord.',
#  '10. The Tenant testified that the reason he fell into arrears is because the second tenant left in 2017.',
#  'He had been using the money he inherited from his father’s estate to pay his rent until it was depleted.',
#  'He has attempted to rent out a room to help with the rent and other financial expenses but has not been successful.',
#  '11. The Tenant seeks a chance to preserve his tenancy as he has invested a lot into this home and has lived in the neighbourhood for forty-six years.',
#  'He requests relief in the form of a repayment plan; he proposes to pay an additional $500.00 on top of his monthly rent for the next thirty months.',
#  '12. The Tenant testified that he receives $1,000.00 from his casual part-time job and $330.00 on the 20th of each month from a friend who he has loaned $15,000.00.',
#  'His monthly income totals $1,330.00.',
#  'The Tenant testified that his monthly expenses are $1,300.00 which is equal to the monthly rent.',
#  'Upon cross-examination, the Tenant admitted that he is in arrears of both the hydro and gas bills.',
#  '13. The Tenant lives in the rental unit on his own and has never been to the Board before.',
#  '14. The Landlord opposes repayment plan as its duration is too long for the Landlord and the arrears outstanding are too high.',
#  'The Tenant’s evidence appears to indicate that the rental unit is not affordable for him.',
#  'ANALYSIS',
#  "15. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1)(a) of the Act.",
#  '16. The problem with the Tenant’s proposed repayment plan is that after his expenses are subtracted from his income, he is left with $30.00.',
#  'Thus, it is unclear how the Tenant will be able to come up with another $500.00 to pay towards the outstanding arrears.',
#  '17. Repayment plans are granted in order to allow a tenant to catch up on the arrears while continuing to pay their monthly rent.',
#  'Here, based on the Tenant’s own statements, a repayment plan would seem to be unrealistic and put the Tenants in further financial distress.',
#  '18. Therefore, I cannot grant the Tenant’s request for a repayment plan.',
#  '19. The Tenant stated he required more time than the standard eleven days.',
#  'However, he did not provide the Board with any submissions on how much time he required, and no other circumstances were disclosed with respect to why the Tenant required more than eleven days.',
#  'Therefore, I find that it would be unfair to postpone the eviction pursuant to subsection 83(1)(b) of the Act.',
#  '20. An order shall issue accordingly.',
#  '21. This order contains all of the reasons for my decision within it.',
#  'No further reasons shall be issued.',
#  'It is ordered that: 1.',
#  'Unless the Tenant voids the order as set out below, the tenancy between the Landlord and the Tenant is terminated.',
#  'The Tenant must move out of the rental unit on or before February 21, 2020.',
#  '2. The Tenant shall pay to the Landlord $17,519.74*, which represents the amount of rent owing and compensation up to February 10, 2020, less the rent deposit and interest the Landlord owes on the rent deposit.',
#  '3. The Tenant shall also pay to the Landlord $42.74 per day for compensation for the use of the unit starting February 11, 2020 to the date the Tenant moves out of the unit.',
#  '4. The Tenant shall also pay to the Landlord $175.00 for the cost of filing the application.',
#  '5. If the Tenant does not pay the Landlord the full amount owing* on or before February 21, 2020, the Tenant will start to owe interest.',
#  'This will be simple interest calculated from February 22, 2020 at 3.00% annually on the balance outstanding.',
#  '6. If the unit is not vacated on or before February 21, 2020, then starting February 22, 2020, the Landlord may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '7. Upon receipt of this order, the Court Enforcement Office (Sheriff) is directed to give vacant possession of the unit to the Landlord, on or after February 22, 2020.',
#  '8. If, on or before February 21, 2020, the Tenant pays the amount of $19,935.00** to the Landlord or to the Board in trust, this order for eviction will be void.',
#  'This means that the tenancy would not be terminated, and the Tenant could remain in the unit.',
#  'If this payment is not made in full and on time, the Landlord may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '9. The Tenant may make a motion to the Board under subsection 74(11) of the Act to set aside this order if they pay the amount required under that subsection on or after February 22, 2020 but before the Sheriff gives vacant possession to the Landlord.',
#  'The Tenant is only entitled to make this motion once during the period of the tenancy agreement with the Landlord.',
#  'February 10, 2020 Date Issued Sonia Anwar-Ali Member, Landlord and Tenant Board Toronto East-RO 2275 Midland Avenue, Unit 2 Toronto ON M1P3E7 If you have any questions about this order, call 416-645-8080 or toll free at 1-888-332-3234.',
#  'In accordance with section 81 of the Act, the part of this order relating to the eviction expires on August 22, 2020 if the order has not been filed on or before this date with the Court Enforcement Office (Sheriff) that has territorial jurisdiction where the rental unit is located.',
#  '* Refer to section A on the attached Summary of Calculations.',
#  '** Refer to section B on the attached Summary of Calculations.',
#  'Schedule 1 SUMMARY OF CALCULATIONS File Number: TEL-05033-19 A.',
#  'Amount the Tenant must pay if the tenancy is terminated: Reasons for amount owing Period Amount Arrears: (up to the termination date in the Notice of Termination) January 1, 2015 to September 22, 2019 $12,900.27 Plus compensation: (from the day after the termination date in the Notice to the date of the order) September 23, 2019 to February 10, 2020 $6,026.34 Less the rent deposit: -$1,300.00 Less the interest owing on the rent deposit: December 30, 2014 to September 22, 2019 -$106.87 Amount owing to the Landlord on the order date:(total of previous boxes) $17,519.74 Additional costs the Tenant must pay to the Landlord: $175.00 Plus daily compensation owing for each day of occupation starting February 11, 2020: $42.74 (per day) Total the Tenant must pay the Landlord if the tenancy is terminated: $17,694.74, + $42.74 per day starting February 11, 2020 B.',
#  'Amount the Tenant must pay to void the eviction order and continue the tenancy: Reasons for amount owing Period Amount Arrears: January 1, 2015 to February 29, 2020 $19,760.00 Additional costs the Tenant must pay to the Landlord: $175.00 Total the Tenant must pay to continue the tenancy: On or before February 21, 2020 $19,935.00']

# %% [markdown]
# ## Updating CSV with Cleaned File, Metadata, and Case Contents
# - Adding column for cleaned full file
# - Adding column for metadata
# - Adding column for case contents

# %%
silver_data
# Out:
#                                          raw_file_text        raw_file_name
# 0    Metadata:\nDate:\t2017-01-18\nFile number:\t\n...     CEL-62600-16.txt
# 1    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-62852-16.txt
# 2    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-63024-16.txt
# 3    Metadata:\nDate:\t2017-01-20\nFile number:\t\n...     CEL-63056-16.txt
# 4    Metadata:\nDate:\t2017-02-03\nFile number:\t\n...     CEL-63193-16.txt
# ..                                                 ...                  ...
# 667  Metadata:\nDate:\t2018-12-13\nFile number:\t\n...  TSL-98918-18-RV.txt
# 668  Metadata:\nDate:\t2018-11-23\nFile number:\t\n...     TSL-99691-18.txt
# 669  Metadata:\nDate:\t2018-11-29\nFile number:\t\n...     TSL-99824-18.txt
# 670  Metadata:\nDate:\t2018-12-12\nFile number:\t\n...     TSL-99900-18.txt
# 671  Metadata:\nDate:\t2018-11-20\nFile number:\t\n...     TSL-99965-18.txt
#
# [672 rows x 2 columns]

# %%
import time
import numpy as np
from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen = 500)

cases_contents = []
cases_metadata = []
full_cleaned = []

raw_files = silver_data['raw_file_text'].tolist()
for index, raw_file in enumerate(raw_files):
    iteration_start_time = time.time()
    better_file = general_cleaning(raw_file)
    try:
        metadata_list, content_list = separate_file_sections(better_file)
        full_cleaned.append(better_file)
        # cases_metadata.append(remove_end_tag_and_restructure(metadata_list)) # removing a bit more text if possible
        cases_metadata.append(metadata_list) # removing a bit more text if possible
        cases_contents.append(remove_end_tag_and_restructure(content_list))

        # Save the end time of this iteration and push it into the deque
        iteration_end_time = time.time()
        time_deque.append(iteration_end_time - iteration_start_time)

        # progress tracker
        average_time_per_file = np.mean(time_deque)
        files_left = len(raw_files) - (index + 1)
        estimated_time_left = files_left * average_time_per_file

        print(f"Files processed: {index + 1} of {len(raw_files)}, Estimated time remaining: {time.strftime('%H:%M:%S', time.gmtime(estimated_time_left))}", end='\r')
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", index)

silver_data['full_cleaned'] = full_cleaned
silver_data['metadata'] = cases_metadata
silver_data['content'] = cases_contents
silver_data.head()
# Out:
# Files processed: 672 of 672, Estimated time remaining: 00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...

# %% [markdown]
# # Case Citation and File Number
# - Extracting case citation from metadata
# - Extracting file number from all data (it's not as consistently formatted so the approach has to be more broad)

# %%
import re

def get_case_citation(metadata_list):
    for line in metadata_list:
        if "Citation:" in line:
            citation_start = line.find("Citation: ")
            # print(citation_start)
            citation_end = line.find("LTB)") + 4
            # print(citation_end)
            return line[citation_start : citation_end].replace("Citation: ", "").strip()
        elif "Référence: " in line:
            citation_start = line.find("Référence: ")
            # print(citation_start)
            citation_end = line.find("LTB)") + 4
            # print(citation_end)
            return line[citation_start : citation_end].replace("Référence: ", "").strip()
    return None

def get_file_number(metadata_list):
    # metadata_str = "".join(get_case_citation(metadata_list))
    metadata_str = " ".join(metadata_list)

    if "Citation: " in metadata_str:
        file_nums = metadata_str[metadata_str.find("File number: ") + len("File number: ") : metadata_str.find("Citation:")].strip()
    elif "Référence: " in metadata_str:
        file_nums = metadata_str[metadata_str.find("Numéro de dossier: ") + len("Numéro de dossier: ") : metadata_str.find("Référence")].strip()

    if len(file_nums) == 0:
        return None
    
    file_nums = file_nums.replace(";", " ")
    
    # eliminates duplicates or instances of something like 'TNL-10004-18 TNL-10004-18' being one list item
    file_num = list(set(file_nums.split()))
    file_num = ";".join(file_num)
    file_num = re.sub(r'[^\w\s]$', '', file_num)

    # removing duplicate file numbers
    if ";" in file_num:
        file_num = list(set(file_num.split(";"))) 
        file_num = [re.sub(r'[\(\)]', '', num) for num in file_num] # removing any trailing punctuation from each file number
        file_num = ";".join(file_num)

    # removes any parentheses from the file number
    file_num = re.sub(r'[\(\)]', '', file_num)

    return file_num

# test_row = 149
# test_metadata = silver_data.loc[test_row, "metadata"]# + silver_data.loc[test_row, "content"]
# print(get_file_number(test_metadata))
# silver_data.loc[test_row, "metadata"]

# %%
import time
import numpy as np
from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 500 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    # adding to 'case_citation' and 'file_number' columns
    try:
        metadata_list, content_list = separate_file_sections(general_cleaning(silver_data.loc[row.Index, "raw_file_text"]))
        silver_data.at[row.Index, 'case_citation'] = get_case_citation(metadata_list)
        silver_data.at[row.Index, 'file_number'] = get_file_number(metadata_list)
        
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print(f"Files processed: {index + 1} of {len(silver_data)}, Estimated time remaining: {time.strftime('%H:%M:%S', time.gmtime(estimated_time_left))}", end='\r')

silver_data.head()
# Out:
# Files processed: 672 of 672, Estimated time remaining: 00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16

# %%
from evaluation import *
# wrongs = evaluate(silver_data, gold_data, "file_number", return_inaccurate = True, metric = "jaro_winkler")
# extracted_successfully = 0
# for row in wrongs.index:
#     if str(wrongs.loc[row, wrongs.columns[1]]) in str(wrongs.loc[row, wrongs.columns[0]]):
#         extracted_successfully += 1
        
# print(f"\nExtracted {extracted_successfully} out of {len(silver_data)} also file numbers correctly. Total accuracy could be {round((extracted_successfully / len(silver_data)), 2) + 0.916}%")
evaluate(silver_data, gold_data, "file_number", return_inaccurate = True, metric = "jaro_winkler")
# Out:
#                                     silver_file_number  \
# 33                                     CEL-71370-17-RV
# 48              CET-73038-18;CEL-75759-18;CEL-73640-18
# 50                     CEL-76175-18-SA;CEL-73963-18-RV
# 51                           CEL-73985-18;CET-72638-18
# 60              CEL-76171-18;CEL-75701-18;CET-75675-18
# 61                                     CEL-76435-18-RV
# 72                           CEL-77933-18;CET-77737-18
# 73   CEL-78470-18.;CEL-78005-18;CEL-78005-18-RV;CEL...
# 83                                     CEL-80413-18-IN
# 92              CET-65284-17;CEL-65840-17;CEL-65426-17
# 93              CET-70370-17;CEL-71395-17;CET-70509-17
# 94                           CET-74655-18;CEL-75019-18
# 95                           EAL-60748-16;EAT-60550-16
# 107                                    EAL-73036-18-RV
# 133                                    HOL-03461-18-RV
# 150                          SWL-08113-17;SWL-08112-17
# 166                                    SWL-13848-18-RV
# 187                          SWL-18712-18;SWL-18713-18
# 188                       SWL-19968-18-SA;SWL-19968-18
# 255                                    TEL-78933-17-RV
# 269                                   TEL-80483-17-RV2
# 293                          TEL-86219-17;TEL-90053-18
# 298                                               2-14
# 301                          TEL-86991-17;TET-85939-17
# 302                                    TEL-87077-17-AM
# 306                                    TEL-87330-18-RV
# 310             TEL-87475-18;TET-88355-18;TET-86819-17
# 340                                    TEL-89124-18-RV
# 344                                    TEL-89226-18-RV
# 368                                    TEL-90055-18-RV
# 388                                    TEL-91060-18-RV
# 411                                    TEL-95255-18-AM
# 420                          TNL-01183-18;TNL-00793-18
# 425                                    TNL-01365-18-RV
# 440                          TNT-00589-17;TNL-03299-18
# 441                                   TNL-03769-18-RV2
# 459                                659/18;TNL-05489-18
# 489                                    TNL-08533-18-RV
# 496                                    TNL-09111-18-RV
# 544                          TNT-98761-17;TNL-95937-17
# 545                          TNT-99703-17;TNL-99287-17
# 548                          TNT-05236-18;TNL-05630-18
# 560                    TST-02626-19-RV;TSL-04253-19-RV
# 572          TSL-75068-16;TST-73374-16;TSL-07388-19-RV
# 573                          TSL-07620-19;TST-05964-19
# 587                                   TSL-81884-17-IN2
# 606                                    TSL-91342-17-RV
# 608                    TSL-91513-17-IN;TST-90349-17-IN
# 616          TSL-93207-18-RV;TSL-00082-18;TST-94747-18
# 633                       TSL-95431-18-RV;TSL-95431-18
# 637                                    TSL-95667-18-RV
# 657                                       TSL-98384-18
#
#                               gold_file_number
# 33                                CEL-71370-17
# 48                                CEL-73640-18
# 50                             CEL-73963-18-RV
# 51                                CEL-73985-18
# 60                                CEL-76171-18
# 61                                CEL-76435-18
# 72                                CEL-77933-18
# 73                             CEL-78005-18-RV
# 83                                CEL-80413-18
# 92                                CET-65284-17
# 93                                CET-70370-17
# 94                                CET-74655-18
# 95                                EAL-60748-16
# 107                               EAL-73036-18
# 133                               HOL-03461-18
# 150                  SWL-08112-17;SWL-08113-17
# 166                               SWL-13848-18
# 187                               SWL-18712-18
# 188                            SWL-19968-18-SA
# 255                               TEL-78933-17
# 269                            TEL-80483-17-RV
# 293                               TEL-86219-17
# 298                               TEL-86783-17
# 301                               TEL-86991-17
# 302                               TEL-87077-17
# 306                               TEL-87330-18
# 310     TEL-87475-18;TET-86819-17;TET-88355-18
# 340                               TEL-89124-18
# 344                               TEL-89226-18
# 368                               TEL-90055-18
# 388                               TEL-91060-18
# 411                               TEL-95255-18
# 420                  TNL-00793-18;TNL-01183-18
# 425                               TNL-01365-18
# 440                  TNL-03299-18;TNT-00589-17
# 441                               TNL-03769-18
# 459                               TNL-05489-18
# 489                               TNL-08533-18
# 496                               TNL-09111-18
# 544                               TNL-95937-17
# 545                               TNL-99287-17
# 548                               TNT-05236-18
# 560                               TSL-04253-19
# 572                               TSL-07388-19
# 573                               TSL-07620-19
# 587                               TSL-81884-17
# 606                               TSL-91342-17
# 608                               TSL-91513-17
# 616  TSL-93207-18-RV;TST-94747-18;TSL-00082-18
# 633                            TSL-95431-18-RV
# 637                               TSL-95667-18
# 657                            TSL-98384-18-AM

# %%
from evaluation import *
wrongs = evaluate(silver_data, gold_data, "file_number", return_inaccurate = True, metric = "jaro_winkler")
extracted_successfully = 0
for row in wrongs.index:
    if str(wrongs.loc[row, wrongs.columns[1]]) in str(wrongs.loc[row, wrongs.columns[0]]):
        extracted_successfully += 1
        
print(f"\nExtracted {extracted_successfully} out of {len(silver_data)} also citations correctly. Total accuracy could be {round((extracted_successfully / len(silver_data)), 2) + 0.916}%")
# Out:
# Extracted 45 out of 672 also citations correctly. Total accuracy could be 0.986%

# %%
test_row = 67
test_metadata = silver_data.loc[test_row, "metadata"]# + silver_data.loc[test_row, "content"]
print(get_file_number(test_metadata))
silver_data.loc[test_row, "metadata"]
# Out:
# CEL-77387-18
# ['Date: 2018-07-30',
#  'File number:',
#  'CEL-77387-18',
#  'CEL-77387-18',
#  'Citation: CEL-77387-18 (Re), 2018 CanLII 88554 (ON LTB), <https://canlii.ca/t/hv7l3>, retrieved on 2023-05-16 https://canlii.ca/t/hv7l3']

# %%
def check_df(df):
    """
    Checks df for null values, number of unique values in each column, and data types
    """

    print(f"Df Size: {df.shape[0]} rows, {df.shape[1]} columns")
    print("-" * 30)

    print("\n" + "Checking for null values...")
    print("-" * 25)
    print(df.isnull().sum())

    print("\n" + "Checking data types...")
    print("-" * 25)
    for col in df.columns:
        col_type = str(type(df.loc[0, col])).replace("<class '", "").replace("'>", "")
        print(f"{col}: {col_type}")

check_df(silver_data)
# Out:
# Df Size: 672 rows, 7 columns
# ------------------------------
#
# Checking for null values...
# -------------------------
# raw_file_text    0
# raw_file_name    0
# full_cleaned     0
# metadata         0
# content          0
# case_citation    0
# file_number      0
# dtype: int64
#
# Checking data types...
# -------------------------
# raw_file_text: str
# raw_file_name: str
# full_cleaned: list
# metadata: list
# content: list
# case_citation: str
# file_number: str

# %%
## can't eval because it wasn't actually annotated in the gold data
# evaluate(silver_data, gold_data, "case_citation", return_inaccurate = True, metric = "jaro_winkler")

# %% [markdown]
# # Language Detection

# %%
# !pip install langdetect
from langdetect import detect

def is_mostly_french(text, threshold):
    try:
        detected_language = detect(text)
        if detected_language == 'fr':
            return True
        else:
            return False
    except:
        return False

def is_french(text, threshold):
    try:
        detected_language = detect(text)
        if detected_language == 'fr':
            return True
        language_probabilities = detect_langs(text)
        for lang in language_probabilities:
            if lang.lang == 'fr' and lang.prob > threshold:
                return True
        return False
    except:
        return False

is_french(silver_data.loc[109, "raw_file_text"], 0.7)
# Out:
# False

# %% [markdown]
# ## Updating CSV with Language

# %%
# import time
# import numpy as np
# from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 500 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    # adding to 'case_citation' and 'file_number' columns
    try:
        # adding to 'language' column
        if is_french(silver_data.loc[row.Index, "raw_file_text"], 0.7) == True:
            silver_data.at[row.Index, 'language'] = "French"
        else:
            silver_data.at[row.Index, 'language'] = "English"

    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print(f"Files processed: {index + 1} of {len(silver_data)}, Estimated time remaining: {time.strftime('%H:%M:%S', time.gmtime(estimated_time_left))}", end='\r')

silver_data.head()
# Out:
# Files processed: 672 of 672, Estimated time remaining: 00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English

# %% [markdown]
# # Year
# - not meaningful really but nice for the corpus

# %%
import re

def get_year_from_file_number(file_number):

    if isinstance(file_number, list):
        file_number = " ".join(file_number)

    if ";" not in file_number:
        # print("UES")
        file_number = [tok for tok in file_number.split("-") if (len(tok) == 2 and tok.isdigit())]
        return "20" + file_number[0]
    else:
        file_numbers = file_number.split(";")
        file_numbers = [tok for tok in file_numbers if (len(tok) == 2 and tok.isdigit())]
        return "20" + file_number[0]
    # elif file_number.isinstance(list):

print(get_year_from_file_number("TEL-81359-17-AM")) # Outputs: "17"
print(get_year_from_file_number("TEL-81405-17")) # Outputs: "17"
print(get_year_from_file_number(silver_data.loc[5, 'file_number'])) # Outputs: "17"
silver_data.loc[5, 'file_number']
# Out:
# 2017
# 2017
# 2017
# 'CEL-63559-17'

# %% [markdown]
# ## Updating CSV with Year

# %%
# import time
# import numpy as np
# from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 500 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    # adding to 'case_citation' and 'file_number' columns
    try:
        silver_data.at[row.Index, 'year'] = get_year_from_file_number(silver_data.at[row.Index, 'file_number'])
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print(f"Files processed: {index + 1} of {len(silver_data)}, Estimated time remaining: {time.strftime('%H:%M:%S', time.gmtime(estimated_time_left))}", end='\r')
    
    # if index == 6:
    #     break

silver_data.head()
# Out:
# Files processed: 672 of 672, Estimated time remaining: 00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016

# %%
check_df(silver_data)
# Out:
# Df Size: 672 rows, 9 columns
# ------------------------------
#
# Checking for null values...
# -------------------------
# raw_file_text    0
# raw_file_name    0
# full_cleaned     0
# metadata         0
# content          0
# case_citation    0
# file_number      0
# language         0
# year             0
# dtype: int64
#
# Checking data types...
# -------------------------
# raw_file_text: str
# raw_file_name: str
# full_cleaned: list
# metadata: list
# content: list
# case_citation: str
# file_number: str
# language: str
# year: str

# %% [markdown]
# # LTB Location
# - not 100% effective but close to. Fallback on other methods (transformers, etc) if need be

# %% [markdown]
# ## Method 1 - Rule-Based

# %%
def find_all_positions(text, keyword):
    positions = []
    start = 0
    while True:
        index = text.find(keyword, start)
        if index == -1:
            break
        positions.append(index)
        start = index + 1
    return positions

# %%
# backup for other methods, using " ON " + postal code as a marker
def find_postal_code_index(text):
    match = re.search(r' ON [A-Z]\d[A-Z] ?\d[A-Z]\d', text)
    if match:
        return match.start()
    else:
        return None

def extract_loc_rule(text_list):

    content_str = " ".join(text_list)
    # print(content_str)

    # "hear" is a good marker for the location sentence ("heard in/on", "hearing", etc)
    if "hear" in content_str:
        hear_inds = find_all_positions(content_str, "hear") # list of indices where "hear" appears in string
        # print(hear_inds)

        for hear_ind in hear_inds:

            hear_substr = content_str[hear_ind - 50 : hear_ind + 50]
            possible_sentences = hear_substr.split(". ")
            # print(possible_sentences)
            
            hear_sent = [sent for i, sent in enumerate(possible_sentences) if "hear" in sent][0]
            # print(hear_sent)

            if len(hear_sent.split(" on ")) != 2:
                # print("TEST")
                # return None
                pass # go to next "hear" location in string
            else:
                
                location_sent, date = hear_sent.split(" on ") # should only split into 2 parts
                # print(location_sent)

                if " in " in location_sent:

                    # print(location_sent)
                    location = location_sent.split(" in ")[1].strip() # location name should be last tokens of string after token containing " in " (city name could be multiple tokens, so need to get all tokens after " in " token, not just last one)

                    # print(location)
                    location = location.split(" ")[-1] # location name should be last tokens of string after token containing "hear" (city name could be multiple tokens, so need to get all tokens after "hear" token, not just last one)
                    # print("YESSS")
                    return location.strip()
                
                else:
                    pass

    # use " ON " + postal code as a marker
    if " ON " in content_str:
        # print("|UESSS")
        # print(find_postal_code_index(content_str))
        postal_ind = find_postal_code_index(content_str)
        content_str_subsection = (content_str[postal_ind - 50 : postal_ind + 50])
        location = content_str_subsection.split(" ON ")[0].split()[-1]
        return location.strip()
    
    # if absolutely nothing works, return None and we'll use a transformer or something more nuanced
    return None

test_num = 10
extract_loc_rule(silver_data.loc[test_num, 'content'])
# " ".join(silver_data.loc[56, 'content'])
# silver_data.loc[test_num, 'content']
# Out:
# 'Mississauga'

# %% [markdown]
# ## Method 2 - SpaCy

# %%
gold_data.columns
# Out:
# Index(['file_number', 'adjudicating_member', 'ltb_location',
#        'landlord_represented', 'landlord_attended_hearing',
#        'tenant_represented', 'tenant_attended_hearing', 'landlord_nonprofit',
#        'tenant_collecting_subsidy', 'case_outcome',
#        'What was the length of the tenancy', 'monthly_rent',
#        'rental deposit amount', 'was there an rent increases', 'total_arrears',
#        'Over how many months did the arrears accumulate?',
#        'Does the tenant made a payment on the arrears after the eviction notice',
#        'tenant_arrears_history_mentioned', 'tenant_ability_to_pay_rent',
#        'What were the specific mental, medical, or physical conditions of the tenant, if any?',
#        'tenant_children_present', 'tenant_employed',
#        'tenant_government_assistance', 'employment_stability_doubts',
#        'sufficient_income_to_pay_rent', 'tenant_job_loss_mentioned',
#        'tenant_extenuating_circumstances', 'tenant_difficulty_finding_housing',
#        'tenant_prior_notice_given', 'postponement_additional_arrears',
#        'validity_of_N4_notice_mentioned', 'Payment Plan', 'L1 present?',
#        'L2 present?', 'L3 present?', 'L4 present?', 'L8 present?',
#        'L9 present?', 'N5 present?', 'N6 present?', 'N7 present?',
#        'N8 present?', 'T1 present?', 'T2 present?', 'T3 present?',
#        'T5 present?', 'T6 present?', 'raw_file_text', 'raw_file_name'],
#       dtype='object')

# %%
all_locations = list(set(gold_data['ltb_location'].unique().tolist())) # list of all unique locations in the annotated data
all_locations = list(set([loc.strip() for loc in all_locations]))
all_locations

import spacy

# Load the English language model in spaCy
nlp = spacy.load('en_core_web_sm')

def extract_location_spacy(string_list, model = nlp, other_locations = all_locations):

    string = " ".join(string_list)

    # uses a spacy model + its vocabulary to extract and return the location if possible
    doc = model(string)
    for ent in doc.ents:
        if ent.label_ == 'GPE':
            return ent.text

    # otherwise looks through the list of all locations in the annotated data and returns the first one that appears in the string -- for example, "Hamilton"
    for tok in string.split():
        if tok in other_locations:
            return tok

    # if all else fails, return None -- use a transformer or something later idk
    return None

all_locations
# Out:
# 2023-05-30 22:05:09.519931: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ['Belleville',
#  'Bracebridge',
#  'Toronto',
#  'London',
#  'Mississauga',
#  'by telephone',
#  'Whitby',
#  'Kingston',
#  'Barrie',
#  'Stratford',
#  'Peterborough',
#  'Hamilton',
#  'Brantford',
#  'Cobourg',
#  'Ottawa',
#  'Windsor',
#  'Sudbury',
#  'Review completed without hearing',
#  'Waterloo',
#  'Not stated',
#  'Lindsay',
#  'Orangeville',
#  'Burlington',
#  'Newmarket',
#  'Woodstock',
#  'Thunder Bay',
#  'Not stated, hearing in Windsor']

# %%
start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    try:
        ### rule-based extremely quick -- pretty effective but imperfect
        location = extract_loc_rule(silver_data.loc[row.Index, 'content'])#.title() # returns the string in title case

        if not location[0].isalnum(): # something like "[CITY]" -- use spacy method
            location = extract_location_spacy(silver_data.loc[row.Index, 'content'])

        if not location[0].isupper():
            # I know this isn't a great rule in general but this seems to be consistent/reliable across all cases.
            # City names are all capitalized. Otherwise it finds "it", "heard", and more as locations
            location = extract_location_spacy(silver_data.loc[row.Index, 'content'])

        if location == None: # rule-based returns None
            location = extract_location_spacy(silver_data.loc[row.Index, 'content'])

        # use the found location
        silver_data.at[row.Index, 'ltb_location'] = location.title() # Title casing for consistency

    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print("Files processed: ", index + 1, "of", len(silver_data),
          "Estimated time remaining: ", time.strftime('%H:%M:%S', time.gmtime(estimated_time_left)), end='\r')

silver_data.head()
# Out:
# 'NoneType' object is not subscriptable with file at Df row:  459
# Files processed:  672 of 672 Estimated time remaining:  00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year  \
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016
#
#   ltb_location
# 0  Mississauga
# 1  Mississauga
# 2  Mississauga
# 3  Mississauga
# 4  Mississauga

# %%
silver_data.ltb_location.value_counts()
# Out:
# Toronto         365
# Mississauga      78
# Whitby           63
# Newmarket        33
# Belleville       16
# Peterborough     15
# Barrie           12
# London           11
# Ottawa           11
# Lindsay          10
# Windsor           8
# Burlington        5
# Hamilton          5
# Duty Counsel      5
# Waterloo          5
# Cobourg           3
# Stratford         3
# Kingston          2
# Sudbury           2
# Woodstock         1
# Dg                1
# Elgin             1
# Dd                1
# D.C.              1
# Nc                1
# N.F.              1
# Kw                1
# Ac                1
# Lg                1
# Gl                1
# Sarnia            1
# Goderich          1
# Tc                1
# Brantford         1
# Bay               1
# Bracebridge       1
# Orangeville       1
# J.H.S.            1
# Name: ltb_location, dtype: int64

# %%
get_nulls(silver_data, 'ltb_location') # this one is problematic for other columns too. The formatting seems to be completely different
# Out:
#                                          raw_file_text     raw_file_name  \
# 459  Metadata:\nDate:\t2018-12-17\nFile number:\t\n...  TNL-05489-18.txt
#
#                                           full_cleaned  \
# 459  [Metadata:, Date: 2018-12-17, File number:, 65...
#
#                                               metadata  \
# 459  [Date: 2018-12-17, File number:, 659/18;, TNL-...
#
#                                                content case_citation  \
# 459  [CITATION: Capreit 2 Limited Partnership v., R...           Cit
#
#              file_number language year ltb_location
# 459  659/18;TNL-05489-18  English  206          NaN

# %%
evaluate(silver_data, gold_data, "ltb_location", return_inaccurate = True, metric = "jaro_winkler").head(60)
# Out:
#     silver_ltb_location               gold_ltb_location
# 5                Barrie                     Mississauga
# 6                 Elgin                     Mississauga
# 34               Barrie                     Mississauga
# 81              Toronto                     Mississauga
# 85               Barrie                     Mississauga
# 88              Toronto                     Mississauga
# 106              Ottawa                    by telephone
# 110              Ottawa                    by telephone
# 117              Barrie                     Mississauga
# 123            Hamilton                         Toronto
# 126           Newmarket                         Toronto
# 128          Burlington                         Toronto
# 131              Whitby                         Toronto
# 133           Newmarket                         Toronto
# 134           Newmarket                         Toronto
# 142                 Bay                     Thunder Bay
# 148          Burlington                        Hamilton
# 149                  Tc                          London
# 150             Windsor  Not stated, hearing in Windsor
# 151            Goderich                          London
# 152             Windsor                          London
# 155           Stratford                          London
# 156             Windsor                          London
# 157             Windsor                          London
# 158           Stratford                          London
# 159              Sarnia                          London
# 160             Windsor                          London
# 161            Waterloo                          London
# 162             Windsor                          London
# 163            Waterloo                          London
# 164             Windsor                          London
# 165                  Ac                          London
# 166            Waterloo                          London
# 167                  Gl                          London
# 168        Duty Counsel                          London
# 169        Duty Counsel                          London
# 170                  Lg                          London
# 172                  Dg                          London
# 174        Duty Counsel                          London
# 175                  Kw                          London
# 176            Waterloo                          London
# 178                  Nc                          London
# 181        Duty Counsel                          London
# 184        Duty Counsel                          London
# 187                  Dd                          London
# 196             Toronto                          Whitby
# 219                D.C.                         Toronto
# 224             Toronto                    by telephone
# 255             Toronto                          Whitby
# 269                N.F.                      Belleville
# 277             Lindsay                         Toronto
# 307              Whitby                         Toronto
# 308              Whitby                         Toronto
# 310              Whitby                         Toronto
# 311              Whitby                         Toronto
# 313              Whitby                         Toronto
# 315              Whitby                         Toronto
# 316              Whitby                         Toronto
# 317        Peterborough                         Toronto
# 322              Whitby                         Toronto

# %%
silver_data.loc[454, 'content']
# Out:
# ["Order under Section 69 Residential Tenancies Act, 2006 File Number: TNL-04964-18 RV (the 'Landlord') applied for an order to terminate the tenancy and evict GG (the 'Tenant') because the Tenant did not pay the rent that the Tenant owes.",
#  'This application was heard in Toronto on June 5, 2018.',
#  'The Landlord and the Tenant attended the hearing.',
#  'Determinations and Reasons: 1.',
#  'The Tenant has not paid the total rent she was required to pay for the period from February 1, 2018 to June 30, 2018.',
#  'Because of the arrears, the Landlord served a Notice of Termination effective May 11, 2018.',
#  '2. The Tenant testified that she is living in the rental unit with four young grandchildren, aged between seven and fourteen years old.',
#  'She was supporting them on short-term disability payments and child tax credits until the payments stopped in April, 2018.',
#  'She has been working to replace her short term disability with ODSP payments.',
#  'She has not paid the rent since February, 2018, because she needed the money to buy groceries for the children.',
#  'The Tenant has been looking for alternative accommodation since January, 2018, and does not believe she is currently eligible to go to a shelter.',
#  '3. The Landlord is seeking a standard termination order.',
#  'She has not received any rent payments in over five months and it is a hardship for her to carry all the costs related to the rental unit.',
#  "4. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act.",
#  'Although the Tenant is in very difficult circumstances at the moment, she was unable to propose any reasonable payment plan, and had no idea when she would have sufficient income to make any payments towards the rent.',
#  'The lack of any rent payments for over five months has severely prejudiced the Landlord.',
#  'However, I find that it would not be unfair to postpone the eviction until June 30, 2018, pursuant to subsection 83(1)(b) of the Act.',
#  'This will permit the Tenant more time to find alternative accommodation for such a large family.',
#  'It is ordered that: 1.',
#  'Unless the Tenant voids the order as set out below, the tenancy between the Landlord and the Tenant is terminated.',
#  'The Tenant must move out of the rental unit on or before June 30, 2018.',
#  '2. The Tenant shall pay to the Landlord $7,144.72*, which represents the amount of rent owing and compensation up to June 12, 2018.',
#  '3. The Tenant shall also pay to the Landlord $59.18 per day for compensation for the use of the unit starting June 13, 2018 to the date he moves out of the unit.',
#  '4. The Tenant shall also pay to the Landlord $190.00 for the cost of filing the application.',
#  '5. If the Tenant does not pay the Landlord the full amount owing* on or before June 30, 2018, the Tenant will start to owe interest.',
#  'This will be simple interest calculated from June 24, 2018 at 3.00% annually on the balance outstanding.',
#  '6. If the unit is not vacated on or before June 30, 2018, then starting July 1, 2018, the Landlord may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '7. Upon receipt of this order, the Court Enforcement Office (Sheriff) is directed to give vacant possession of the unit to the Landlord, on or after July 1, 2018.',
#  '8. If, on or before June 30, 2018, the Tenant pays the amount of $8,390.00** to the Landlord or to the Board in trust, this order for eviction will be void.',
#  'This means that the tenancy would not be terminated and the Tenant could remain in the unit.',
#  'If this payment is not made in full and on time, the Landlord may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '9. The Tenant may make a motion to the Board under subsection 74(11) of the Act to set aside this order if they pay the amount required under that subsection on or after July 1, 2018 but before the Sheriff gives vacant possession to the Landlord.',
#  'The Tenant is only entitled to make this motion once during the period of the tenancy agreement with the Landlord.',
#  'June 12, 2018 Date Issued Nancy Morris Member, Landlord and Tenant Board Toronto North-RO 47 Sheppard Avenue East, Suite 700, 7th Floor Toronto ON M2N5X5 If you have any questions about this order, call 416-645-8080 or toll free at 1-888-332-3234.',
#  'In accordance with section 81 of the Act, the part of this order relating to the eviction expires on January 1, 2019 if the order has not been filed on or before this date with the Court Enforcement Office (Sheriff) that has territorial jurisdiction where the rental unit is located.',
#  '* Refer to section A on the attached Summary of Calculations.',
#  '** Refer to section B on the attached Summary of Calculations.',
#  'Schedule 1 SUMMARY OF CALCULATIONS File Number: TNL-04964-18 A.',
#  'Amount the Tenant must pay if the tenancy is terminated: Reasons for amount owing Period Amount Arrears: (up to the termination date in the Notice of Termination) February 1, 2018 to May 11, 2018 $5,250.96 Plus compensation: (from the day after the termination date in the Notice to the date of the order) May 12, 2018 to June 12, 2018 $1,893.76 Amount owing to the Landlord on the order date:(total of previous boxes) $7,144.72 Additional costs the Tenant must pay to the Landlord: $190.00 Plus daily compensation owing for each day of occupation starting June 13, 2018: $59.18 (per day) Total the Tenant must pay the Landlord if the tenancy is terminated: $7,334.72, + $59.18 per day starting June 13, 2018 B.',
#  'Amount the Tenant must pay to void the eviction order and continue the tenancy: Reasons for amount owing Period Amount Arrears: February 1, 2018 to June 30, 2018 $8,200.00 Additional costs the Tenant must pay to the Landlord: $190.00 Total the Tenant must pay to continue the tenancy: On or before June 30, 2018 $8,390.00']

# %% [markdown]
# # Decision Date
# - uses entire case file (metadata + content)
# - Eg.: "This application was heard in Toronto on October 16, 2019." should return "October 16, 2019" (then date is converted into the same format as the other dates in the df)
# - Rule-based may be too simple for this so may need to use ML

# %%
from dateutil.parser import parse

def convert_to_datetime(date_str):
    # Parse date using dateutil.parser.parse
    dt = parse(date_str)
    
    # Format date with strftime in the format 'MM/DD/YYYY'
    return dt.strftime('%m/%d/%Y')

# %%
import spacy

nlp = spacy.load("en_core_web_sm") # loading this outside of the function saves ~2s per function call

def find_dates_in_list(string_list, model=nlp):
    extracted_dates = []
    for string in string_list:
        doc = nlp(string)
        for entity in doc.ents:
            if entity.label_ == "DATE":
                extracted_dates.append(entity.text)

    pattern = r"(?i)(\b\w+ \d{1,2}, \d{4}\b)"
    valid_dates = re.findall(pattern, ", ".join(extracted_dates))
    return list(set(valid_dates))

string_list = [
    "This application was heard in Toronto on October 16, 2019.",
    "The case was heard on June 12, 2020.",
    "The hearing was conducted on January 5, 2021.",
    "The meeting was adjourned, and a new date was set for November 30, 2022.",
    "No hearing was held in this matter.",
    "The matter was discussed on September 14, 2021, and a decision was made."
]
result = find_dates_in_list(string_list)
print(result)
# Out:
# ['November 30, 2022', 'January 5, 2021', 'June 12, 2020', 'September 14, 2021', 'October 16, 2019']

# %%
def get_hearing_date(string_list, prox = 20):
    case_tokens = " ".join(string_list).split() # case file merged into one string
    match_found = False # assume there's no match found
    first_prox = prox

    while not match_found:
        possible_strings_with_dates = [] # we'll look for dates in these strings
        # print(prox)
        for tok in case_tokens:
            if "issue" in tok.lower():
                hear_ind = case_tokens.index(tok)
                near_toks = case_tokens[hear_ind - (prox // 2) : hear_ind + prox]
                near_text = " ".join(near_toks)
                possible_strings_with_dates.append(near_text) # finds all sections within a "prox" range of the word "hear" and adds them to a list
        
        # print(possible_strings_with_dates)

        best_matches = list(set(find_dates_in_list(possible_strings_with_dates))) # finds all dates in the possible strings and returns a list of unique dates
        # print(best_matches)
        if len(best_matches) == 1 or prox <= 0:
            match_found = True
            break
        else:
            prox -= (first_prox // 4) # decrement by 25% of the first_prox each time
    
    if len(best_matches) > 0:
        return convert_to_datetime(best_matches[0])
    
    # if none of the above works, look for "Date: " and get that date lol (it's also the decision date -- I checked the annotated data)
    for line in string_list:
        if "Date: " in line:
            return convert_to_datetime(line.split("Date: ")[1]) # convert to the same format as other dates in the df

case_num = 156
full_case_list = silver_data.loc[case_num, 'metadata'] + silver_data.loc[case_num, 'content']
full_case_list[:15]
print(get_hearing_date(silver_data.loc[case_num, 'metadata'] + silver_data.loc[case_num, 'content'], prox = 20))
(silver_data.loc[case_num, 'metadata'] + silver_data.loc[case_num, 'content'])[:15]
# Out:
# 04/10/2018
# ['Date: 2018-04-10',
#  'File number:',
#  'SWL-11849-17',
#  'SWL-11849-17',
#  'Citation: SWL-11849-17 (Re), 2018 CanLII 88671 (ON LTB), <https://canlii.ca/t/hv7p8>, retrieved on 2023-05-16 https://canlii.ca/t/hv7p8',
#  "Order under Section 69 Residential Tenancies Act, 2006 File Number: SWL-11849-17 JP (the 'Landlord') applied for an order to terminate the tenancy and evict RS (the 'Tenant') because the Landlord intends to demolish the rental unit.",
#  'This application was heard in Windsor on March 29, 2018.',
#  'MH, the Landlord’s Legal Representative, attended the hearing.',
#  'The Tenant attended the hearing and declined the opportunity to speak with Duty Counsel prior to the hearing as he had previously been represented by counsel.',
#  'Determinations: 1.',
#  'The Landlord requires the rental unit to be vacated in order to demolish it.',
#  'I am satisfied that the Landlord has taken all reasonable steps to obtain the necessary permits for this work.',
#  "2. As set out in the attached reasons, I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until May 31, 2018, pursuant to subsection 83(1)(b) of the Act.",
#  'It is ordered that: 1.',
#  'The tenancy between the Landlord and the Tenant is terminated, as of May 31, 2018.']

# %% [markdown]
# ## Updating CSV with Decision Date

# %%
# about 13 per second

start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    try:
        full_case_list = silver_data.loc[row.Index, 'metadata'] + silver_data.loc[row.Index, 'content']
        silver_data.at[row.Index, 'decision_date'] = get_hearing_date(full_case_list, prox = 20)

    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print("Files processed: ", index + 1, "of", len(silver_data),
          "Estimated time remaining: ", time.strftime('%H:%M:%S', time.gmtime(estimated_time_left)), end = '\r')

silver_data.head()
# Out:
# Files processed:  672 of 672 Estimated time remaining:  00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year  \
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016
#
#   ltb_location decision_date
# 0  Mississauga    01/18/2017
# 1  Mississauga    01/09/2017
# 2  Mississauga    01/09/2017
# 3  Mississauga    01/09/2017
# 4  Mississauga    01/10/2017

# %%
get_nulls(silver_data, 'decision_date')
# Out:
# Empty DataFrame
# Columns: [raw_file_text, raw_file_name, full_cleaned, metadata, content, case_citation, file_number, language, year, ltb_location, decision_date]
# Index: []

# %%
evaluate(silver_data, gold_data, "decision_date", return_inaccurate = True, metric = "jaro_winkler")#.head(60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'decision_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb Cell 62 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y120sZmlsZQ%3D%3D?line=0'>1</a> evaluate(silver_data, gold_data, "decision_date", return_inaccurate = True, metric = "jaro_winkler")
#
# File ~/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/evaluation.py:32, in evaluate(preds_df, gold_df, col_name, return_inaccurate, metric, print_score)
#      29     preds = preds_df[col_name].tolist()
#      31 if not isinstance(preds_df, list):
# ---> 32     golds = gold_df[col_name].tolist()
#      34 assert len(preds) == len(golds), "The number of rows in the two DataFrames must be the same."
#      36 preds_cols = preds_df.columns.tolist()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'decision_date'

# %%
wrongs = evaluate(silver_data, gold_data, "decision_date", return_inaccurate = True, metric = "accuracy").index#.head(60)
# gold_data.loc[wrongs, ["hearing_date", "decision_date"]].head(20)
evaluate(silver_data, gold_data, "decision_date", return_inaccurate = True, metric = "accuracy")#.head(60)

# %%
import spacy

nlp = spacy.load("en_core_web_sm") # loading this outside of the function saves ~2s per function call

def find_dates_in_string(string, model=nlp):
    extracted_dates = []
    # for string in string_list:
    doc = nlp(string)
    for entity in doc.ents:
        if entity.label_ == "DATE":
            extracted_dates.append(entity.text)
    
    return list(set(extracted_dates))
    # pattern = r"(?i)(\b\w+ \d{1,2}, \d{4}\b)"
    # valid_dates = re.findall(pattern, ", ".join(extracted_dates))
    # return valid_dates

from datetime import datetime

def order_dates(dates_list):
    sorted_dates = sorted(dates_list, key=lambda x: datetime.strptime(x, '%m/%d/%Y'))
    return sorted_dates

# %%
# def get_hearing_date()
test_case_list = silver_data.loc[wrongs[0], 'content']
test_case_str = " ".join(test_case_list)
hdate_candidates = [line for line in test_case_str.lower().split(". ") if ("application" in line.lower() and "hear" in line.lower())]

order_dates([convert_to_datetime(date) for date in find_dates_in_list(hdate_candidates)])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 0
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb Cell 65 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y123sZmlsZQ%3D%3D?line=0'>1</a> # def get_hearing_date()
# ----> <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y123sZmlsZQ%3D%3D?line=1'>2</a> test_case_list = silver_data.loc[wrongs[0], 'content']
#       <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y123sZmlsZQ%3D%3D?line=2'>3</a> test_case_str = " ".join(test_case_list)
#       <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y123sZmlsZQ%3D%3D?line=3'>4</a> hdate_candidates = [line for line in test_case_str.lower().split(". ") if ("application" in line.lower() and "hear" in line.lower())]
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 0

# %%
silver_data.loc[wrongs[0], 'metadata']

# %% [markdown]
# # Hearing Date

# %%
import re
from datetime import datetime

def clean_and_convert_date(date_str):
    """
    Gets rid of artifacts found within strings containing dates and converts them to a consistent format.

    """
    
    # Use regex to find date in the format 'Month DD, YYYY'
    match = re.search(r'([a-zA-Z]+ \d{1,2}, \d{4})', date_str)
    if match:
        date_str = match.group(1)

        # Parse date with strptime in the format 'Month DD, YYYY'
        dt = datetime.strptime(date_str, '%B %d, %Y')

        # Format date with strftime in the format 'MM/DD/YYYY'
        return dt.strftime('%m/%d/%Y')

    return None

# Test the function
date_str = "September 3, 2019 f"
new_date_str = clean_and_convert_date(date_str)
print(new_date_str)
# Out:
# 09/03/2019

# %%
def extract_date_rule(text_list):

    content_str = " ".join(text_list)
    # print(content_str)

    if "date issued" in content_str.lower():
        DI_inds = find_all_positions(content_str.lower(), "date issued")
        for DI_ind in DI_inds:
            DI_substr = content_str[DI_ind - 50 : DI_ind + 50].lower()
            # print(DI_ind)
            # print(DI_substr)

            if len(DI_substr.split("date issued")) != 2:
                # should only contain 2
                pass

            # DI_sent = DI_substr.split("date issued")#.strip()
            # print(DI_substr)

            # regex pattern to find any date within the DI_sent substring
            date_pattern = r"(?i)(january|february|march|april|may|june|july|august|september|october|november|december) [0-9]{1,2}, [0-9]{4}"

            match = re.search(date_pattern, DI_substr)
            if match:
                # print(match)
                return match.group(0)
            
    elif "hear" in content_str:

        hear_inds = find_all_positions(content_str, "hear") # list of indices where "hear" appears in string
        # print(hear_inds)

        for hear_ind in hear_inds:

            hear_substr = content_str[hear_ind - 50 : hear_ind + 50]
            possible_sentences = hear_substr.split(". ")
            # print(possible_sentences)
            
            hear_sent = [sent for i, sent in enumerate(possible_sentences) if "hear" in sent][0]
            # print(hear_sent)

            if len(hear_sent.split(" on ")) != 2:
                # return None
                pass # go to next "hear" location in string
            else:
                location_sent, date = hear_sent.split(" on ") # should only split into 2 parts
                # print(location_sent)

                return date.strip()

    # if all else fails, return None
    return None

print(extract_date_rule(silver_data.loc[2, 'content']))
# print(clean_and_convert_date(extract_date_rule(silver_data.loc[56, 'content']))) # converts it into desired format
# silver_data.loc[56, 'content']
# Out:
# january 9, 2017

# %%
def extract_date_2(case_metadata: list):
    for line in case_metadata:
        if "Date: " in line:
            break
    
    # return the date in the format they gave us the data in - this might make things more useful for them idk
    return line.replace("Date: ", "")
    # return line.replace("Date: ", "")

print(extract_date_rule(silver_data.loc[0, 'content']))
print(extract_date_2(silver_data.loc[0, 'metadata']))
convert_to_datetime(extract_date_rule(silver_data.loc[0, 'content']))
convert_to_datetime(extract_date_2(silver_data.loc[0, 'metadata']))
# Out:
# january 30, 2017
# 2017-01-18
# '01/18/2017'

# %% [markdown]
# ## Updating CSV with Hearing Date

# %%
import time
import numpy as np
from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen=100)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    try:
        # rule-based method #1 -- uses 'content'
        found_date = extract_date_rule(silver_data.loc[row.Index, 'content'])

        if found_date == None: # rule-based method #2 -- uses 'metadata'
            found_date = extract_date_2(silver_data.loc[row.Index, 'metadata'])

        # normalize the format
        # formatted_date = clean_and_convert_date(found_date)
        formatted_date = convert_to_datetime(found_date)

        # if still None, try one more time to convert it
        silver_data.at[row.Index, 'hearing_date'] = formatted_date
            
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print("Files processed: ", index + 1, "of", len(silver_data),
          "Estimated time remaining: ", time.strftime('%H:%M:%S', time.gmtime(estimated_time_left)), end='\r')

silver_data.head()
# Out:
# String does not contain a date: t with file at Df row:  45900:00
# Files processed:  672 of 672 Estimated time remaining:  00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year  \
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016
#
#   ltb_location decision_date hearing_date
# 0  Mississauga    01/18/2017   01/30/2017
# 1  Mississauga    01/09/2017   01/09/2017
# 2  Mississauga    01/09/2017   01/09/2017
# 3  Mississauga    01/09/2017   01/09/2017
# 4  Mississauga    01/10/2017   02/03/2017

# %%
check_df(silver_data)
# Out:
# Df Size: 672 rows, 12 columns
# ------------------------------
#
# Checking for null values...
# -------------------------
# raw_file_text    0
# raw_file_name    0
# full_cleaned     0
# metadata         0
# content          0
# case_citation    0
# file_number      0
# language         0
# year             0
# ltb_location     1
# decision_date    0
# hearing_date     1
# dtype: int64
#
# Checking data types...
# -------------------------
# raw_file_text: str
# raw_file_name: str
# full_cleaned: list
# metadata: list
# content: list
# case_citation: str
# file_number: str
# language: str
# year: str
# ltb_location: str
# decision_date: str
# hearing_date: str

# %%
get_nulls(silver_data, 'hearing_date')
# Out:
#                                          raw_file_text     raw_file_name  \
# 459  Metadata:\nDate:\t2018-12-17\nFile number:\t\n...  TNL-05489-18.txt
#
#                                           full_cleaned  \
# 459  [Metadata:, Date: 2018-12-17, File number:, 65...
#
#                                               metadata  \
# 459  [Date: 2018-12-17, File number:, 659/18;, TNL-...
#
#                                                content case_citation  \
# 459  [CITATION: Capreit 2 Limited Partnership v., R...           Cit
#
#              file_number language year ltb_location decision_date hearing_date
# 459  659/18;TNL-05489-18  English  206          NaN    07/13/2018          NaN

# %%
evaluate(silver_data, gold_data, "hearing_date", return_inaccurate = True, metric = "jaro_winkler")#.head(60)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/_libs/index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'hearing_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb Cell 75 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/preprocessing_master.ipynb#Y136sZmlsZQ%3D%3D?line=0'>1</a> evaluate(silver_data, gold_data, "hearing_date", return_inaccurate = True, metric = "jaro_winkler")
#
# File ~/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/evaluation.py:32, in evaluate(preds_df, gold_df, col_name, return_inaccurate, metric, print_score)
#      29     preds = preds_df[col_name].tolist()
#      31 if not isinstance(preds_df, list):
# ---> 32     golds = gold_df[col_name].tolist()
#      34 assert len(preds) == len(golds), "The number of rows in the two DataFrames must be the same."
#      36 preds_cols = preds_df.columns.tolist()
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File /opt/miniconda3/lib/python3.10/site-packages/pandas/core/indexes/base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'hearing_date'

# %%
print(convert_to_datetime(extract_date_2(silver_data.loc[454, 'metadata'])))
silver_data.loc[454, 'metadata']

# %% [markdown]
# # Case CanLII URL
# - In the metadata, there's a hyperlink that seems to be a shortened URL to the case
# - Eg.:  *'Citation: NOL-10723-12 (Re), 2013 CanLII 5182 (ON LTB), <https://canlii.ca/t/fw1m8>, retrieved on 2023-05-17'*

# %%
silver_data.loc[0, 'metadata']

# %%
import re

def get_url_from_citation_string(text: str):
    """
    Returns URL to case file given a list of strings of metadata from a case file.
    String must begin with "Citation: " and URL must be within angle brackets.

    Parameters
    ----------
    text : str
        A string of metadata from a case file.

    Returns
    -------
    str
        A string of the URL to the case file.
    """

    pattern = r"<(.*?)>"
    matches = re.findall(pattern, text)
    return matches[0]

def get_url_from_metadata(case_metadata: list):
    """
    Extract URL to case file from a list of strings of metadata from a case file.

    Parameters
    ----------
    case_metadata : list
        A list of strings of metadata from a case file.

    Returns
    -------
    str
        A string of the URL to the case file.
    """

    for line in case_metadata:
        if ("Citation:" or "Référence:") in line:
            return get_url_from_citation_string(line)
        
    return None
        
get_url_from_metadata(silver_data.loc[1, 'metadata'])
# Out:
# 'https://canlii.ca/t/gxq6r'

# %% [markdown]
# ## Updating CSV with URLs

# %%
import time
import numpy as np
from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen = 100)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    try:
        silver_data.at[row.Index, 'url'] = get_url_from_metadata(silver_data.loc[row.Index, 'metadata'])
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print("Files processed: ", index + 1, "of", len(silver_data),
          "Estimated time remaining: ", time.strftime('%H:%M:%S', time.gmtime(estimated_time_left)), end='\r')

silver_data.head()
# Out:
# Files processed:  672 of 672 Estimated time remaining:  00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year  \
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016
#
#   ltb_location decision_date hearing_date                        url
# 0  Mississauga    01/18/2017   01/30/2017  https://canlii.ca/t/gxq6n
# 1  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6r
# 2  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6s
# 3  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6t
# 4  Mississauga    01/10/2017   02/03/2017  https://canlii.ca/t/h3w7b

# %%
check_df(silver_data)
# Out:
# Df Size: 672 rows, 13 columns
# ------------------------------
#
# Checking for null values...
# -------------------------
# raw_file_text    0
# raw_file_name    0
# full_cleaned     0
# metadata         0
# content          0
# case_citation    0
# file_number      0
# language         0
# year             0
# ltb_location     1
# decision_date    0
# hearing_date     1
# url              0
# dtype: int64
#
# Checking data types...
# -------------------------
# raw_file_text: str
# raw_file_name: str
# full_cleaned: list
# metadata: list
# content: list
# case_citation: str
# file_number: str
# language: str
# year: str
# ltb_location: str
# decision_date: str
# hearing_date: str
# url: str

# %%
silver_data.loc[2, 'metadata']
silver_data.loc[150, 'content'][-15:]
# Out:
# ['6. If the unit is not vacated on or before February 28, 2018, then starting March 1, 2018, the Landlords may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '7. Upon receipt of this order, the Court Enforcement Office (Sheriff) is directed to give vacant possession of the unit to the Landlords, on or after March 1, 2018.',
#  '8. If, on or before February 28, 2018, the Tenant pays the amount of $4,719.00** to the Landlords or to the Board in trust, this order for eviction will be void.',
#  'This means that the tenancy would not be terminated and the Tenant could remain in the unit.',
#  'If this payment is not made in full and on time, the Landlords may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '9. The Tenant may make a motion to the Board under subsection 74(11) of the Act to set aside this order if they pay the amount required under that subsection on or after March 1, 2018 but before the Sheriff gives vacant possession to the Landlords.',
#  'The Tenant is only entitled to make this motion once during the period of the tenancy agreement with the Landlords.',
#  '10. If the Tenant complies with paragraph 8 of the order then;',
#  '11. The Landlord’s application for eviction of the Tenant is denied on the condition that: a) The Tenant shall refrain from accumulating garbage in and around the property for a period of 12 months commencing February 2, 2018 and up to and including February 1, 2019.',
#  '12. If the Tenant fails to comply with the conditions set out in paragraph 11 above, then, within 30 days of the breach, the Landlord may apply under section 78 of the Residential Tenancies Act, 2006 (the ‘Act’) for an order terminating the tenancy and evicting the Tenant.',
#  'The Landlord must make the application within 30 days of a breach of a condition set out in paragraph 11 of this order.',
#  '13. The Tenant shall also pay to the Landlord $175.00 or the cost of filing the L2 application.',
#  'February 2, 2018 Date Issued Lorraine Mathers Member, Landlord and Tenant Board Schedule 1 SUMMARY OF CALCULATIONS File Number: SWL-08112-17 A.',
#  'Amount the Tenant must pay if the tenancy is terminated: Reasons for amount owing Period Amount Arrears: (up to the termination date in the Notice of Termination) September 1, 2017 to September 16, 2017 $394.52 Plus compensation: (from the day after the termination date in the Notice to the date of the order) September 17, 2017 to February 2, 2018 $3,427.74 Amount owing to the Landlords on the order date:(total of previous boxes) $3,822.26 Additional costs the Tenant must pay to the Landlords: $175.00 Plus daily compensation owing for each day of occupation starting February 3, 2018: $24.66 (per day) Total the Tenant must pay the Landlords if the tenancy is terminated: $3,997.26, + $24.66 per day starting February 3, 2018 B.',
#  'Amount the Tenant must pay to void the eviction order and continue the tenancy: Reasons for amount owing Period Amount Arrears: September 1, 2017 to February 28, 2018 $4,544.00 Additional costs the Tenant must pay to the Landlords: $175.00 Total the Tenant must pay to continue the tenancy: On or before February 28, 2018 $4,719.00']

# %% [markdown]
# # Adjudicating Member
# - Typically in format like:
#     ```[...,
#     'Date',
#     'Issued Gerald',
#     'Taylor',
#     'Member,'
#     ...]```
# - This seems to be formatted pretty consistently but not sure if it may present in different ways

# %%
silver_data.loc[2, 'metadata']
silver_data.loc[130, 'content'][-15:]
# Out:
# ['8. Upon receipt of this order, the Court Enforcement Office (Sheriff) is directed to give vacant possession of the unit to the Landlord, on or after September 8, 2018.',
#  '9. If the Tenant wishes to void this order and continue the tenancy, the Tenant must pay to the Landlord or to the Board in trust: i) $7,675.00 if the payment is made on or before August 31, 2018, or ii) $10,175.00 if the payment is made on or before September 7, 2018**.',
#  'If the Tenant does not make full payment in accordance with this paragraph and by the appropriate deadline, then the Landlord may file this order with the Court Enforcement Office (Sheriff) so that the eviction may be enforced.',
#  '10. The Tenant may make a motion to the Board under subsection 74(11) of the Act to set aside this order if they pay the amount required under that subsection on or after September 8, 2018 but before the Sheriff gives vacant possession to the Landlord.',
#  'The Tenant is only entitled to make this motion once during the period of the tenancy agreement with the Landlord.',
#  'August 27, 2018 Date Issued Roderick Flynn Member, Landlord and Tenant Board Toronto South-RO 79 St.',
#  'Clair Avenue East, Suite 212, 2nd Floor Toronto ON M4T1M6 If you have any questions about this order, call 416-645-8080 or toll free at 1-888-332-3234.',
#  'In accordance with section 81 of the Act, the part of this order relating to the eviction expires on March 8, 2019 if the order has not been filed on or before this date with the Court Enforcement Office (Sheriff) that has territorial jurisdiction where the rental unit is located.',
#  '* Refer to section A on the attached Summary of Calculations.',
#  '** Refer to section B on the attached Summary of Calculations.',
#  'Schedule 1 SUMMARY OF CALCULATIONS File Number: HOL-02995-18 A.',
#  'Amount the Tenant must pay if the tenancy is terminated: Reasons for amount owing Period Amount Arrears: (up to the termination date in the Notice of Termination) June 1, 2018 to June 17, 2018 $1,397.26 Plus compensation: (from the day after the termination date in the Notice to the date of the order) June 18, 2018 to August 27, 2018 $5,835.49 Less the rent deposit: -$2,500.00 Less the interest owing on the rent deposit: October 7, 2017 to June 17, 2018 -$31.32 Amount owing to the Landlord on the order date:(total of previous boxes) $4,701.43 Additional costs the Tenant must pay to the Landlord: $175.00 Plus daily compensation owing for each day of occupation starting August 28, 2018: $82.19 (per day) Total the Tenant must pay the Landlord if the tenancy is terminated: $4,876.43, + $82.19 per day starting August 28, 2018 B.',
#  'Amount the Tenant must pay to void the eviction order and continue the tenancy: 1.',
#  'If the payment is made on or before August 31, 2018: Reasons for amount owing Period Amount Arrears: June 1, 2018 to August 31, 2018 $7,500.00 Additional costs the Tenant must pay to the Landlord: $175.00 Total the Tenant must pay to continue the tenancy: On or before August 31, 2018 $7,675.00 2.',
#  'If the payment is made after August 31, 2018 but on or before September 7, 2018: Reasons for amount owing Period Amount Arrears: June 1, 2018 to September 30, 2018 $10,000.00 Additional costs the Tenant must pay to the Landlord: $175.00 Total the Tenant must pay to continue the tenancy: On or before September 7, 2018 $10,175.00']

# %%
import re

def get_adj_member(list_of_strings: list):
    text = " ".join(list_of_strings)
    pattern = r"Date Issued(.*?)Member"
    matches = re.findall(pattern, text, re.DOTALL)
    # extracted_text = [match.strip() for match in matches]
    extracted_text = list(set(match.strip() for match in matches))
    if len(extracted_text) > 0:
        return ", ".join(extracted_text) # returns a list of matches and sometimes there's more than one match so we just take the first one -- there are never two
    elif "date issued" in text.lower():
        DI_inds = find_all_positions(text.lower(), "date issued")
        for DI_ind in DI_inds:
            DI_substr = text[DI_ind - 50 : DI_ind + 50].lower()
            if len(DI_substr.split("date issued")) != 2:
                # should only contain 2
                pass

            DI_sent = DI_substr.split("date issued")[1].strip()
            if ", " in DI_sent: # there should be a comma be just in case, it doesn't hurt to have this (and this to try the "hear" method after iterating over all of these if none work)
                DI_sent = DI_sent.split(", ")[0]

            if "member" in DI_sent:
                DI_sent = DI_sent.replace("member", "")

            return DI_sent.title().strip()

test = silver_data.loc[453, 'content']#[-15:]

get_adj_member(test)
# Out:
# 'Nancy Morris'

# %% [markdown]
# ### Updating CSV with Adjudicating Member

# %%
# import time
# import numpy as np
# from collections import deque

start_time = time.time()

# Initialize a deque to store the latest 100 iteration times
time_deque = deque(maxlen = 500)

for index, row in enumerate(silver_data.itertuples()):

    # Save the start time of this iteration
    iteration_start_time = time.time()

    try:
        silver_data.at[row.Index, 'adjudicating_member'] = get_adj_member(silver_data.loc[row.Index, 'content']).replace("Vice Chair", "").replace("Vice-Chair", "").strip()
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

    # Save the end time of this iteration and push it into the deque
    iteration_end_time = time.time()
    time_deque.append(iteration_end_time - iteration_start_time)

    # progress tracker
    average_time_per_row = np.mean(time_deque)
    rows_left = len(silver_data) - (index + 1)
    estimated_time_left = rows_left * average_time_per_row

    print("Files processed: ", index + 1, "of", len(silver_data),
          "Estimated time remaining: ", time.strftime('%H:%M:%S', time.gmtime(estimated_time_left)), end = '\r')

silver_data.head()
# Out:
# 'NoneType' object has no attribute 'replace' with file at Df row:  459
# 'NoneType' object has no attribute 'replace' with file at Df row:  649
# 'NoneType' object has no attribute 'replace' with file at Df row:  657
# Files processed:  672 of 672 Estimated time remaining:  00:00:00
#                                        raw_file_text     raw_file_name  \
# 0  Metadata:\nDate:\t2017-01-18\nFile number:\t\n...  CEL-62600-16.txt
# 1  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-62852-16.txt
# 2  Metadata:\nDate:\t2017-01-09\nFile number:\t\n...  CEL-63024-16.txt
# 3  Metadata:\nDate:\t2017-01-20\nFile number:\t\n...  CEL-63056-16.txt
# 4  Metadata:\nDate:\t2017-02-03\nFile number:\t\n...  CEL-63193-16.txt
#
#                                         full_cleaned  \
# 0  [Metadata:, Date: 2017-01-18, File number:, CE...
# 1  [Metadata:, Date: 2017-01-09, File number:, CE...
# 2  [Metadata:, Date: 2017-01-09, File number:, CE...
# 3  [Metadata:, Date: 2017-01-20, File number:, CE...
# 4  [Metadata:, Date: 2017-02-03, File number:, CE...
#
#                                             metadata  \
# 0  [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1  [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2  [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3  [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4  [Date: 2017-02-03, File number:, CEL-63193-16,...
#
#                                              content  \
# 0  [Arrears Worksheet File Number: CEL-62600-16 T...
# 1  [Arrears Worksheet File Number: CEL-62852-16 T...
# 2  [Arrears Worksheet File Number: CEL-63024-16 T...
# 3  [Arrears Worksheet File Number: CEL-63056-16 T...
# 4  [Arrears Worksheet File Number: CEL-63193-16 T...
#
#                                    case_citation   file_number language  year  \
# 0   CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)  CEL-62600-16  English  2016
# 1   CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)  CEL-62852-16  English  2016
# 2   CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)  CEL-63024-16  English  2016
# 3   CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)  CEL-63056-16  English  2016
# 4  CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)  CEL-63193-16  English  2016
#
#   ltb_location decision_date hearing_date                        url  \
# 0  Mississauga    01/18/2017   01/30/2017  https://canlii.ca/t/gxq6n
# 1  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6r
# 2  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6s
# 3  Mississauga    01/09/2017   01/09/2017  https://canlii.ca/t/gxq6t
# 4  Mississauga    01/10/2017   02/03/2017  https://canlii.ca/t/h3w7b
#
#   adjudicating_member
# 0       Avril Cardoso
# 1    Tiisetso Russell
# 2    Tiisetso Russell
# 3    Tiisetso Russell
# 4       Karen Wallace

# %%
check_df(silver_data)
# Out:
# Df Size: 672 rows, 14 columns
# ------------------------------
#
# Checking for null values...
# -------------------------
# raw_file_text          0
# raw_file_name          0
# full_cleaned           0
# metadata               0
# content                0
# case_citation          0
# file_number            0
# language               0
# year                   0
# ltb_location           1
# decision_date          0
# hearing_date           1
# url                    0
# adjudicating_member    3
# dtype: int64
#
# Checking data types...
# -------------------------
# raw_file_text: str
# raw_file_name: str
# full_cleaned: list
# metadata: list
# content: list
# case_citation: str
# file_number: str
# language: str
# year: str
# ltb_location: str
# decision_date: str
# hearing_date: str
# url: str
# adjudicating_member: str

# %%
nulls_adj = get_nulls(silver_data, 'adjudicating_member', return_index = False)
nulls_inds = nulls_adj.index.tolist()
nulls_adj
# Out:
#                                          raw_file_text  \
# 459  Metadata:\nDate:\t2018-12-17\nFile number:\t\n...
# 649  Metadata:\nDate:\t2018-11-06\nFile number:\t\n...
# 657  Metadata:\nDate:\t2018-10-09\nFile number:\t\n...
#
#                raw_file_name  \
# 459         TNL-05489-18.txt
# 649  TSL-97498-18-RV2-AM.txt
# 657      TSL-98384-18-AM.txt
#
#                                           full_cleaned  \
# 459  [Metadata:, Date: 2018-12-17, File number:, 65...
# 649  [Metadata:, Date: 2018-11-06, File number:, TS...
# 657  [Metadata:, Date: 2018-10-09, File number:, TS...
#
#                                               metadata  \
# 459  [Date: 2018-12-17, File number:, 659/18;, TNL-...
# 649  [Date: 2018-11-06, File number:, TSL-97498-18-...
# 657  [Date: 2018-10-09, File number:, TSL-98384-18,...
#
#                                                content  \
# 459  [CITATION: Capreit 2 Limited Partnership v., R...
# 649  [Amended Order Order under Sections 21.1 and 2...
# 657  [Amended Order Order under Section 69 Resident...
#
#                                          case_citation          file_number  \
# 459                                                Cit  659/18;TNL-05489-18
# 649  TSL-97498-18-RV2-AM (Re), 2018 CanLII 141664 (...  TSL-97498-18-RV2-AM
# 657  TSL-98384-18-AM (Re), 2018 CanLII 120875 (ON LTB)         TSL-98384-18
#
#     language  year ltb_location decision_date hearing_date  \
# 459  English   206          NaN    07/13/2018          NaN
# 649  English  2018      Toronto    12/06/2018   11/01/2018
# 657  English  2018      Toronto    10/12/2018   09/24/2018
#
#                            url adjudicating_member
# 459  https://canlii.ca/t/hwpvq                 NaN
# 649  https://canlii.ca/t/j0fjl                 NaN
# 657  https://canlii.ca/t/hwmcl                 NaN

# %%
evaluate(silver_data, gold_data, "adjudicating_member", return_inaccurate = True, metric = "jaro_winkler").head(60)
# Out:
#    silver_adjudicating_member gold_adjudicating_member
# 0               Avril Cardoso            avril cardoso
# 1            Tiisetso Russell         tiisetso russell
# 2            Tiisetso Russell         tiisetso russell
# 3            Tiisetso Russell         tiisetso russell
# 4               Karen Wallace            karen wallace
# 5               Avril Cardoso            avril cardoso
# 6               Avril Cardoso            avril cardoso
# 7               Karen Wallace            karen wallace
# 8               Avril Cardoso            avril cardoso
# 9               Karen Wallace            karen wallace
# 10           Tiisetso Russell         tiisetso russell
# 11              Karen Wallace            karen wallace
# 12              Avril Cardoso            avril cardoso
# 13                 Ruth Carey               ruth carey
# 14           Tiisetso Russell         tiisetso russell
# 15              Avril Cardoso            avril cardoso
# 16              Karen Wallace            karen wallace
# 17           Lisa Del Vecchio         lisa del vecchio
# 18                 Alex Brkic               alex brkic
# 19             Solange Losier           solange losier
# 20           Tiisetso Russell         tiisetso russell
# 21              Avril Cardoso            avril cardoso
# 22              Lynn Mitchell            lynn mitchell
# 23              Lynn Mitchell            lynn mitchell
# 24                  Harry Cho                harry cho
# 25                 Alex Brkic               alex brkic
# 26                 Alex Brkic               alex brkic
# 27                 Alex Brkic               alex brkic
# 28              Avril Cardoso            avril cardoso
# 29              Karen Wallace            karen wallace
# 30           Tiisetso Russell         tiisetso russell
# 31           Lisa Del Vecchio         lisa del vecchio
# 32              Avril Cardoso            avril cardoso
# 33              Karen Wallace         sandra macchione
# 34              Avril Cardoso            avril cardoso
# 35                 Alex Brkic               alex brkic
# 36           Lisa Del Vecchio         lisa del vecchio
# 37                 Alex Brkic               alex brkic
# 38                 Alex Brkic               alex brkic
# 39                 Alex Brkic               alex brkic
# 40                 Alex Brkic               alex brkic
# 41             David Mungovan           david mungovan
# 42              Avril Cardoso            avril cardoso
# 43              Avril Cardoso            avril cardoso
# 44              Avril Cardoso            avril cardoso
# 45              Karen Wallace            karen wallace
# 46           Tiisetso Russell         tiisetso russell
# 47              Avril Cardoso            avril cardoso
# 48              Avril Cardoso            avril cardoso
# 49                 Alex Brkic            avril cardoso
# 50              Karen Wallace            karen wallace
# 51             David Mungovan           david mungovan
# 52              Avril Cardoso            avril cardoso
# 53              Karen Wallace            karen wallace
# 54             David Mungovan           david mungovan
# 55           Lisa Del Vecchio         lisa del vecchio
# 56              Avril Cardoso            avril cardoso
# 57              Avril Cardoso            avril cardoso
# 58                 Alex Brkic               alex brkic
# 59              Karen Wallace            karen wallace

# %%
silver_data.file_number.value_counts()
# Out:
# TEL-95255-18-AM    2
# HOL-03461-18-RV    2
# TEL-91060-18-RV    2
# TNL-04964-18       1
# TNL-04214-18       1
#                   ..
# TEL-61064-15-RV    1
# TEL-75185-16       1
# TEL-75630-16       1
# TEL-75637-16       1
# TSL-99965-18       1
# Name: file_number, Length: 669, dtype: int64

# %%
silver_data
# Out:
#                                          raw_file_text        raw_file_name  \
# 0    Metadata:\nDate:\t2017-01-18\nFile number:\t\n...     CEL-62600-16.txt
# 1    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-62852-16.txt
# 2    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-63024-16.txt
# 3    Metadata:\nDate:\t2017-01-20\nFile number:\t\n...     CEL-63056-16.txt
# 4    Metadata:\nDate:\t2017-02-03\nFile number:\t\n...     CEL-63193-16.txt
# ..                                                 ...                  ...
# 667  Metadata:\nDate:\t2018-12-13\nFile number:\t\n...  TSL-98918-18-RV.txt
# 668  Metadata:\nDate:\t2018-11-23\nFile number:\t\n...     TSL-99691-18.txt
# 669  Metadata:\nDate:\t2018-11-29\nFile number:\t\n...     TSL-99824-18.txt
# 670  Metadata:\nDate:\t2018-12-12\nFile number:\t\n...     TSL-99900-18.txt
# 671  Metadata:\nDate:\t2018-11-20\nFile number:\t\n...     TSL-99965-18.txt
#
#                                           full_cleaned  \
# 0    [Metadata:, Date: 2017-01-18, File number:, CE...
# 1    [Metadata:, Date: 2017-01-09, File number:, CE...
# 2    [Metadata:, Date: 2017-01-09, File number:, CE...
# 3    [Metadata:, Date: 2017-01-20, File number:, CE...
# 4    [Metadata:, Date: 2017-02-03, File number:, CE...
# ..                                                 ...
# 667  [Metadata:, Date: 2018-12-13, File number:, TS...
# 668  [Metadata:, Date: 2018-11-23, File number:, TS...
# 669  [Metadata:, Date: 2018-11-29, File number:, TS...
# 670  [Metadata:, Date: 2018-12-12, File number:, TS...
# 671  [Metadata:, Date: 2018-11-20, File number:, TS...
#
#                                               metadata  \
# 0    [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1    [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2    [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3    [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4    [Date: 2017-02-03, File number:, CEL-63193-16,...
# ..                                                 ...
# 667  [Date: 2018-12-13, File number:, TSL-98918-18-...
# 668  [Date: 2018-11-23, File number:, TSL-99691-18,...
# 669  [Date: 2018-11-29, File number:, TSL-99824-18,...
# 670  [Date: 2018-12-12, File number:, TSL-99900-18,...
# 671  [Date: 2018-11-20, File number:, TSL-99965-18,...
#
#                                                content  \
# 0    [Arrears Worksheet File Number: CEL-62600-16 T...
# 1    [Arrears Worksheet File Number: CEL-62852-16 T...
# 2    [Arrears Worksheet File Number: CEL-63024-16 T...
# 3    [Arrears Worksheet File Number: CEL-63056-16 T...
# 4    [Arrears Worksheet File Number: CEL-63193-16 T...
# ..                                                 ...
# 667  [Order under Section 21.2 of the Statutory Pow...
# 668  [Order under Section 69 Residential Tenancies ...
# 669  [Order under Section 69 Residential Tenancies ...
# 670  [Order under Section 69 Residential Tenancies ...
# 671  [Order under Section 69 Residential Tenancies ...
#
#                                          case_citation      file_number  \
# 0         CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)     CEL-62600-16
# 1         CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)     CEL-62852-16
# 2         CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)     CEL-63024-16
# 3         CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)     CEL-63056-16
# 4        CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)     CEL-63193-16
# ..                                                 ...              ...
# 667  TSL-98918-18-RV (Re), 2018 CanLII 141679 (ON LTB)  TSL-98918-18-RV
# 668     TSL-99691-18 (Re), 2018 CanLII 141675 (ON LTB)     TSL-99691-18
# 669     TSL-99824-18 (Re), 2018 CanLII 141673 (ON LTB)     TSL-99824-18
# 670     TSL-99900-18 (Re), 2018 CanLII 140403 (ON LTB)     TSL-99900-18
# 671     TSL-99965-18 (Re), 2018 CanLII 141672 (ON LTB)     TSL-99965-18
#
#     language  year ltb_location decision_date hearing_date  \
# 0    English  2016  Mississauga    01/18/2017   01/30/2017
# 1    English  2016  Mississauga    01/09/2017   01/09/2017
# 2    English  2016  Mississauga    01/09/2017   01/09/2017
# 3    English  2016  Mississauga    01/09/2017   01/09/2017
# 4    English  2016  Mississauga    01/10/2017   02/03/2017
# ..       ...   ...          ...           ...          ...
# 667  English  2018      Toronto    11/08/2018   12/13/2018
# 668  English  2018      Toronto    11/23/2018   11/23/2018
# 669  English  2018      Toronto    11/29/2018   12/11/2018
# 670  English  2018      Toronto    12/12/2018   12/12/2018
# 671  English  2018      Toronto    11/20/2018   11/20/2018
#
#                            url adjudicating_member
# 0    https://canlii.ca/t/gxq6n       Avril Cardoso
# 1    https://canlii.ca/t/gxq6r    Tiisetso Russell
# 2    https://canlii.ca/t/gxq6s    Tiisetso Russell
# 3    https://canlii.ca/t/gxq6t    Tiisetso Russell
# 4    https://canlii.ca/t/h3w7b       Karen Wallace
# ..                         ...                 ...
# 667  https://canlii.ca/t/j0fjv     Nancy Henderson
# 668  https://canlii.ca/t/j0fk1           David Lee
# 669  https://canlii.ca/t/j0fk2          Renée Lang
# 670  https://canlii.ca/t/hzzb6      David Mungovan
# 671  https://canlii.ca/t/j0fk5           David Lee
#
# [672 rows x 14 columns]

# %%
# silver_data.to_csv(f"pproc_{len(silver_data)}_files_1.csv", index = False)

# %% [markdown]
# # Rule-Based Case OutCome Extraction

# %%
# gold_data.columns # looking for case outcome column name
len(gold_data['case_outcome'].unique()) # only 47 unique outcomes across 679 cases - that means it can probably be summarized effectively
gold_data['case_outcome'].unique()
# Out:
# array(['No relief', 'Relief', 'Conditional Order'], dtype=object)

# %%
reclassified_outcomes = {
    'no_relief': [
        'No relief',
        'No relief, but arrears calculated based on the lawful monthly rent ($1400), despite the landlord claiming it to be $1500',
        'Tenants already vacated rental unit. Tenants pay full amount owed.',
        'Ordered payment of arrears, no eviction',
        'Conditional order to preserve tenancy',
        'Conditional relief',
        'Payment of damages (not a rent dispute)',
        'Request to review is denied',
        'No relief; rent abatement due to maintenance repairs',
        'Application dismissed',
        'Relief not to evict. Tenant has paid all arrears and there was a material error on the landlord\'s part.',
        'Notice of termination was found to be invalid so Landlord requested consent of Board to withdraw application of non-payment of rent which was granted.',
        'Application Dismissed',
        'No eviction granted, payment plan merely involved paying rent on time',
        'Tenant ordered to pay adjusted arrears cost',
        'Order to pay rent on time',
        'Tenant must pay arrears with EI lump-sum check or else he will be evicted',
        'landlord was not seeking eviction but seeking to terminate tenancy because of persistent late payment; relief granted (not terminating tenancy) if tenant can pay in time and in full for the next 11 months',
        'No relief, because tenant can pay off the arrears with the help of social assistance',
        'No relief because tenants could pay the balance',
        'No relief because tenant can pay the balance'
    ],
    'no_payment': [
        'Payment plan',
        'Eviction refused; Tenant pays arrears only',
        'Payment and eviction',
        'Eviction order set aside',
        'Pay on time order'
    ],
    'other': [
        'Postponement of eviction',
        'Order under review reversed in part to correct serious error',
        'Extended termination date',
        'Other: Standard eviction order but if arrears are paid, tenant can stay as long as all future payments for 1 year are paid on time (subject to s. 78)',
        'Postponement of eviction but conditioned on the fact that all rent is paid on time for one year period',
        'Probation',
        'Relief from eviction subject to conditions',
        'Conditional order',
        'Conditional Order',
        'Landlord\'s Application for Eviction was dismissed',
        'Abatement of Rent',
        'Voiding of order',
        'Tenant forced out, landlord wants space. All rent was paid.',
        'Tenant shall pay rent on time from February 2020 - January 2021. Additionally, tenant must pay application cost + $20 NSF charges incurred by the Landlord',
        'Full relief',
        'Interim order'
    ]
}

for new_class, old_classes in reclassified_outcomes.items():
    for old_class in old_classes:
        gold_data.loc[gold_data['case_outcome'] == old_class, 'new_case_outcome'] = new_class

gold_data['new_case_outcome'].value_counts()
# Out:
# no_relief    430
# other          7
# Name: new_case_outcome, dtype: int64

# %%
def find_outcome_context(text: str, proximity: int):
    full_text = text
    positions = []
    start = 0
    while True:
        index = text.find("ordered", start)
        if index == -1:
            break
        positions.append(index)
        start = index + 1
    # return positions

    if len(positions) == 0:
        return None
    elif len(positions) == 1:
        surrounding_text = text[positions[0] - (proximity // 4) : positions[0] + proximity]#.lower()
        surrounding_sents = surrounding_text.split(". ")
        # print(surrounding_sents)
        ordered_ind = [i for i, sent in enumerate(surrounding_sents) if "ordered" in sent][0]
        # print(surrounding_sents[ordered_ind:])
        # print(surrounding_sents)
        relevant_text = "".join(full_text[full_text.find(surrounding_sents[ordered_ind]):])
        return_text_end = relevant_text.lower().find("date issued")
        print(return_text_end)

        return " ".join(relevant_text.split(". "))
        return relevant_text
    else: # if there is more than one instance of the keyword, return the one that is closest to "find"
        print("POOOPOOOO")
        # closest = min(positions, key = lambda x: abs(x - text.find("find")))
        # surrounding_text = text[closest - (proximity // 4) : closest + proximity]#.lower()
        # return surrounding_text

row = 5
test_str = " ".join(silver_data.loc[row, "content"])
print(find_outcome_context(test_str, 1000))
# Out:
# POOOPOOOO
# None

# %%
for row in silver_data.index:
    # row = 5
    # print(gold_data.loc[row, "case_outcome"])
    test_str = "\n".join(silver_data.loc[row, "content"])
    keyword = "consider"

    # print(find_outcome_context(test_str, 500))
    # keyword = "ordered"
    finds_found = find_all_positions(test_str.lower(), keyword)
    proximity = 500
    if len(finds_found) == 0:
        # print(finds_found)
        # print(f"{row}: No 'ordered'")
        if len(find_all_positions(test_str.lower(), "find")) == 0:
            print(f"{row}: No '{keyword}'")
        # for found_position in finds_found:
        #     surrounding_text = test_str[found_position - (proximity // 2) : found_position + proximity].lower()
        #     # if "it is ordered that" in surrounding_text:
        #         # print (surrounding_text.strip())

# silver_data.loc[46, "content"]
# Out:
# 219: No 'consider'
# 255: No 'consider'
# 340: No 'consider'
# 344: No 'consider'
# 388: No 'consider'
# 389: No 'consider'
# 422: No 'consider'
# 448: No 'consider'
# 467: No 'consider'
# 489: No 'consider'
# 608: No 'consider'
# 662: No 'consider'
# 664: No 'consider'
# 665: No 'consider'

# %%
silver_data.loc[6, "content"]
# Out:
# ["Arrears Worksheet File Number: CEL-63931-17 Time period for Arrears Owing From: December 1, 2016 to December 16, 2016 (From the commencement of arrears to the termination date in the notice, or the end of the rental period if the tenancy is not being terminated.) Part 1 - Calculations of Arrears Owing (A) Rent Period (monthly, weekly, etc.) (B) Rent Charged (C) Lawful Rent (if issue raised) (D) Lower of (B) and (C) (E) Rent Paid (F) Amount Owing (D-E) 01/12/2016 - 16/12/2016 $526.03 $526.03 $500.00 $26.03 **Part Month ** To calculate the Rent for part of a month, use the following formula for columns (B), (C) and (D): Monthly Rent X 12 X # Days 365 (F) Total Rent Owing $26.03 (G1) Arrears Owing $26.03 [From (F)] (G2) Arrears Claimed $1,670.00 (G3) Include whichever is less when Calculation Total Arrears Owing $26.03 (I) Total Amount Owing $26.03 Part II - Calculation of Compensation (Use this part if the tenancy is being terminated) (J) (i) Lump Sum Compensation Start Date December 17, 2016 (Day after termination date in notice) (ii) Lump Sum Compensation End Date March 8, 2017 (Date of order) (K) Daily Compensation (Monthly Rent X 12) $32.88 365 (L) Number of Days for Lump Sum Compensation 82 days (# days between start date and order date - inclusive) (M) Total Lump Sum Compensation $2,696.16 [(K) X (L)] = Part IV - Total Amount Owing (Q) Terminating the tenancy [I+M-P] $2,722.19 Order under Section 69 Residential Tenancies Act, 2006 File Number: CEL-63931-17 In the matter of: Between: M S Landlord and M F Tenant M S (the 'Landlord') applied for an order to terminate the tenancy and evict M F (the 'Tenant') because the Tenant did not pay the rent that the Tenant owes (L1 Application).",
#  'The Landlord also applied for an order to terminate the tenancy and evict the Tenant because the Tenant, another occupant of the rental unit or someone the Tenant permitted in the residential complex has wilfully or negligently caused undue damage to the premises; because the Tenant, another occupant of the rental unit or someone the Tenant permitted in the residential complex has substantially interfered with the reasonable enjoyment or lawful right, privilege or interest of the Landlord or another tenant; and because the Landlord requires possession of the rental unit for the purpose of residential occupation.',
#  'The Landlord has also applied for an order requiring the Tenant to compensate the Landlord for the damage.',
#  'The Landlord also claimed compensation for each day the Tenant remained in the unit after the termination date (L2 Application).',
#  'This application was heard in Port Elgin on February 28, 2017.',
#  'The Landlord and the Tenant attended the hearing.',
#  'The Tenant was assisted by a friend, A.',
#  'P.',
#  'Determinations and Reasons: Regarding L1 Application (rent arrears) 1.',
#  'The monthly rent is $1,000.00.',
#  '2. The Tenant has not paid the total rent the Tenant was required to pay for the period from December 1, 2016 to February 28, 2017.',
#  'Because of the arrears, the Landlord served a Notice of Termination effective December 16, 2016.',
#  'Regarding L2 Application (N5 Notice) 3.',
#  'On December 2, 2016, the Landlord served the Tenant with an N5 Notice in accordance with sub sections 64(1) and 62(1) of the Residential Tenancies Act, 2006 (the ‘Act’).',
#  'The N5 Notice has a termination date of December 22, 2016 and alleges that: a) The Tenant is harassing and substantially interfering with the reasonable enjoyment of the Landlord through numerous phone calls, voicemails and unannounced visits to the Landlord’s home; b) The Tenant damaged the front room ceiling, walls and floor due to “brewing kegs of homemade wine” which exploded all over the room.',
#  'The Landlord claimed $320.00 to repair the alleged property damage.',
#  '4. The N5 Notice sets out the dates, times and specific allegations against the Tenant.',
#  '5. Because this is a first N5 Notice, the Tenant has an opportunity to void the notice in accordance with sub section 64(3) of the Act by correcting the identified problems within seven days of the date the notice was served.',
#  'In this case, the seven day period begins the day following service of the N5 Notice, from December 3, 2016 to December 9, 2016.',
#  'The Landlord confirmed that the N5 Notice was not voided and that the Tenant did not pay $320.00 for the alleged damages claimed in the N5 notice.',
#  '6. The Landlord testified: a) The Tenant is her biological father; b) The Tenant was brewing wine in the front room of the home and the red wine “exploded” and stained the ceiling, walls and floor.',
#  'The Landlord submitted photos of the front room; c) The Landlord gave notice to enter to replace the battery for the furnace and the Tenant denied entry and police were called; d) The Tenant is not co-operative and verbally abusive such that the Landlord went to the police.',
#  'He withheld rent in return for personal favours, forced his way in and used the Landlord’s cottage, requested help in paying bills and constantly calls the Landlord with unreasonable requests.',
#  'He does not respect boundaries.',
#  'He caused a “scene” when the roof was re-shingled and damaged the workers’ truck.',
#  'When he comes to her house, he throws temper tantrums.',
#  '7. The Tenant admitted responsibility for the red wine stains on the ceiling of the front room.',
#  'He testified that the container of red wine was corked and the cork popped causing wine to spray on the ceiling.',
#  'He said he paid his grandson to clean the stains.',
#  'Wilful or negligent damage – front room 8.',
#  'Section 62(1) of the Act states that a landlord may give a tenant notice of termination if the tenant wilfully or negligently causes undue damage to the rental unit.',
#  '9. I am not satisfied that the conduct of the Tenant was negligent or that the wine stains on the ceiling is representative of undue damage.',
#  '10. “Conduct is negligent if there is a risk of damage which a reasonable person would take reasonable precautions against” (Bolton v.',
#  'Stone [1951] A.C.',
#  '850).',
#  'Further, “If a person reasonably, albeit mistakenly, believes that there is no risk then the conduct is not negligent” (Beutler v.',
#  'Beutler [1983] O.J.',
#  'No.',
#  '505 at para.',
#  '148).',
#  '11. Wilful conduct means with intent or deliberate.',
#  '12. The Tenant placed a cork in the container of wine which shows that he took reasonable precautions against spillage.',
#  'The fact that the cork popped and caused the wine to spray the ceiling and spill onto the floor was not reasonably foreseeable.',
#  'As a consequence, the Tenant’s conduct was not negligent.',
#  'The facts do not demonstrate any intent by the Tenant to spray wine on the ceiling and floor.',
#  '13. I am not satisfied that the stains on the ceiling and the faint spot on the floor are representative of undue damage.',
#  'Undue suggests some damage is acceptable.',
#  'The stains on the ceiling and floor are akin to normal wear and tear.',
#  '14. As the Landlord has not met the test under section 62(1), this claim is dismissed.',
#  'In any event, the Landlord did not substantiate the remedy claimed of $320.00 with a quote or other similar evidence.',
#  '15. The Landlord’s claim regarding damage caused by hooks on a ceiling beam is dismissed because the Landlord did not explain how the hooks caused undue damage.',
#  'Substantial interference',
#  '16. Asking someone to read your mail to them, show them how to pay bills, smoke fish for them and not respecting boundaries indicates that the Landlord’s allegations are representative of personal issues between members of a family rather than those between a Landlord and Tenant.',
#  'This does not represent substantial interference of reasonable enjoyment of the residential complex by the Landlord or harassment and this claim is dismissed.',
#  '17. The issues claimed by the Landlord that occurred at her home did not occur at the residential complex and therefore do not substantially interfere with her reasonable enjoyment of the residential complex.',
#  'This claim is dismissed.',
#  '18. The Landlord’s claim that the Tenant damaged the roofing worker’s truck is dismissed.',
#  'The Landlord did not provide sufficient details regarding this claim or any supporting evidence regarding this alleged damage.',
#  '19. The Landlord did not provide sufficient details such as dates and times, to support a finding of harassment or substantial interference regarding her complaints that the Tenant demanded she come over to change a light bulb, wanted a new kitchen tap and made numerous calls regarding the thermostat “flashing”.',
#  'These claims are dismissed.',
#  '20. The Landlord failed to substantiate her claim regarding denial of entry to the rental unit to replace the battery for the furnace on December 1, 2016.',
#  'A notice to enter was not provided and no details regarding police involvement were submitted.',
#  'In any event, a single event is not indicative of substantial interference.',
#  'This claim is dismissed.',
#  '21. The Landlord led evidence that the Tenant failed to maintain the unit in a state of ordinary cleanliness.',
#  'However, these issues were not raised in the N5 Notices which formed the basis of the L2 Application and are not relevant to a finding of a substantial interference or wilful or negligent damage.',
#  'Regarding L2 Application (N12 Notice – Landlord own use)',
#  '22. The Landlord served the Tenant with an N12 notice of termination effective January 31, 2017 claiming the Landlord intended to move into the rental unit.',
#  '23. The Landlord testified that she intends to move into the rental unit to use the unit for her home based business and for other business purposes.',
#  '24. Subsection 48(1) of the Act states: A landlord may, by notice, terminate a tenancy if the landlord in good faith requires possession of the rental unit for the purpose of residential occupation by, (a) the landlord; (b) the landlord’s spouse; (c) a child or parent of the landlord or the landlord’s spouse; or (d) a person who provides or will provide care services to the landlord, the landlord’s spouse, or a child or parent of the landlord or the landlord’s spouse, if the person receiving the care services resides or will reside in the building, related group of buildings, mobile home park or land lease community in which the rental unit is located.',
#  '25. The term “residential occupation” is not defined in the Act.',
#  'However, the Court has stated in various decisions that residential occupation is generally understood to mean the property will be used as the person’s main residence and requires more than occasional or temporary use of the unit.',
#  '26. Based on the Landlord’s evidence, the test of residential occupation has not been met.',
#  'It is clear from the Landlord’s own evidence that the property will not be the main residence of the Landlord and she intends to use the unit for business purposes, not residential occupation.',
#  'This claim is dismissed.',
#  'Relief from eviction (L1 Application)',
#  '27. The Tenant testified that his source of income is retirement benefits of about $1,800 per month.',
#  'He has a hearing impairment and relies on oxygen for breathing purposes.',
#  'If evicted, he requested until April to find another home.',
#  '28. The Landlord said that she will lose her house if the arrears are not paid because she is using credit to pay bills and the mortgage.',
#  '29. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would not be unfair to grant relief from eviction subject to the conditions set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act.',
#  '30. In granting relief, I am taking into account the submissions of the Landlord and her financial obligations, and balancing that against the Tenant’s disclosed circumstances.',
#  'Therefore the relief from eviction is subject to conditions set out in this order which, if not met, would allow the Landlord to apply to the Board, without further notice to the Tenant, for an order terminating the tenancy and evicting the Tenant pursuant to section 78 of the Act.',
#  'It is ordered that: L2 Application 1.',
#  'The Landlord’s L2 application is dismissed.',
#  'L1 Application (rent owing) 2.',
#  'The Tenant shall pay the Landlord $3,500.00 which represents the amount of rent arrears owing up to March 31, 2017.',
#  '3. The Tenant shall also pay the Landlord $190.00 for the cost of filing the application.',
#  '4. The Tenant shall pay the Landlord the full amount owing of $3,690.00, and the additional rent that comes due, as follows: a.',
#  'On or before April 1, 2017 April rent b.',
#  'On or before April 30, 2017 $3,690.00 (arrears and filing fee) 5.',
#  'If the Tenant fails to make any one of the payments ordered in paragraph 4, in full and on time, the Landlord may apply under section 78 of the Act, without notice to the Tenant for an order terminating the tenancy and evicting the Tenant.',
#  'The Landlord must make this application no later than 30 days after the Tenant’s failure to make a payment.',
#  'March 13, 2017 Date Issued Avril Cardoso Member, Landlord and Tenant Board Central-RO 3 Robert Speck Pkwy, 5th Floor Mississauga ON L4Z2G5']

# %% [markdown]
# It seems like it's usually around the text "...find that...." and "....it is ordered that...."
#
# - could get all text within x left and right of the text that this is near, and train a model to classify it according to a certain number of class options (just like metadata extraction)

# %% [markdown]
# # Testing Metadata Extraction Model
# - report to be written in based on data from WANDB
# - wandb report link: https://wandb.ai/kmaurinjones/huggingface/reports/FLAN-T5-Metadata-Extractor-Model--Vmlldzo0NDk4MDEx

# %% [markdown]
# ### General Cleaning functions (used with model)

# %%
import re

def general_cleaning(raw_file_str: str):
    # gets rid of tabs, non-breaking spaces, leading/trailing whitespace, removes empty lines, and "\xa0"
    generally_cleaned_str = [line.replace("\t", " ").replace("\xa0", "").strip() for line in raw_file_str.split('\n') if line.strip() != '']
    return generally_cleaned_str

def remove_whitespace_and_underscores(string):
    # Remove consecutive whitespace
    string = re.sub(r'\s+', ' ', string)

    # Remove more than three consecutive underscores
    string = re.sub(r'_+', '', string)

    return string.strip()

# %%
import transformers
# from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# %%
model_name = "metadata_extractor_flant5_small"

# folder where the model files are located -- unzip before running
model_dir = f"/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/models/metadata_extractor/{model_name}"

tokenizer = AutoTokenizer.from_pretrained(model_dir)
model = AutoModelForSeq2SeqLM.from_pretrained(model_dir)

# %%
def extract_metadata_t5(raw_case_file_text: str, model = model, tokenizer = tokenizer):
    # do general case file cleaning
    clean_file_list = general_cleaning(raw_case_file_text)
    clean_file_str = " ".join([line for line in clean_file_list if ("metadata:" or "content:") not in line.lower()])
    print(clean_file_str)
    
    # run model on cleaned case file text
    inputs = ["extract metadata boundary:" + clean_file_str] # PREFIX = "extract metadata boundary:"

    # print("INPUT:", inputs)
    inputs = tokenizer(inputs, max_length = 256, truncation = True, return_tensors = "pt")
    output = model.generate(**inputs, num_beams = 8, do_sample = True, min_length = 1, max_length = 128)
    decoded_output = tokenizer.batch_decode(output, skip_special_tokens = True)[0]
    # print("OUTPUT:", decoded_output)

    return decoded_output
    
    # return metadata and content as lists

# %%
row_num = 3
# print(silver_data.loc[row_num, 'raw_file_text'])
[line for line in general_cleaning(silver_data.loc[row_num, 'raw_file_text']) if ("metadata:" or "content:") not in line.lower()]
# Out:
# ['Date: 2017-01-20',
#  'File number:',
#  'CEL-63056-16',
#  'CEL-63056-16',
#  'Citation: CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB), <https://canlii.ca/t/gxq6t>, retrieved on 2023-05-16 https://canlii.ca/t/gxq6t',
#  'Content:',
#  'Arrears Worksheet',
#  'File Number: CEL-63056-16',
#  'Time',
#  'period for Arrears Owing From: November 1, 2016 to November 24,',
#  '2016',
#  '(From',
#  'the commencement of arrears to the termination date in the notice, or the end',
#  'of the rental period if the tenancy is not being terminated.)',
#  'Part',
#  '1',
#  '- Calculations of Arrears Owing',
#  '(A)',
#  'Rent Period (monthly, weekly, etc.)',
#  '(B)',
#  'Rent Charged',
#  '(C)',
#  'Lawful Rent',
#  '(if issue raised)',
#  '(D)',
#  'Lower of',
#  '(B) and (C)',
#  '(E)',
#  'Rent Paid',
#  '(F)',
#  'Amount Owing',
#  '(D-E)',
#  '01/11/2016',
#  '- 24/11/2016',
#  '$895.54',
#  '$895.54',
#  '$0.15',
#  '$895.39',
#  '**Part',
#  'Month',
#  '**',
#  'To calculate the Rent for part of a month, use the',
#  'following formula for columns (B), (C) and (D):',
#  'Monthly Rent X 12 X # Days',
#  '365',
#  '(F)',
#  'Total Rent Owing',
#  '$895.39',
#  '(G1)  Arrears',
#  'Owing                                  $895.39',
#  '[From',
#  '(F)]',
#  '(G2)  Arrears',
#  'Claimed                                $1,304.82',
#  '(G3)  Include',
#  'whichever is less when Calculation Total Arrears Owing        $895.39',
#  '(H1)  Payment',
#  'to Landlord                               $700.00',
#  '(I)   Total',
#  'Amount Owing                               $195.39',
#  'Part',
#  'II',
#  '- Calculation of Compensation',
#  '(Use',
#  'this part if the tenancy is being terminated)',
#  '(J)',
#  '(i)  Lump Sum Compensation Start Date               November',
#  '25, 2016',
#  '(Day',
#  'after termination date in notice)',
#  '(ii)  Lump Sum Compensation End Date                January',
#  '9, 2017',
#  '(Date',
#  'of order)',
#  '(K)',
#  'Daily Compensation (Monthly Rent X 12)                     $37.31',
#  '365',
#  '(L)   Number',
#  'of Days for Lump Sum Compensation                   46',
#  'days',
#  '(#',
#  'days between start date and order date - inclusive)',
#  '(M)   Total',
#  'Lump Sum Compensation                        $1,716.26',
#  '[(K)',
#  'X (L)] =',
#  'Part',
#  'III',
#  '- Rent Deposit and Interest Owing',
#  '(Use',
#  'this part if you are terminating the tenancy)',
#  '(N)   Rent',
#  'Deposit                                  $1,084.74',
#  '(O1)  Interest',
#  'Owing on Rent Deposit',
#  'For',
#  'period from: 01/01/2016 to 24/11/2016',
#  '(i) Annual',
#  'Amount (S) X 2%    =                    $21.69',
#  '(ii) Daily',
#  'Amount (i) / 365      =                     0.0594',
#  '(iii) Interest',
#  'Owing (ii) X 329 (# of days) =                        $19.54',
#  '(O2)  Total',
#  'amount of interest owing on rent deposit',
#  '[(O1)]                                 $19.54',
#  '(P)   Rent',
#  'Deposit + Interest',
#  '[(N)',
#  '+ (O2)] =                                   $1,104.28',
#  'Part',
#  'IV',
#  '- Total Amount Owing',
#  '(Q)   Terminating',
#  'the tenancy [I+M-P]                          $807.37',
#  'Order under Section 69',
#  'Residential Tenancies Act, 2006',
#  'File Number: CEL-63056-16',
#  'In',
#  'the matter of:',
#  'Between:',
#  'T',
#  'I',
#  'Landlord',
#  'and',
#  'O',
#  'S',
#  'Tenant',
#  'T',
#  "I (the 'Landlord') applied for an order to terminate the tenancy and evict O S",
#  "and R S (the 'Tenants') because the Tenants did not pay the rent that the",
#  'Tenants owe.',
#  'This',
#  'application was heard in Mississauga on January 4, 2017.',
#  "The Landlord's Legal Representative, B R and the Tenant, O S (OS)",
#  'and the Tenant’s brother S S attended the hearing.',
#  'The',
#  'Tenant stated that Tenant R S has been living in Ottawa for the last year and a',
#  'half and is no longer in possession of the unit. The Landlord stated they were',
#  'not aware of that fact. Since the Tenant’s uncontested evidence indicates that R',
#  'S was not in possession of the unit at the time of the application, he was',
#  'removed as a party.',
#  'Determinations:',
#  '1.  The',
#  'Tenant has not paid the total rent they were required to pay for the period',
#  'from November 1, 2016 to January 31, 2017. Because of the arrears, the',
#  'Landlord served a Notice of Termination effective November 24, 2016.',
#  '2.  The',
#  'Landlord collected a rent deposit of $1,084.74 from the Tenant and this deposit',
#  'is still being held by the Landlord.',
#  '3.  Interest',
#  'on the rent deposit is owing to the Tenant for the period from January 1, 2016',
#  'to November 24, 2016.',
#  '4.  The',
#  'Tenant paid $700.00 after the application was filed.',
#  '5.  The',
#  'Tenant OW was seeking a little extra time to pay and the Landlord did not',
#  'strenuously object to extending the void date to January 20, 2016.',
#  '6.  I',
#  'have considered all of the disclosed circumstances in accordance with',
#  "subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and",
#  'find that it would be unfair to grant a brief relief from eviction pursuant to',
#  'subsection 83(1) of the Act.',
#  'It is ordered that:',
#  '1.  Unless',
#  'the Tenant voids the order as set out below, the tenancy between the Landlord',
#  'and the Tenants is terminated. The Tenant must move out of the rental unit on',
#  'or before January 20, 2017.',
#  '2.  The',
#  'Tenant shall pay to the Landlord $807.37*, which represents the amount of rent',
#  'owing and compensation up to January 9, 2017, less the rent deposit and',
#  'interest the Landlord owes on the rent deposit.',
#  '3.  The',
#  'Tenant shall also pay to the Landlord $37.31 per day for compensation for the',
#  'use of the unit starting January 10, 2017 to the date they move out of the',
#  'unit.',
#  '4.  The',
#  'Tenant shall also pay to the Landlord $170.00 for the cost of filing the',
#  'application.',
#  '5.  If',
#  'the Tenant does not pay the Landlord the full amount owing* on or before',
#  'January 20, 2017, the Tenant will start to owe interest. This will be simple',
#  'interest calculated from January 21, 2017 at 2.00% annually on the balance',
#  'outstanding.',
#  '6.  If',
#  'the unit is not vacated on or before January 20, 2017, then starting January',
#  '21, 2017, the Landlord may file this order with the Court Enforcement Office',
#  '(Sheriff) so that the eviction may be enforced.',
#  '7.  Upon',
#  'receipt of this order, the Court Enforcement Office (Sheriff) is directed to give',
#  'vacant possession of the unit to the Landlord, on or after January 21, 2017.',
#  '8.  If,',
#  'on or before January 20, 2017, the Tenant pays the amount of $2,874.76** to the',
#  'Landlord or to the Board in trust, this order for eviction will be void. This',
#  'means that the tenancy would not be terminated and the Tenant could remain in',
#  'the unit. If this payment is not made in full and on time, the Landlord may',
#  'file this order with the Court Enforcement Office (Sheriff) so that the',
#  'eviction may be enforced.',
#  '9.  The',
#  'Tenant may make a motion to the Board under subsection 74(11) of the Act to set',
#  'aside this order if they pay the amount required under that subsection on or',
#  'after January 21, 2017 but before the Sheriff gives vacant possession to the',
#  'Landlord. The Tenant is only entitled to make this motion once during the',
#  'period of the tenancy agreement with the Landlord.',
#  'January 9, 2017                     _______________________',
#  'Date Issued                        Tiisetso',
#  'Russell',
#  'Member,',
#  'Landlord and Tenant Board',
#  'Central-RO',
#  '3 Robert Speck Pkwy, 5th Floor',
#  'Mississauga ON L4Z2G5',
#  'If you have any questions about this order, call 416-645-8080 or',
#  'toll free at 1-888-332-3234.',
#  'In accordance with section 81 of the Act, the part of this order',
#  'relating to the eviction expires on July 21, 2017 if the order has not been',
#  'filed on or before this date with the Court Enforcement Office (Sheriff) that',
#  'has territorial jurisdiction where the rental unit is located.',
#  '*    Refer to section A on the attached Summary of',
#  'Calculations.',
#  '**   Refer to section B on the attached Summary of',
#  'Calculations.',
#  'Schedule 1',
#  'SUMMARY OF CALCULATIONS',
#  'File Number: CEL-63056-16',
#  'A.   Amount the Tenant must pay if the tenancy is terminated:',
#  'Reasons for amount owing',
#  'Period',
#  'Amount',
#  'Arrears: (up to the termination date in',
#  'the Notice of Termination)',
#  'November 1, 2016 to November 24, 2016',
#  '$895.39',
#  'Less the amount the Tenant paid to the Landlord',
#  '-$700.00',
#  'Plus compensation: (from the day after the',
#  'termination date in the Notice to the date of the order)',
#  'November 25, 2016 to January 9, 2017',
#  '$1,716.26',
#  'Less the rent deposit:',
#  '-$1,084.74',
#  'Less the interest owing on the rent deposit:',
#  'January 1, 2016 to November 24, 2016',
#  '-$19.54',
#  'Amount owing to the Landlord on the order date:(total of previous boxes)',
#  '$807.37',
#  'Additional costs the Tenant must pay to the Landlord:',
#  '$170.00',
#  'Plus daily compensation owing for each day of occupation',
#  'starting January 10, 2017:',
#  '$37.31 (per',
#  'day)',
#  'Total the Tenant must pay the Landlord if the tenancy is',
#  'terminated:',
#  '$977.37, + $37.31 per day starting January 10, 2017',
#  'B. Amount the Tenant must pay to void the eviction order and',
#  'continue the tenancy:',
#  'Reasons for amount owing',
#  'Period',
#  'Amount',
#  'Arrears:',
#  'November 1, 2016 to January 31, 2017',
#  '$3,404.76',
#  'Less the amount the Tenant paid to the Landlord',
#  '-$700.00',
#  'Additional costs the Tenant must pay to the Landlord:',
#  '$170.00',
#  'Total the Tenant must pay to continue the tenancy:',
#  'On or before January 20, 2017',
#  '$2,874.76']

# %%
test_case_file = silver_data.loc[row_num, 'raw_file_text']
print(f"GOAL: {' '.join(silver_data.loc[row_num, 'metadata'])}")
print()
print(f"MODEL: {extract_metadata_t5(raw_case_file_text = test_case_file)}")
# Out:
# GOAL: Date: 2017-01-20 File number: CEL-63056-16 CEL-63056-16 Citation: CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB), <https://canlii.ca/t/gxq6t>, retrieved on 2023-05-16 https://canlii.ca/t/gxq6t
#
# Date: 2017-01-20 File number: CEL-63056-16 CEL-63056-16 Citation: CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB), <https://canlii.ca/t/gxq6t>, retrieved on 2023-05-16 https://canlii.ca/t/gxq6t Content: Arrears Worksheet File Number: CEL-63056-16 Time period for Arrears Owing From: November 1, 2016 to November 24, 2016 (From the commencement of arrears to the termination date in the notice, or the end of the rental period if the tenancy is not being terminated.) Part 1 - Calculations of Arrears Owing (A) Rent Period (monthly, weekly, etc.) (B) Rent Charged (C) Lawful Rent (if issue raised) (D) Lower of (B) and (C) (E) Rent Paid (F) Amount Owing (D-E) 01/11/2016 - 24/11/2016 $895.54 $895.54 $0.15 $895.39 **Part Month ** To calculate the Rent for part of a month, use the following formula for columns (B), (C) and (D): Monthly Rent X 12 X # Days 365 (F) Total Rent Owing $895.39 (G1)  Arrears Owing                                  $895.39 [From (F)] (G2)  Arrears Claimed                                $1,304.82 (G3)  Include whichever is less when Calculation Total Arrears Owing        $895.39 (H1)  Payment to Landlord                               $700.00 (I)   Total Amount Owing                               $195.39 Part II - Calculation of Compensation (Use this part if the tenancy is being terminated) (J) (i)  Lump Sum Compensation Start Date               November 25, 2016 (Day after termination date in notice) (ii)  Lump Sum Compensation End Date                January 9, 2017 (Date of order) (K) Daily Compensation (Monthly Rent X 12)                     $37.31 365 (L)   Number of Days for Lump Sum Compensation                   46 days (# days between start date and order date - inclusive) (M)   Total Lump Sum Compensation                        $1,716.26 [(K) X (L)] = Part III - Rent Deposit and Interest Owing (Use this part if you are terminating the tenancy) (N)   Rent Deposit                                  $1,084.74 (O1)  Interest Owing on Rent Deposit For period from: 01/01/2016 to 24/11/2016 (i) Annual Amount (S) X 2%    =                    $21.69 (ii) Daily Amount (i) / 365      =                     0.0594 (iii) Interest Owing (ii) X 329 (# of days) =                        $19.54 (O2)  Total amount of interest owing on rent deposit [(O1)]                                 $19.54 (P)   Rent Deposit + Interest [(N) + (O2)] =                                   $1,104.28 Part IV - Total Amount Owing (Q)   Terminating the tenancy [I+M-P]                          $807.37 Order under Section 69 Residential Tenancies Act, 2006 File Number: CEL-63056-16 In the matter of: Between: T I Landlord and O S Tenant T I (the 'Landlord') applied for an order to terminate the tenancy and evict O S and R S (the 'Tenants') because the Tenants did not pay the rent that the Tenants owe. This application was heard in Mississauga on January 4, 2017. The Landlord's Legal Representative, B R and the Tenant, O S (OS) and the Tenant’s brother S S attended the hearing. The Tenant stated that Tenant R S has been living in Ottawa for the last year and a half and is no longer in possession of the unit. The Landlord stated they were not aware of that fact. Since the Tenant’s uncontested evidence indicates that R S was not in possession of the unit at the time of the application, he was removed as a party. Determinations: 1.  The Tenant has not paid the total rent they were required to pay for the period from November 1, 2016 to January 31, 2017. Because of the arrears, the Landlord served a Notice of Termination effective November 24, 2016. 2.  The Landlord collected a rent deposit of $1,084.74 from the Tenant and this deposit is still being held by the Landlord. 3.  Interest on the rent deposit is owing to the Tenant for the period from January 1, 2016 to November 24, 2016. 4.  The Tenant paid $700.00 after the application was filed. 5.  The Tenant OW was seeking a little extra time to pay and the Landlord did not strenuously object to extending the v ...
# MODEL: Date: 2017-01-20 File number: CEL-63056-16 CEL-63056-16 Citation: CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB), https://canlii.ca/t/gxq6t>, retrieved on 2023-05-16 https://canlii.ca/t/gxq6t

# %% [markdown]
# ## case outcome extraction 2

# %%
silver_data = silver_data.drop(columns='outcome_text')
silver_data
# Out:
#                                          raw_file_text        raw_file_name  \
# 0    Metadata:\nDate:\t2017-01-18\nFile number:\t\n...     CEL-62600-16.txt
# 1    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-62852-16.txt
# 2    Metadata:\nDate:\t2017-01-09\nFile number:\t\n...     CEL-63024-16.txt
# 3    Metadata:\nDate:\t2017-01-20\nFile number:\t\n...     CEL-63056-16.txt
# 4    Metadata:\nDate:\t2017-02-03\nFile number:\t\n...     CEL-63193-16.txt
# ..                                                 ...                  ...
# 667  Metadata:\nDate:\t2018-12-13\nFile number:\t\n...  TSL-98918-18-RV.txt
# 668  Metadata:\nDate:\t2018-11-23\nFile number:\t\n...     TSL-99691-18.txt
# 669  Metadata:\nDate:\t2018-11-29\nFile number:\t\n...     TSL-99824-18.txt
# 670  Metadata:\nDate:\t2018-12-12\nFile number:\t\n...     TSL-99900-18.txt
# 671  Metadata:\nDate:\t2018-11-20\nFile number:\t\n...     TSL-99965-18.txt
#
#                                           full_cleaned  \
# 0    [Metadata:, Date: 2017-01-18, File number:, CE...
# 1    [Metadata:, Date: 2017-01-09, File number:, CE...
# 2    [Metadata:, Date: 2017-01-09, File number:, CE...
# 3    [Metadata:, Date: 2017-01-20, File number:, CE...
# 4    [Metadata:, Date: 2017-02-03, File number:, CE...
# ..                                                 ...
# 667  [Metadata:, Date: 2018-12-13, File number:, TS...
# 668  [Metadata:, Date: 2018-11-23, File number:, TS...
# 669  [Metadata:, Date: 2018-11-29, File number:, TS...
# 670  [Metadata:, Date: 2018-12-12, File number:, TS...
# 671  [Metadata:, Date: 2018-11-20, File number:, TS...
#
#                                               metadata  \
# 0    [Date: 2017-01-18, File number:, CEL-62600-16,...
# 1    [Date: 2017-01-09, File number:, CEL-62852-16,...
# 2    [Date: 2017-01-09, File number:, CEL-63024-16,...
# 3    [Date: 2017-01-20, File number:, CEL-63056-16,...
# 4    [Date: 2017-02-03, File number:, CEL-63193-16,...
# ..                                                 ...
# 667  [Date: 2018-12-13, File number:, TSL-98918-18-...
# 668  [Date: 2018-11-23, File number:, TSL-99691-18,...
# 669  [Date: 2018-11-29, File number:, TSL-99824-18,...
# 670  [Date: 2018-12-12, File number:, TSL-99900-18,...
# 671  [Date: 2018-11-20, File number:, TSL-99965-18,...
#
#                                                content  \
# 0    [Arrears Worksheet File Number: CEL-62600-16 T...
# 1    [Arrears Worksheet File Number: CEL-62852-16 T...
# 2    [Arrears Worksheet File Number: CEL-63024-16 T...
# 3    [Arrears Worksheet File Number: CEL-63056-16 T...
# 4    [Arrears Worksheet File Number: CEL-63193-16 T...
# ..                                                 ...
# 667  [Order under Section 21.2 of the Statutory Pow...
# 668  [Order under Section 69 Residential Tenancies ...
# 669  [Order under Section 69 Residential Tenancies ...
# 670  [Order under Section 69 Residential Tenancies ...
# 671  [Order under Section 69 Residential Tenancies ...
#
#                                          case_citation      file_number  \
# 0         CEL-62600-16 (Re), 2017 CanLII 9545 (ON LTB)     CEL-62600-16
# 1         CEL-62852-16 (Re), 2017 CanLII 9535 (ON LTB)     CEL-62852-16
# 2         CEL-63024-16 (Re), 2017 CanLII 9543 (ON LTB)     CEL-63024-16
# 3         CEL-63056-16 (Re), 2017 CanLII 9537 (ON LTB)     CEL-63056-16
# 4        CEL-63193-16 (Re), 2017 CanLII 30828 (ON LTB)     CEL-63193-16
# ..                                                 ...              ...
# 667  TSL-98918-18-RV (Re), 2018 CanLII 141679 (ON LTB)  TSL-98918-18-RV
# 668     TSL-99691-18 (Re), 2018 CanLII 141675 (ON LTB)     TSL-99691-18
# 669     TSL-99824-18 (Re), 2018 CanLII 141673 (ON LTB)     TSL-99824-18
# 670     TSL-99900-18 (Re), 2018 CanLII 140403 (ON LTB)     TSL-99900-18
# 671     TSL-99965-18 (Re), 2018 CanLII 141672 (ON LTB)     TSL-99965-18
#
#     language  year ltb_location decision_date hearing_date  \
# 0    English  2016  Mississauga    01/18/2017   01/30/2017
# 1    English  2016  Mississauga    01/09/2017   01/09/2017
# 2    English  2016  Mississauga    01/09/2017   01/09/2017
# 3    English  2016  Mississauga    01/09/2017   01/09/2017
# 4    English  2016  Mississauga    01/10/2017   02/03/2017
# ..       ...   ...          ...           ...          ...
# 667  English  2018      Toronto    11/08/2018   12/13/2018
# 668  English  2018      Toronto    11/23/2018   11/23/2018
# 669  English  2018      Toronto    11/29/2018   12/11/2018
# 670  English  2018      Toronto    12/12/2018   12/12/2018
# 671  English  2018      Toronto    11/20/2018   11/20/2018
#
#                            url adjudicating_member new_case_outcome
# 0    https://canlii.ca/t/gxq6n       Avril Cardoso        No relief
# 1    https://canlii.ca/t/gxq6r    Tiisetso Russell           Relief
# 2    https://canlii.ca/t/gxq6s    Tiisetso Russell           Relief
# 3    https://canlii.ca/t/gxq6t    Tiisetso Russell        No relief
# 4    https://canlii.ca/t/h3w7b       Karen Wallace        No relief
# ..                         ...                 ...              ...
# 667  https://canlii.ca/t/j0fjv     Nancy Henderson        No relief
# 668  https://canlii.ca/t/j0fk1           David Lee        No relief
# 669  https://canlii.ca/t/j0fk2          Renée Lang        No relief
# 670  https://canlii.ca/t/hzzb6      David Mungovan        No relief
# 671  https://canlii.ca/t/j0fk5           David Lee        No relief
#
# [672 rows x 15 columns]

# %%
# import pandas as pd
# gold_df = pd.read_csv('data/allard_labels_with_text.csv')
# gold_df.head()
# silver_data['new_case_outcome'] = gold_df['case_outcome']
# silver_data.head()
silver_data.to_csv('data/outcome_extraction_testing.csv', index = False)

# %%
# row = 0

keyword = "accordance with"
# keyword = "based on"
# keyword = "considered"

found_total = 0

for row in silver_data.index:
    gold_outcome = silver_data.loc[row, 'new_case_outcome']
    # print(gold_outcome)

    case_text = " ".join(silver_data.loc[row, 'content'])
    # if case_text.find(keyword) != -1:
    if keyword in case_text.lower():
        found_total += 1

print(f"{found_total / len(silver_data.index)}; {found_total} / {len(silver_data.index)}")
# Out:
# 0.9419642857142857; 633 / 672

# %%
start_boundary = "accordance with"
end_boundary = "ordered that"

# start_boundary = "based on"
# start_boundary = "considered"

found_total = 0
# row = 500

for row in silver_data.index:
    gold_outcome = silver_data.loc[row, 'new_case_outcome']

    # print(silver_data.loc[row, 'url'])
    # print(gold_outcome)
    # print()

    case_text = " ".join(silver_data.loc[row, 'content'])
    start_bound_positions = find_all_positions(case_text.lower(), start_boundary)

    proximity = 1000 # number of characters after the start boundary to look for the end boundary

    for pos in start_bound_positions:
        near_text = case_text[pos - 100 : pos + proximity]
        near_text = ". ".join(near_text.split(". ")[1:])
        end_bounds_finds = find_all_positions(near_text, end_boundary)
        # if len(end_bounds_finds) > 1:
        #     print("MORE THAN ONE END BOUNDARY")
        if end_boundary in near_text:
            found_total += 1
            subset2 = near_text[:near_text.find(end_boundary)]
            outcome = ". ".join(subset2.split(". ")[:-1])
            # print("YES END BOUNDARY")
            # print(f"{len(outcome.split(' '))} words")
            # print()
            outcome = re.sub(r'^\d+\.\s*', '', outcome).strip() # removes "16. " from start of string
            silver_data.loc[row, 'outcome_text'] = outcome
            # print(outcome)
            break
        else:
            silver_data.loc[row, 'outcome_text'] = "NEED OTHER METHOD"
            continue
            # break
        # print(near_text)
    
found_total / len(silver_data.index)
# Out:
# 0.7247023809523809

# %%
start_boundary = "accordance with"
end_boundary = "ordered that"

found_total = 0

max_outcome_len = 0
total_outcome_len = 0

for row in silver_data.index:
    gold_outcome = silver_data.loc[row, 'new_case_outcome']

    case_text = " ".join(silver_data.loc[row, 'content'])
    start_bound_positions = find_all_positions(case_text.lower(), start_boundary)

    proximity = 1000 # number of characters after the start boundary to look for the end boundary

    for pos in start_bound_positions:
        near_text = case_text[pos - 100 : pos + int(proximity)]
        near_text = ". ".join(near_text.split(". ")[1:])

        # Use a while loop to increase the proximity if end_boundary is not found in near_text
        while end_boundary not in near_text and proximity < len(case_text) - pos:
            proximity *= 1.5
            near_text = case_text[pos - 100 : pos + int(proximity)]
            near_text = ". ".join(near_text.split(". ")[1:])

        end_bounds_finds = find_all_positions(near_text, end_boundary)

        if end_boundary in near_text:
            found_total += 1
            subset2 = near_text[:near_text.find(end_boundary)]
            outcome = ". ".join(subset2.split(". ")[:-1])
            outcome = re.sub(r'^\d+\.\s*', '', outcome).strip() # removes "16. " from start of string
            silver_data.loc[row, 'outcome_text'] = outcome
            outcome_len = len(outcome.split(' '))
            if outcome_len > max_outcome_len:
                max_outcome_len = outcome_len
            total_outcome_len += outcome_len
            break
        else:
            silver_data.loc[row, 'outcome_text'] = "NEED OTHER METHOD"

    # Reset the proximity back to the original value for the next row
    proximity = 1000

print(found_total / len(silver_data.index))
print(max_outcome_len)
print(total_outcome_len / len(silver_data.index))
# Out:
# 0.9211309523809523
# 4235
# 221.10267857142858

# %%
silver_data['outcome_text'].tolist()
# Out:
# ["The N5 Notice has a termination date of November 17, 2016 and alleges that the conduct of the Tenant substantially interfered with the reasonable enjoyment of the residential complex and the Tenant has wilfully or negligently damaged the rental unit or residential complex. 5. The N5 Notice sets out the dates, times and specific allegations against the Tenant. 6. Because this is a first N5 Notice, the Tenant has an opportunity to void the notice in accordance with section 64(3) of the Act by correcting the identified problems within seven days of the date the notice was served. In this case, the seven day period begins the day following service of the N5 Notice, from October 28th to November 3rd, 2016. The Landlord's Legal Representative confirmed that the first N5 Notice was not voided because the conduct has not stopped since the notice was served and the Tenant has not paid $500.00 required to replace or replace the damaged property. Window screens 7. The Tenant negligently caused undue damage to the rental unit and residential complex by damaging the screens on two windows and the patio door. The photos submitted into evidence support a finding of negligence because the screens were badly torn which did not occur from usual wear and tear. The Landlord is entitled to the cost claimed of $300.00 to repair the window screens. The Landlord provided an invoice to support this claim. Conduct issues 8. The conduct of the Tenant substantially interfered with the reasonable enjoyment of the Landlord and other tenant for the following reasons: 9. The City of Mississauga issued a Notice of Contravention in April 2016 regarding debris located on the property because of the Tenant’s failure to properly store her garbage. A copy of the Notice was submitted; 10. The City of Mississauga also informed the Landlord about a noise complaint because the Tenant’s dog was barking for hours while left unattended in the backyard disturbing the neighbours. The Landlord submitted a copy of this letter into evidence; 11. Based on the testimony of the Landlord, the Tenant parks in the adjacent neighbour’s driveway and the Landlord receives complaints from the neighbour; 12. On August 29th the Tenant left her dog unattended in a common area of the residential complex and the Landlord was unable to show the unit to prospective renters. The Tenant fails to respond to the Landlord’s requests to control her dog. The Landlord submitted a text message sent to the Tenant regarding this issue on October 27th; 13. The Tenant installed a lock on the gate to the shared backyard and refused to remove the lock. The Landlord submitted a text message sent to the Tenant on August 23rd requesting a key to which the Tenant responded with foul language to leave her alone. Consequently the Landlord changed the lock and provided the tenants with keys; 14. The Tenant changed the lock on the entry door to the basement unit without the Landlord’s consent. Section 35 of the Act specifies that a tenant shall not alter the locking system on a door giving entry to a rental unit or residential complex without the consent of the Landlord. The Landlord is entitled to her costs for installing a new lock of $200.00 which she supported with an invoice; 15. The Tenant leaves her clothes in the laundry room and leaves kitty litter under the sink such that it interferes with the use of the laundry room by the other tenant. The Landlord has received numerous complaints from the other tenant regarding inability to do laundry and despite the creation of a laundry schedule, the issue continues. Photos of the laundry room and text messages reporting the issues were submitted into evidence; 16. The Tenant plays loud music and makes excessive noise at late hours. These incidents occurred on November 21st, 25th and 29th and continue on a regular basis. The Tenant yells and swears at the Landlord and the downstairs tenant. In support of this testimony, the Landlord submitted text messages. The do ...
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act. I am allowing the payment plan suggested by the Tenant and the prejudice to the Landlord is minimized by the provisions of section 78. of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act. I am allowing the payment plan suggested by the Tenant and the prejudice to the Landlord is minimized by the provisions of section 78. of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant a brief relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. This tenancy just commenced in July 2016 and the Tenant has been unable or unwilling to pay the rent on time and/or in full each month since then. A prior L1 rent arrears order was issued in October 2016. The Tenant was able to pay the amount owing by the date in the order which voided the order. However, immediately after that, he fell into arrears for the November rent. 19. The Tenant stated he was injured in an accident shortly after he moved in and was off work. However, he is now back at work and hopes to pay the amount owing by the end of February. 20. The Tenant still has the option set out below in paragraph 9 of the order if he wants to preserve this tenancy",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the conditions set out in this order pursuant to subsections 83(1)(a) and 204(1) of the Act. I have extended the termination date to February 28th to allow the Tenants time to seek out other resources which may be available to them to void the arrears portion of the order. This extension is only two weeks longer than requested by the Landlord's Legal Representative to reduce the prejudice to the Landlord. The Tenants are required to void the rent arrears portion of the order to benefit from a condition to pay the rent on time with a section 78 provision where the Landlord can file for eviction if a payment of rent is late without notice to the Tenants",
#  'On December 2, 2016, the Landlord served the Tenant with an N5 Notice in accordance with sub sections 64(1) and 62(1) of the Residential Tenancies Act, 2006 (the ‘Act’). The N5 Notice has a termination date of December 22, 2016 and alleges that: a) The Tenant is harassing and substantially interfering with the reasonable enjoyment of the Landlord through numerous phone calls, voicemails and unannounced visits to the Landlord’s home; b) The Tenant damaged the front room ceiling, walls and floor due to “brewing kegs of homemade wine” which exploded all over the room. The Landlord claimed $320.00 to repair the alleged property damage. 4. The N5 Notice sets out the dates, times and specific allegations against the Tenant. 5. Because this is a first N5 Notice, the Tenant has an opportunity to void the notice in accordance with sub section 64(3) of the Act by correcting the identified problems within seven days of the date the notice was served. In this case, the seven day period begins the day following service of the N5 Notice, from December 3, 2016 to December 9, 2016. The Landlord confirmed that the N5 Notice was not voided and that the Tenant did not pay $320.00 for the alleged damages claimed in the N5 notice. 6. The Landlord testified: a) The Tenant is her biological father; b) The Tenant was brewing wine in the front room of the home and the red wine “exploded” and stained the ceiling, walls and floor. The Landlord submitted photos of the front room; c) The Landlord gave notice to enter to replace the battery for the furnace and the Tenant denied entry and police were called; d) The Tenant is not co-operative and verbally abusive such that the Landlord went to the police. He withheld rent in return for personal favours, forced his way in and used the Landlord’s cottage, requested help in paying bills and constantly calls the Landlord with unreasonable requests. He does not respect boundaries. He caused a “scene” when the roof was re-shingled and damaged the workers’ truck. When he comes to her house, he throws temper tantrums. 7. The Tenant admitted responsibility for the red wine stains on the ceiling of the front room. He testified that the container of red wine was corked and the cork popped causing wine to spray on the ceiling. He said he paid his grandson to clean the stains. Wilful or negligent damage – front room 8. Section 62(1) of the Act states that a landlord may give a tenant notice of termination if the tenant wilfully or negligently causes undue damage to the rental unit. 9. I am not satisfied that the conduct of the Tenant was negligent or that the wine stains on the ceiling is representative of undue damage. 10. “Conduct is negligent if there is a risk of damage which a reasonable person would take reasonable precautions against” (Bolton v. Stone [1951] A.C. 850). Further, “If a person reasonably, albeit mistakenly, believes that there is no risk then the conduct is not negligent” (Beutler v. Beutler [1983] O.J. No. 505 at para. 148). 11. Wilful conduct means with intent or deliberate. 12. The Tenant placed a cork in the container of wine which shows that he took reasonable precautions against spillage. The fact that the cork popped and caused the wine to spray the ceiling and spill onto the floor was not reasonably foreseeable. As a consequence, the Tenant’s conduct was not negligent. The facts do not demonstrate any intent by the Tenant to spray wine on the ceiling and floor. 13. I am not satisfied that the stains on the ceiling and the faint spot on the floor are representative of undue damage. Undue suggests some damage is acceptable. The stains on the ceiling and floor are akin to normal wear and tear. 14. As the Landlord has not met the test under section 62(1), this claim is dismissed. In any event, the Landlord did not substantiate the remedy claimed of $320.00 with a quote or other similar evidence. 15. The Landlord’s claim regarding damage caused by hooks on a ceiling beam is dismissed because the ...
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. 24. The Tenant stated that she is looking for a new place to move and wants to move as soon as possible but, as of the hearing date, she was not certain of an exact date she will be moving. She is currently unable to make any payment towards the three months of rent that are owing. As a result, termination of the tenancy is ordered",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until April 20, 2017 pursuant to subsection 83(1)(b) of the Act. This is 12 days longer than the 11 day standard order requested by the Landlord, a short delay to reduce the prejudice to the Landlord",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. No rent has been paid since February. There are over seven months of rent owing to the Landlord. The Tenant did not comply with the interim order. The interim order was meant to ensure that the amount of rent arrears ordered in March did not increase when April rent came due. Yet, that was not accomplished. No amount was paid to the Board. The Tenant said he is currently unable to pay the April rent",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act, because two more month’s rent will come due for April and May 2017",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until May 31, 2017 pursuant to subsection 83(1)(b) of the Act. The Tenant has made plans to vacate the rental unit on May 31st and there is a last month's rent deposit to cover the May rent",
#  nan,
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. THE APPLICATION BASED ON THE TENANT’S NOTICE TO TERMINATE 7. The Landlord’s application for an order terminating the tenancy and evicting the Tenant based on the assertion that the Tenant gave notice to terminate must be dismissed. The Tenant did not give notice to terminate the tenancy to the Landlord in compliance with the Residential Tenancies Act, 2006 (the 'Act'). 8. Rather the parties exchanged a number of text messages and in one of them the Tenant said he would remove his possessions from the unit before February 1, 2017. 9. This text does not constitute a valid notice to terminate in that it does not meet the following requirements of the Act: it does not state a date for termination that is the last day of a month of the tenancy (s. 44); 60 days’ notice was not provided (s. 44); it is not in the Board’s prescribed form (s. 43(1)); it is not signed (s. 43(1)(c)); and it does not identify the rental unit (s. 43(1)(a)). 10. There was also no written agreement to terminate and the Tenant remains in possession of the rental unit. 11. As a result, the Landlord’s application under s. 77 of the Act must be dismissed",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act., because I find the lengthy payment plan proposed by the Tenant to be too long and prejudicial towards the Landlord. I have no evidence before me that the Tenant will be able to pay the arrears owing within a reasonable amount of time. Under these circumstances, I find the Landlord’s proposal of an extended termination date to be more reasonable",
#  'I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act and find that it would not be necessary to grant relief from eviction pursuant to subsection 83(1) of the Act because the Tenants vacated the rental unit',
#  "Regarding the L1 application: I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be necessary to grant relief from eviction pursuant to subsection 83(1) of the Act. The Tenants stated that they can pay the amount owing within 11 days. Landlord’s Own Use of the Basement Unit 13. The Landlord served the Tenants with a valid N12 notice of termination effective May 31, 2017. 14. The property is a bungalow with two separate units. The Tenants rent the basement unit. The Landlord resides in the upper unit with his wife and three children ages 16, 15 and 10. 15. The Landlord’s wife deals with the Tenants for most of the matters involved in the tenancy. She is having surgery in the near future for severe arthritis in her knee. Medical documentation was provided to support this. She will require modifications to the bathroom to assist her after her surgery. There is only one bathroom on the upper floor. The Landlord, his wife and their three children share the one bathroom. 16. The Landlord intends to return the property to a single family home. He requires the extra space in the basement for two reasons. One, so that there will be a second bathroom available for his family’s use; and two, so his two teenaged sons will no longer have to share a bedroom upstairs. 17. The Landlord provided documentation to establish that one of his sons has autism. The shared bedroom arrangement between his two sons is no longer working now that the boys are older and they need their own rooms. 18. The Landlord, in good faith, requires the rental unit for his own use to accommodate the needs of his family. The property will be returned to a single family home. 19. The test of good faith is whether the Landlord has a genuine intention to occupy the rental unit for his own use (Salter v Beljinac 2001 CanLII 40231 (ON SCDC), [2001] O.J. No. 2792 Div Ct). I find that the Landlord has this genuine intention. 20. The Landlord has provided the affidavit required by section 72 of the Residential Tenancies Act, 2006 (the ‘Act’) stating that he needs the rental unit for his own use. 21. The Tenants question the good faith of the Landlord. There is no dispute that the landlord/tenant relationship has become tense. The police have been called by both sides for various disputes between the Tenants and the Landlord’s wife. 22. The Tenants state that they have received six N12 notices of termination over the past few months and two N4 notices. They consider this to be harassment. 23. The notices of termination that the Landlord issued do not amount to harassment. 24. The two N4’s are for the same rent arrears. There was just one copy issued to each Tenant separately. The N4 notices were only issued due to the undisputed rent arrears. There is nothing improper in the issuing of the N4 notices. 25. The six N12 notices really only amount to three. Three N12’s were issued with one separate copy for each Tenant. There were defects or deficiencies in the prior N12 notices. The last N12 notice issued (with a separate copy for each Tenant) is valid and is the basis for this L2 application. 26. The Tenants attempted to raise other issues regarding harassment such as a parking issue. However, this issue was already determined in a prior Board application (TET-72567-16) and cannot be raised for a second time. 27. There is no question or dispute that the tenancy is problematic and the relationship been the Landlord’s wife and the Tenants is no longer functioning. The Tenants claim that this is the real reason for the N12 notices. However, this does not amount to bad faith. There is nothing improper about a Landlord deciding that he no longer wants to rent his unit anymore. As long as he genuinely intends to use the rental unit for his (and his family’s) own residential use, the test of good faith has been met. 28. The Tenants claim that they have had no heat and h ...
#  'Section 83 10. Having considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, I find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. 11. This is the second application by the Landlord in less than one year to collect the rent arrears that are currently substantial. The Landlord is unable to financially maintain this property. The Landlord is required to pay the mortgage and the taxes regularly while the Tenant continues to occupy the premises. 12. The Tenant requested that the eviction be stayed or refused pending the outcome of the Superior Court of Justice decision as it would be unfair for the Tenant to lose occupancy of the premises whilst the argument for ownership proceeds at the Courts. 13. The Divisional Court in Lomico 188 Inc. v. David Mouritsen and Irina Mouritsen 2014 ONSC 2442 (CanLII) Div. Crt. File No.: 541/13 has determined that the Board’s jurisdiction to hear an application to terminate the tenancy for arrears of rent is not ousted by reason of a pending action in the Superior Court involving the same tenancy. 14. The eviction order is remedial upon payment of the rent owed in accordance with the signed tenancy agreement between the parties. This is the Tenant’s second application before the Board within one year for substantial rent arrears. The Tenant’s application before the Superior Court of Justice was only filed in recent weeks. L2 application 15. The N5 notice of termination at the root of this application was filed pursuant to section 64 of the Act. Subsection 64(1) of the Act states the following: A landlord may give a tenant notice of termination of the tenancy if the conduct of the tenant, another occupant of the rental unit or a person permitted in the residential complex by the tenant is such that it substantially interferes with the reasonable enjoyment of the residential complex for all usual purposes by the landlord or another tenant or substantially interferes with another lawful right, privilege or interest of the landlord or another tenant. 16. The issue in the N5 notice is regarding the Landlord inability to access the premises as the Tenant has refused access, changed the lock and failed to provide a key to the Landlord. There was no dispute that the Tenant only recently provided the Landlord with a key to the rental unit. 17. Based on the evidence before me, I am not satisfied that the Tenant has continued to refuse access to the rental unit by the Landlord. According to the Landlord a notice of entry was provided to the Tenant, however she made a typographical error in the date. Unfortunately, given that the typographical error was the date of the notice, it stated May 5, 2017, and the notice simply stated that the Landlord requires entry in 24 hours, I find that the Landlord’s attempt to enter on May 4, 2017 was not in compliance with the notice. Section 83 18. Having considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, I find that it would not be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act given that the Landlord has obtained a key from the Tenant. L8 application 19. There was no dispute that the Tenant complied with interim order CEL-65920-17 issued April 26, 2017 and provided the Landlord with a key to the rental unit on May 3, 2017. The parties agreed that this issue was resolved. Consequently the application is dismissed',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until May 31, 2017 pursuant to subsection 83(1)(b) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until June 30, 2017 pursuant to subsection 83(1)(b) of the Act",
#  nan,
#  'The rent deposit applies to June 2017. 8. No circumstances were disclosed in accordance with subsection 83(2) of the Act, to consider relief from eviction pursuant to subsection 83(1) of the Act',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  'I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act. 7. Although the Tenant requested two months to pay the amount that she owes to the Landlord, I find that it is reasonable to postpone the eviction date to only July 31, 2017. It is appropriate to postpone the eviction date because of the Landlords’ failure to provide the Tenant with rent receipts. However, I also find that it is not appropriate to postpone the eviction date beyond July 31, 2017, because the Tenant elected to spend the rent money she withheld from the Landlords on other items. Under the circumstances, it would be unfair to the Landlords to postpone the eviction date beyond July 31, 2017, as doing so could result in the accrual of additional rent arrears. 8. The Tenant shall be ordered to smoke cigarettes away from the residential complex, to prevent any second hand smoke from entering the property',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. Under the circumstances, a seven-day voidable eviction order is warranted",
#  'Section 83 17. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act',
#  'In respect of the L1 and L3 applications, I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would not be unfair to grant relief from eviction subject to the conditions set out in this order pursuant to subsections 83(1)(a) and 204(1) of the Act. The Landlord's Agent did not provide sufficient details regarding prior applications such as whether the Tenant complied with any relief provided. This is a longer term tenancy, six years in length. To balance any prejudice to the Landlord, the Tenant is required to void the rent arrears portion of the order to benefit from a condition to pay the rent on time with a section 78 provision where the Landlord can file for eviction if a payment of rent is late without notice to the Tenant",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until January 31, 2018 pursuant to subsection 83(1)(b) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act because I do not believe the Tenant has the financial resources to pay the rent and the arrears",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act given that the Tenant stated that the amounts can be paid to the Landlord within the standard timeframe. Regarding the L2 application N5 Notice of termination 4. The N5 notice of termination was served on the Tenant pursuant to section 64 of the Act. Subsection 64(3) of the Act states: The notice of termination under subsection (1) is void if the tenant, within seven days after receiving the notice, stops the conduct or activity or corrects the omission. 5. There were only three issues listed on the N5 notice. The first related to an incident on April 9, 2017 involving police services. This was a one-time occurrence and this conduct had not continued. Therefore, I am satisfied that this issue in the N5 notice was corrected. Of the two remaining issues in the N5 notice the Landlord chose not to proceed with the allegation of the failure to maintain the exterior of the rental unit. 6. The final issue related to an allegation that the Tenant rented the basement at the rental unit. In regards to this issue, the evidence before me was insufficient to find that the Tenant has rented out the basement to another tenant. The Landlord only suspected that the basement was rented because another person was seen at the property. However, the Tenant confirmed that this person is his relative. N12 Notice of termination 7. The Landlord stated that her in-laws, who currently reside with her and her husband, would like to move into the rental unit. They lived in the rental unit previously and formed relationships within that community. Her eldest child is able to care for his younger sibling, and her in-laws are no longer needed to care for the children in her home. 8. MP testified at the hearing, and although there was some difficulty with the translation from Hindi, which is spoken by both the Landlord and the Tenant, to English, MP confirmed that he planned to reside at the rental unit to be closer to friends and part-take in community gatherings in the park near the unit. MP also stated that he is looking forward to mental peace. 9. The Tenant disputed the intention of MP to reside at the unit. He submitted that the Landlord’s in-laws have not resided in the rental unit for two years, and ought to have assimilated to their new community. Further, he believes that he was served with the N12 notice because he refused to agree to a rent increase proposed by the Landlord. 10. According to the Tenant, just prior to the lease renewal, the Landlord approached him for renewal at a significantly higher rent. At that time, he refused to renew for another one-year term at this new rent because he could not afford to pay that amount. Then he received a N12 notice of termination. 11. The test of good faith is whether the Landlord (or a permitted person) has a genuine intention to occupy the rental unit for their own use (Salter v Beljinac 2001 CanLII 40231 (ON SCDC), [2001] O.J. No. 2792 Div Ct). The motives of the Landlord, the fact that there may be other options available or the reasonableness of their plans are not relevant to the test of good faith. 12. Based on the evidence before me, I am satisfied that there is a genuine intention for the Landlord’s in-laws to move into the rental unit after the Tenant vacates the unit. The Landlord stated that when the Tenant did not renew the tenancy, her in-laws made the decision to move. While the Tenant offered reasonable suspicions, which are genuinely held by him, they remain mere suspicions. I am not satisfied that they are sufficient to cast significant doubt on the Landlord’s in-laws intentions. The Landlord’s in-laws provided the affidavits required by section 72 of the Act and MP testified at the hearing regarding their intention. 13. Therefore, I find that t ...
#  'I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would not be unfair to grant relief from eviction subject to the conditions set out in this order pursuant to subsections 83(1)(a) and 204(1) of the Act. The tenancy is eight years in length and the Tenant is able to repay the arrears in a short amount of time. To balance the prejudice to the Landlord, the Tenant is required to void the rent arrears portion of the order to benefit from a condition to pay the rent on time with a section 78 provision where the Landlord can file for eviction if a payment of rent is late without notice to the Tenants',
#  'A preliminary review of the review request was completed without a hearing in accordance with Rule 29.11 of the Board’s Rules of Practice. Determinations: 1. The Tenants attended the hearing that took place on January 25, 2018. Their tenancy was terminated in order CEL-71370-17, issued on January 30, 2018. However, the eviction or move out date was delayed by one month to February 28, 2018. 2. The Tenants are understandably disappointed with that result. Yet, a review is not an opportunity to reargue your case in hopes of a more favourable outcome. Nor is it an opportunity to present evidence and submissions that could and should have been presented at the original hearing. 3. On the basis of the submissions made in the request, and after listening to the recording of the hearing, I am not satisfied that there is a serious error in the order or that a serious error occurred in the proceedings. 4. The Tenants allege that there is a serious error in the order because the order fails to give adequate reasons for the determinations made by the Member. In particular, they allege that the order should have stated the exact amount of utilities that the Tenants owe to the Landlord. This does not amount to a serious error. 5. The order does not require the Tenants to pay the Landlord the amount of the unpaid utilities. Therefore, stating the exact amount was not necessary. The N5 Notice of Termination and the application state the exact amount of unpaid utilities the Landlord claims is owing. The Board’s file and the recording of the hearing reveal that the Landlord provided a spread sheet at the hearing which identified the amount owing as of the hearing date. As a result, the Tenants were aware of the amount that was claimed to be owing. Also, paragraph 12 of the review request reveals that the Tenants were aware of the amount for unpaid utilities since they refer to the amount as “only a little more than…the Tenants’ monthly rent.” 6. The failure to provide full reasons for the determinations made does not amount to a serious error that would justify a review of the order. The Board hears a very large volume of cases. Due to this volume, full reasons for the decision are not provided with every order. However, Rule 26.2 of the Board’s Rules of Practice states that a party can request reasons for the decision within 30 days of the order. If the Tenants required more detailed reasons they could have requested those reasons. There is no record of any such request. 7. The Tenants allege that the Member failed to fully consider their circumstances under section 83 of the Residential Tenancies Act, 2006, (the ‘Act’). They state that they have a fixed, limited income, have three young children and a move will be difficult for the family. The hearing recording reveals that the Member asked the Tenants more than once near the conclusion of the hearing if there was anything else they wanted to say or add to their evidence. The Tenants had a full opportunity to explain all of their circumstances. Paragraph 9 of the order reveals that the Tenants’ family circumstances were considered and this was the reason for the delayed eviction date 8. The remedies that are ordered, including the termination or eviction date, are within the discretion of the Member who heard all of the evidence and submissions from both the Landlord and the Tenants. The reasonable exercise of discretion will not be interfered with on review. 9. The N5 Notice of Termination that the Landlord’s application is based on is dated October 11, 2017 with a termination date of November 2, 2017. The N5 notice alleges that the Tenant have failed to pay the utility bills from February 2017 to October 2017. The Tenants allege that it was a serious error for the Member to consider the state of the utility accounts as of the January 25, 2018 hearing date and only the timeframe in the N5 notice should have been considered. 10. This is not a serious error. The Member is required, under se ...
#  'I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act and find that it would not be necessary to grant relief from eviction pursuant to subsection 83(1) of the Act because the Tenants vacated the rental unit',
#  "Section 83 21. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "Having considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), I find that it would not be unfair to postpone the eviction until June 30, 2018 pursuant to subsection 83(1)(b) of the Act. 16. The Tenants have resided in the rental unit for almost eight years. Their children attend the local schools and they require additional time to find alternate housing given DM’s health issues. I am satisfied that a delay until the end of June 2018 provides a sufficient time frame for the Tenants to find accommodation without significant prejudice the Landlords’ daughter. The Landlords’ daughter is still able to attend university, her employment and her volunteer position from her current residence in the interim. 17. The Landlords have paid the Tenants the required compensation pursuant to section 48.1 of the Act. Regarding CET-73173-18 T2 application 18. In this application, the Tenants alleged that the Landlords harassed the Tenants, substantially interfered with the Tenants’ reasonable enjoyment of the rental unit and withheld or deliberately interfered with a vital service. A number of the Tenants’ issues in this application also related to the Tenants’ T6 application with respect to the Landlords’ failure to maintain the appliances and the furnace. Those allegations will be addressed in regards to the T6 application below. Harassment and Substantial Interference 19. The Tenants stated that they had a good relationship with the Landlords until the Landlords tried to increase the rent by $300.00-$400.00 in 2015. The Tenants were also upset that the Landlords demanded that the Tenants pay a rent deposit of $7,800.00 representing three months’ rent at the time at the commencement of the tenancy. As well, according to JM, in every conversation with the Landlords after the initial term of the tenancy, the Landlords complained that the “rent is too low” or “I am losing money.” 20. JM stated that they had to take care of everything on their own. It has only been in the last year that they put their foot down and now they feel like the Landlords are bullying them. The Tenants were extremely upset that MH made a racist comment towards DM when MH attended the rental unit on December 7, 2017. The comment to DM was something to the effect that MH only decided to replace the appliances “because you are married to a white man.” DM was concerned how she would be treated if she were not married to a white man. 21. MH denied making the above comment. MH provided her own version of the events on that day, December 7, 2017, when she attended the rental unit. She stated that DM grabbed her arm and stated that she is not leaving until she gives permission to replace the stove. MH also stated that it was on this day when she first advised the Tenants that her daughter wants to move into the rental unit. MH said she left the unit shaking. 22. The Landlords’ brother, BT, testified that he received a call from MH, who was crying, and advised that the Tenants wouldn’t allow her to leave. BT subsequently went to the rental unit that night. According to BT, DM was aggressive towards MH when they returned to the rental unit. BT also testified that DM said that MH “can’t speak English properly and she is a pharmacist.” 23. There was no dispute that the Landlords collected three months as a deposit in the initial tenancy agreement. The Tenants confirmed that at the time of entering the tenancy, they were going through bankruptcy proceedings and they paid the amount requested. The Landlords are no longer retaining these moneys and haven’t been for over one year, which is the time limitation for a tenant to make an application for illegal collection or retention of moneys by a landlord. 24. The Tenants have only raised the collection of the three month deposit and the demand for an unlawful increase after receiving the N12 notice. I am not satisfied that these two issues amount to a patter ...
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. L2 Application N8 Notice to End Tenancy 8. Based on the submissions of the parties, I find the Tenant has persistently failed to pay the rent on the date it was due. 9. The Tenant requested relief from eviction by requiring the Tenant to pay here lawful rent for the next twelve months on or before the 1st day of every month, starting in March 2018. 10. The Landlords agreed to this on the condition that should the Tenant fail to make any one of said rent payments in full and on time, the Landlords would have the right to seek the Tenant’s eviction, without notice to the Tenant, under section 78 of the Act. The Tenant understood and agreed to this condition, and so this is what will be ordered. N5 Notice to End Tenancy 11. There are two N5 notices of termination underlying the L2 application. The first N5 was served on the Tenant on November 30, 2017, and identified the Landlord’s complaint that the Tenant called the Landlords about an air conditioning issue when the Landlords stated there was no such issue. The second N5 was served on the Tenant on January 11, 2018, this time detailing the Landlord’s complaint of another false issue reported by the Tenant concerning a leak in the basement, and further notified the Tenant about the Tenant’s removal of a door, the CO detector and clutter around the furnace area. 12. The Landlords testified that they believed the first N5 was corrected by the Tenant and therefore voided in the seven-day period. Reference is made to exhibits LL#3 and LL#4 in support of their testimony. 13. RL testified that on December 19, 2017, he received an emergency call from the Tenant that morning about a flood/leak in the rental unit. RL played a video clip he took later that day to show when he came to inspect the unit, and also submitted exhibit LL#5, which comprises text message exchanges between RL and YL dated December 19th and 20th. RL testified that when he arrived, there was no sign of any emergency leak in the basement. 14. YL submitted 6 photographs (exhibits TT#3 to TT#8) that she testified were taken early on December 19th, and which evidence the large amount of water leaking into her sons’ bedroom. YL confirmed she called RL around 5:30 am that morning about the leak. 15. JE testified that she attended the rental unit after 6:00 am on December 19th and witnessed about 1-1/2 inches of water leaking “everywhere” and especially into the sons’ bedroom. JE described how she assisted YL in trying to mop up the water using a series of towels and other implements. JE is married to YL’s ex-spouse, and had arrived to pick up the children. 16. On this particular Landlords’ claim, I find that the evidence and testimonies, especially that of JE, support the Tenant’s version of events over the version claimed by the Landlords. Specifically, I believe that there had been a serious leak of water that occurred in the rental unit in the early hours of December 19, 2017. Based on this, I do not find that the Tenant substantially interfered with the Landlord’s reasonable enjoyment or lawful rights. The Tenant did what a responsible tenant is supposed to do in these circumstances. As such, I am denying this L2 claim, which is the substantive part of the L2 application. 17. The Landlords testified that the Tenant also removed a light dome and laundry room door, dismantled the carbon monoxide detector, had interfered with Landlords entry into the unit by placing “do not enter” signs and had cluttered the area around the furnace with the Tenant’s combustibles. The Landlords submitted exhibits LL#6 to LL#10 in support of their testimony, which include reports from a Brampton Fire Prevention Officer. 18. The Tenant did not dispute the light dome/door issue, the CO detector disma ...
#  "I have considered all of the disclosed circumstances for both L1 and L2 applications in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "Section 83 Circumstances 25. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. L2 Application 5. RN submitted exhibit LL#1, comprising five pages of photographs taken on February 2, 2018, and which show the garage still full of the Tenants’ belongings. This was clearly complained about in the two N5 notices served by the Landlord on the Tenants. In order to remedy the N5 notices, the Tenants must remove their belongings from the garage. 6. The garage is situated adjacent to the house that contains the rental unit (hereinafter referred to as the ‘Garage’). RN affirmed in her testimony that the Tenants have no right to use, or store their things in, the Garage under the tenancy. 7. The Tenants were given a first N5 Notice of Termination under section 67 of the Act on January 5, 2018. Serving a second N5 Notice of Termination on January 13, 2018 was permissible pursuant to Section 68 of the Act. 8. As the Tenants did not remedy the N5 notices within the voiding period provided for under the Act, I find the Tenants’ conduct has substantially interfered with the Landlord's and the other tenants' reasonable enjoyment of the residential complex, and with a lawful right, privilege or interest of the Landlord. 9. While there were other claims made in the N5 notices, they were not presented by the Landlord during the hearing. As a result, my determination is limited to the finding in paragraph 8 above, with any other claim being denied hereto. 10. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act",
# ...
#  'NEED OTHER METHOD',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. At the hearing the EPIC worker advised that the Tenant’s arrears would be cleared up well in advance of 11 days from the date of the order",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to postpone the eviction until September 30, 2018 pursuant to subsection 83(1)(b) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act, because the Landlord must bear some responsibility for the confusion over the rent arrears flowing from the alleged set off arrangement. Tenant’s T6 application 16. The Tenants filed a T6 application alleging that the Landlord breached its maintenance obligations by failing to maintain the rental unit in manner fit for habitation. 17. Pursuant to section 29(2) of the Act, a T6 application cannot be filed more than one year after the day the alleged conduct giving rise to the application occurred. Most of the claims made in the application cannot be considered because they fall outside of this one-year limitation period, which in this case is September 24, 2017. 18. At the hearing the Tenants presented a stack of documentary evidence more than three inches thick. I directed the Tenants to draw my attention to those images and documents that they believe are necessary for me to make a finding on their claims. 19. While I am satisfied that the Tenants have established that the rental unit was in need of repair, I am not satisfied that the Tenants has established that he actually undertook the work claimed or incurred the expenses claimed. 20. The Tenant, OLK alleged that he spent $18,000.00 to repair the rental unit because of the following required repairs: (a) Exposed light bulbs in the hall way and through the unit; (b) Electrical issues - hired an electrician to repair the circuit panel; (c) Absence of fire alarms in the rental unit; (d) Humidity and mould; (e) The balcony door could not open; (f) Leaky kitchen sink; (g) Holes and leaks in walls and around the windows and drafty windows; and (h) Untidy carpet needing repair; 21. An examination of the photographs taken by the Landlords in preparation for hearing, indicates that OLK did not install any of the fixtures or undertook any of the repairs he is claiming a refund for. It was also evident through cross-examination that the Tenant had not used many of the items he purportedly purchased in the rental unit. 22. The Tenant’s evidence though copious does not allow me to conclude that they are entitled to receive a refund for the amounts claimed. The Tenant’s evidence in support of his out of pocket expenses is not reliable given the cross examination and he did not adequately refute the suggestion that many of the receipts were for items not used for the rental unit. 23. The Tenants have alleged that they stopped paying rent because they made an agreement with the Landlord to repair the unit in lieu of rent. The Tenant initially said that he made repairs worth an entire year’s rent, however, he later indicated that the unit is still in need of significant repairs. This was also confirmed by the Tenant’s own home inspection report which they obtained on December 11, 2018. The report indicates that the unit is in need of extensive upgrades, maintenance and repairs such as: i) External masonry weakness; ii) Porch slope and handrails; iii) Trees and shrubs are too close to the building; iv) Windows have cracked glazing and frames are old; v) Mold observed on the ceiling and under kitchen cabinets; vi) Kitchen exhaust fans were missing; and vii) Bathroom exhaust fan missing. 24. The OLK also claimed $9,000.00 for out of pocket expenses for meals, laundry etc. which he said the Tenants incurred because of the problems he noted in the kitchen. 25. It is alleged OLK meal receipts should not be accepted because they are inflated to mislead the Board. Mr. S testified using the OLK’s own disclosure that the OLK claimed meal expenses from Ziggys on January 8, 2019, and three separate purchases were made within 30 minutes using three separate debit cards. 26. It was also sugges ...
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. 10. The Tenant has persistently paid her rent late. The Tenant did not contest this allegation, but noted that she is forced to pay her rent – which she does regularly in cash – at variable times such that the Landlord does not become familiar with her travel patterns so that it is in a position to harm her. 11. With respect to the L2 application, as outlined by NM, the Landlord is not seeking termination of the tenancy but asking for a conditional, “pay on time order”. 12. As stated at the hearing, I believe that a conditional “pay on time” order with respect to the L2 application is appropriate under the circumstances. 13. However, my concern with such an order is that the Tenant may be a person with a disability as defined in the Human Rights Code (“the Code”). The Tenant seems – with no reasonable basis – to be entirely convinced that the Landlord and its agents are committed to, and have devoted considerable resources and planning toward - doing her physical and financial harm. It is my obligation under the Code to accommodate the Tenant short of undue hardship. However, the Tenant neither has requested accommodation nor self-identified as a person with a disability. 14. In this context, what I believe is appropriate in light of my comments above, is to defer the start date of the conditional order with respect to the L2 application. Instead of a start date of November 1, 2018, the pay-on-time requirement will begin on December 1, 2018. 15. This delayed beginning of the requirement to pay on time shall allow the Tenant a) to get legal and other advice on the order and the requirement to pay on time; and b) to make necessary arrangements to pay her rent on time in a manner with which the Tenant feels comfortable",
#  "Relief from eviction 17. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  'NEED OTHER METHOD',
#  'NEED OTHER METHOD',
#  'NEED OTHER METHOD',
#  'NEED OTHER METHOD',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would not be unfair to grant relief from eviction subject to the condition(s) set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act. 11. On the totality of circumstances and evidence before me, it seems reasonable to me to grant the Tenant an opportunity to save his tenancy by issuing a conditional order in the L2 application requiring him to pay his rent on time. I believe his evidence that he was thrown into financial chaos by the sudden and wrongful termination of his job, and it took him some time to recover from that impact. I believe it is reasonable to allow him a chance, now that he is working, to continue in his occupation of the unit by paying his future rent on time",
#  'I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. Because of the holiday period, I will delay the eviction until January 5, 2019',
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. L2 application 8. On September 11, 2018, the Landlord served the Tenant a Notice to Terminate at End of the Term for persistent late payment of rent (the ‘N8 notice’) with a termination date of November 30, 2018. 9. The Landlord had stated in the Notice that the Tenant was late in paying his rent for June 2018, by paying the Landlord in two installments on May 1 and May 3, 2018. 10. If the Tenant had paid the rent for June 2018 in May 2018, then the Tenant could not have been late for that month. 11. At the hearing, the Landlord admitted that this was a mistake. As such, I am satisfied that the N8 notice is defective and as a result the Landlord’s L2 application shall be dismissed",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. L2 application Utilities 8. The Landlord served the Tenant with an N5 notice of termination (‘N5 notice’) on September 4, 2018 by mail. Service was effective five days later on September 9, 2018. The grounds for the N5 notice were that the Tenant has substantially interfered with a lawful right, privilege or interest of the Landlord. The N5 notice alleges that the Tenant has failed to pay for utilities for which the Tenant is responsible. 9. Based on the Landlord’s uncontested evidence, I find that the tenancy agreement provides that the Tenant is responsible to pay for hydroelectricity and for water/sewage costs. 10. Based on the Landlord’s uncontested evidence, I find that the Tenant has not paid for the costs of hydroelectricity for the rental unit. I therefore find that the Tenant has substantially interfered with a lawful right, privilege or interest of the Landlord. Late payment of rent 11. The Tenant has persistently paid rent late. Section 83 12. I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), including the Tenant’s assertions he withheld June rent because he did not receive a standard lease, which is no excuse; he sent etransfers for rent for October and December using the same passwords but in circumstances where there was no good reason the Landlord would not accept rent payments if she could have, and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act. L2 application 7. The certificate of service provides that the Landlord gave the Tenant and N4 and N12 notice on August 27, 2018 by handing them to the Tenant however in somewhat confused testimony the Landlord said she gave the Tenant the N4 notice in August 2018 and she gave him the N12 notice in the middle of October 2018. The termination date on the N12 notice is October 31, 2018. 8. Subsections 48(1)(b) and (2) state: 48(1)A landlord may, by notice, terminate a tenancy if the landlord in good faith requires possession of the rental unit for the purpose of residential occupation for a period of at least one year by, (b) the landlord’s spouse; … (2)The date for termination specified in the notice shall be at least 60 days after the notice is given and shall be the day a period of the tenancy ends or, where the tenancy is for a fixed term, the end of the term. 9. As the termination date on the N12 notice must be 60 days after the Tenant is given that notice, I find the N12 notice is a nullity by virtue of the failure to comply with the requisite notice period. Accordingly, the L2 application must be denied",
#  "I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Residential Tenancies Act, 2006 (the 'Act'), and find that it would be unfair to grant relief from eviction pursuant to subsection 83(1) of the Act"]

# %%
# len("""
# 29.   I have considered all of the disclosed circumstances in accordance with subsection 83(2) of the Act, and find that it would not be unfair to grant relief from eviction subject to  the conditions set out in this order pursuant to subsection 83(1)(a) and 204(1) of the Act.

# 30.   In granting relief, I am taking into account the submissions of the Landlord and her financial obligations, and balancing that against the Tenant’s disclosed circumstances. Therefore the relief from eviction is subject to conditions set out in this order which, if not met, would allow the Landlord to apply to the Board, without further notice to the Tenant, for an order terminating the tenancy and evicting the Tenant pursuant to section 78 of the Act.

# It is ordered that:

# """)
