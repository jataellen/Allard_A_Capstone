# %% [markdown]
# # Full Extraction Pipeline
#
# This is a notebook where I'm updating the entire pipeline of the data extraction process from start to finish, with a single example. Functions/aspects of the process should be thoroughly tested and vetted before being added to this notebook. This notebook should be a "final" version of the pipeline, and should be able to be run from start to finish with no issues.

# %% [markdown]
# # Loading in HTML File(s)
#
# Creates/finds a folder called "raw_htmls" and each file in that folder:
# - loads the HTML file
# - parses the HTML file
# - cleans and extracts the text from the HTML file (gets rid of encoding artifacts, extra lines, etc)
# - OPTIONAL -- creates a .txt file with the cleaned text, named according to the file number of the case
# - creates a CSV with the raw_file_str and the file_number of the case
# - puts this CSV (Pandas df) through the rest of the pipeline
# - writes to a CSV the contents of the populated Pandas df once pipeline is complete

# %%
import pandas as pd
import os
from bs4 import BeautifulSoup

# %%
input_dir = "raw_html_files/"

files_dict = {}
files_dict['raw_file_str'] = []

for file in os.listdir(input_dir):
    try:
        if os.path.isfile(input_dir + file) and not file.startswith('.') and file.endswith('.html'): # will only work for non-system files that are .html files
            # print("Adding ", file, "...")
            with open(input_dir + file) as f:
                html = f.read()
            soup = BeautifulSoup(html, "html.parser")

            # find metadata
            document_meta = soup.find("div", {"id": "documentMeta"}) 
            meta_items = document_meta.find_all("div", {"class": "row py-1"})

            # "Metadata"
            case_ID = ""
            meta_data = []
            for meta_item in meta_items:
                children_text = []
                for x in meta_item.findChildren()[:2]:
                    children_text.append(x.text)
                child_string = '\t'.join(children_text)
                if "file number" in child_string.lower():
                    case_ID = child_string.split("\t")[1].strip()
                    # print(case_ID)
                meta_data.append(child_string)

            # "Content"
            document_body = soup.find("div", {"class": "documentcontent"}).get_text()

            # add to raw_files_dict{} to be put into dataframe later
            files_dict['raw_file_str'].append('Metadata:\n' +          # metadata marker
                                               '\n'.join(meta_data) +   # metadata text
                                               'Content:\n' +           # content marker
                                               document_body)           # content text
            
    except:
        print("Error with:", file)

data_df = pd.DataFrame(files_dict)
data_df
# Out:
#                                         raw_file_str
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...

# %% [markdown]
# # Step 1: General Cleaning
# - General file cleaning

# %%
import re

def general_cleaning(raw_file_str: str):
    """
    Performs general cleaning on a raw file string.

    This function removes tabs, non-breaking spaces, leading/trailing whitespace, empty lines, 
    and "\xa0" characters. This function operates line-by-line for the input text and only keeps 
    non-empty lines after stripping.

    Parameters
    ----------
    raw_file_str : str
        The raw file content as a string, where different lines are separated by '\n'.

    Returns
    -------
    list
        A list of cleaned lines. Each element of the list is a cleaned string corresponding to a non-empty 
        line in the input string. Tabs and "\xa0" characters are replaced with spaces, leading/trailing 
        whitespaces are removed.

    Examples
    --------
    >>> general_cleaning("  First line \t \n \xa0 \nSecond line \n   Third line\t")
    ['First line', 'Second line', 'Third line']
    """

    # gets rid of tabs, non-breaking spaces, leading/trailing whitespace, removes empty lines, and "\xa0"
    generally_cleaned_list = [line.replace("\t", " ").replace("\xa0", "").strip() for line in raw_file_str.split('\n') if line.strip() != '']
    return generally_cleaned_list

def remove_whitespace_and_underscores(string):
    """
    Removes consecutive whitespace and more than three consecutive underscores from a given string.
    
    Parameters
    ----------
    string : str
        The input string to be processed.
        
    Returns
    -------
    str
        The processed string with consecutive whitespace and more than three consecutive underscores removed.
    
    Examples
    --------
    >>> remove_whitespace_and_underscores("Hello    world___")
    'Hello world'
    
    >>> remove_whitespace_and_underscores("   This    string_has___many____underscores  ")
    'This string_has_many_underscores'
    """
    # Remove consecutive whitespace
    string = re.sub(r'\s+', ' ', string)

    # Remove more than three consecutive underscores
    string = re.sub(r'_+', '', string)

    return string.strip()

# %% [markdown]
# # Step 2: Metadata + Content Separation

# %% [markdown]
# This is the Flan-T5 model trained to separate Content and Metadata but tbh the rule-based method worked perfectly and took about 0.00001x the time so I think we should use that instead

# %%
# import transformers
# # from transformers import AutoTokenizer
# from transformers import AutoModelForSeq2SeqLM, AutoTokenizer, DataCollatorForSeq2Seq, Seq2SeqTrainingArguments, Seq2SeqTrainer

# model_name = "metadata_extractor_flant5_small"

# # folder where the model files are located -- unzip before running
# model_dir = f"/Users/kmaurinjones/Desktop/School/UBC/UBC_Coursework/capstone/Allard_A_Capstone/models/metadata_extractor/{model_name}"

# tokenizer = AutoTokenizer.from_pretrained(model_dir)
# model = AutoModelForSeq2SeqLM.from_pretrained(model_dir)

# %%
# def extract_metadata_t5(raw_case_file_text: str, model, tokenizer = tokenizer):
#     """
#     Extracts metadata and content from a raw case file text using a T5-based model.

#     This function performs general cleaning on the raw case file text and then applies a Flant-T5-small model
#     to extract the metadata and content. The metadata is extracted using the "extract metadata boundary:"
#     prefix, and the content is obtained by removing the metadata from the cleaned text.

#     Parameters
#     ----------
#     raw_case_file_text : str
#         The raw case file text to be processed.
#     model : T5Model
#         The T5-based model to use for extraction. By default, it uses the pre-defined model.
#     tokenizer : T5Tokenizer, optional
#         The tokenizer associated with the T5-based model. By default, it uses the pre-defined tokenizer.

#     Returns
#     -------
#     tuple
#         A tuple containing two strings: the extracted metadata and the content.
    
#     Examples
#     --------
#     >>> raw_text = "metadata: Title: Example Case\nContent: This is the content of the case."
#     >>> extract_metadata_t5(raw_text)
#     ('Title: Example Case', 'This is the content of the case.')

#     >>> raw_text = "metadata: Author: John Doe\nContent: Some content."
#     >>> extract_metadata_t5(raw_text)
#     ('Author: John Doe', 'Some content.')
#     """

#     # do general case file cleaning
#     clean_file_list = general_cleaning(raw_case_file_text)
#     clean_file_str = " ".join([line for line in clean_file_list if ("metadata:" or "content:") not in line.lower()])

#     if "Browse myCanLII Save this case Set up citation alert Email this case" in clean_file_str:
#         clean_file_str = clean_file_str.replace("Browse myCanLII Save this case Set up citation alert Email this case", "").strip()

#     # run model on cleaned case file text
#     inputs = ["extract metadata boundary:" + clean_file_str] # PREFIX = "extract metadata boundary:"

#     inputs = tokenizer(inputs, max_length = 256, truncation = True, return_tensors = "pt")
#     output = model.generate(**inputs, num_beams = 8, do_sample = True, min_length = 1, max_length = 128)
#     decoded_output = tokenizer.batch_decode(output, skip_special_tokens = True)[0]

#     for to_delete in ["<", ">"]:
#         decoded_output = decoded_output.replace(to_delete, "")

#     metadata = decoded_output.strip()

#     # this is just for reformatting the first URL in the metadata -- really specific but seemed to be the only pitfall of the model
#     # this fixes the issue completely
#     pattern = r'https://[^,]*,'
#     matches = re.findall(pattern, metadata)
#     metadata = metadata.replace(matches[0], f"<{matches[0][:-1]}>,")

#     # differentially get the content
#     content = clean_file_str.replace(metadata, "").replace("Content:", "").strip()

#     full_file_cleaned = "Metadata: " + metadata + " " + "Content: " + content
    
#     return full_file_cleaned, metadata, content

# %%
# for row in data_df.index:
#     full_raw_text = data_df.loc[row, 'raw_file_str']

#     # full_file, case_metadata, case_content = extract_metadata_t5(
#     #     raw_case_file_text = full_raw_text,
#     #     model = model,
#     #     tokenizer = tokenizer)
    
#     full_file, case_metadata, case_content = separate_file_sections(full_raw_text)
    
#     data_df.loc[row, 'full_file'] = full_file
#     data_df.loc[row, 'metadata'] = case_metadata
#     data_df.loc[row, 'content'] = case_content

# data_df

# %% [markdown]
# Rule-based method for separating raw case file str into content and metadata, and also returns a cleaned version of the entire case file (metadata + content) in case we want to print that to a text file later on (it includes \n characters that we can later split the str by in order to print it to a human-readable list)

# %%
def separate_file_sections(text_with_newlines: str):
    metadata_list = []
    content_list = []

    is_metadata = True
    is_content = False

    cleaned_full_file = general_cleaning(text_with_newlines)

    for line in text_with_newlines.split("\n"):
        if line.strip() == 'Metadata:':
            is_metadata = True
            is_content = False
        elif line.strip() == 'Content:':
            is_metadata = False
            is_content = True
        elif is_metadata:
            metadata_list.append(remove_whitespace_and_underscores(line))
        elif is_content:
            content_list.append(remove_whitespace_and_underscores(line))

    return "\n".join(cleaned_full_file).strip(), " ".join(cleaned_full_file).strip(), " ".join(metadata_list).strip(), " ".join(content_list).strip()

# %%
for row in data_df.index:
    full_raw_text = data_df.loc[row, 'raw_file_str']

    # full_file, case_metadata, case_content = extract_metadata_t5(
    #     raw_case_file_text = full_raw_text,
    #     model = model,
    #     tokenizer = tokenizer)
    
    for_txt_file, full_file_str, case_metadata, case_content = separate_file_sections(full_raw_text)
    
    data_df.loc[row, 'cleaned_case_with_newlines'] = for_txt_file
    data_df.loc[row, 'full_file'] = full_file_str
    data_df.loc[row, 'metadata'] = case_metadata
    data_df.loc[row, 'content'] = case_content

data_df
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
# 5  Metadata:\nDate: 2019-11-20\nFile number:\nTSL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
# 5  Metadata: Date: 2019-11-20 File number: TSL-07...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
# 5  Date: 2019-11-20 File number: TSL-07666-19-RV ...
#
#                                              content
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
# 5  Order under Section 21.2 of the Statutory Powe...

# %%
print(data_df.loc[0, 'cleaned_case_with_newlines'])
# Out:
# Metadata:
# Date: 2018-07-23
# File number:
# TET-89650-18
# Citation: TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB), <https://canlii.ca/t/hwbfs>, retrieved on 2023-05-23
# Content:
# Order
# under Sections 31, 69 and 89
# Residential
# Tenancies Act, 2006
# File
# Numbers: TET-89650-18
# TEL-90138-18
# A.C. (the 'Tenant') applied for an order
# determining that M.M. (the 'Landlord') or the
# Landlord's agent harassed, obstructed, coerced, threatened or interfered
# with the Tenant, entered the rental unit illegally, altered the locking system
# on a door giving entry to the rental unit or residential complex without giving
# the Tenant replacement keys, and substantially interfered with the reasonable
# enjoyment of the rental unit or residential complex.
# The Landlord applied for an order to
# terminate the tenancy and evict the Tenant because the Tenant did not pay the
# rent the Tenant owes, and because the Tenant has substantially interfered with
# the reasonable enjoyment or lawful right, privilege or interest of the
# Landlord, committed an illegal act, and wilfully or negligently caused undue
# damage to the premises. The Landlord has also applied for an order requiring
# the Tenant to compensate the Landlord for the damage. The Landlord also claimed
# compensation for each day the Tenant remained in the unit after the termination
# date.
# This application was
# heard in Toronto on May 25, 2018.
# The Tenant and the
# Landlord attended the hearing.
# Determinations:
# 1.
# These applications are about
# a friendly relationship that went very bad. So bad that criminal charges are
# pending against the Tenant.
# 2.
# The parties used to be
# friends. The Tenant has lived in the Landlord’s one bedroom basement apartment
# more than once. He lived there about six years ago, moved out and then moved in
# again in July of 2015.
# THE ARREARS OF
# RENT
# 3.
# The parties agree that there
# was no written tenancy agreement between them but disagree as to the lawful
# monthly rent charged.
# 4.
# Both the Landlord and the
# Tenant say that initially the monthly rent agreed to was $750.00. They also
# both agree that the Tenant subsequently told the Landlord he could not afford
# that amount.
# 5.
# The Tenant says that they
# agreed the rent would be lowered to $650.00. He further says the Landlord
# agreed to “cook the books” and issue receipts for $550.00 even though the
# Tenant was paying $650.00. This was because the Tenant is in receipt of social
# assistance from Ontario Works (‘OW’) and his worker told him he had to have
# cheaper housing.
# 6.
# The Landlord says that
# because the Tenant was financially struggling he agreed to accept payments
# towards the rent and the Tenant would pay any shortfall when his situation
# improved. They were friends so the Landlord just left the situation as it was.
# 7.
# The only documentary
# evidence produced by either party about the lawful monthly rent is a series of
# receipts produced by the Landlord.
# 8.
# Based on the receipts and
# the evidence of both parties I am satisfied that the tenancy commenced July 1,
# 2015 and the parties agreed to a monthly rent of $750.00.
# 9.
# The receipts corroborate the
# evidence of both the Landlord and the Tenant in that they show for July and
# August of 2015 the Landlord collected $750.00 each month plus an additional $500.00
# as a last month’s rent deposit. The receipts also indicate that until February
# 28, 2016 the Landlord charged and collected $750.00 each month from the Tenant.
# 10. The reason this is important is because s. 113
# of the Residential Tenancies Act, 2006 (the ‘Act’) says the lawful rent
# is the rent first charged to the Tenant subject to any discounts offered under
# s. 111.
# 11. The scheme of the Act tightly regulates rent
# increases and decreases. None of what the Tenant describes constitutes a legal
# decrease in the rent under any of the relevant provisions of the Act nor was a
# new tenancy agreement entered into. (See for example, ss. 111, and 125.)
# Pursuant to s. 3 of the Act, the provisions of the Act apply despite any
# agreement or waiver to the contrary. So absent a legally recognizable agreement
# to decrease the rent or a new tenancy agreement, the lawful monthly rent here
# has always been $750.00.
# 12. As explained further below, the Tenant was
# essentially illegally evicted effective April 21, 2018. The arrears of rent and
# daily compensation owing for the period ending April 21, 2018 total $5,443.84.
# 13. The Landlord collected a last month’s rent
# deposit from the Tenant of $500.00. Pursuant to subsection 106(10) of the Act
# the deposit must be applied to the rent due for the last month of the tenancy.
# 14. Interest is owing on the deposit for the period
# July 1, 2015 to May 31, 2018 totalling $26.76.
# 15. The Landlord incurred costs of $190.00 for
# filing the application and is entitled to reimbursement of those costs.
# THE TENANT’S
# CLAIMS OF ILLEGAL ENTRY
# 16. The relationship between the parties seems to
# have gone seriously wrong as a result of events that flowed from the rental
# unit having a problem with mice.
# 17. The problem with the mice seems to date back to
# 2016 which is a period outside of the Board’s one year limitation period (see
# section 29(2)). But what the Tenant is really complaining about is what
# happened on February 17, 2018.
# 18. The Tenant complained to the Landlord about the
# mice in his unit so the Landlord or his spouse contacted a contractor and the
# Landlord told the Tenant the contractor would come in to address the issue
# within 48 hours. The Tenant wanted prompter action and told the Landlord that
# was unreasonable. According to the Tenant, the Landlord called him a “bitch”
# and a “little wife” and the Tenant went back downstairs for a nap.
# 19. The Landlord does not specifically deny saying
# these things to the Tenant. He just says the Tenant was very arrogant and being
# unreasonable.
# 20. A couple of hours later the Landlord’s spouse
# texted the Tenant to say the contractor would be there in 10 minutes. According
# to the Tenant, the contractor then barged into his unit. The Tenant told the
# contractor he had not received proper notice of entry, this was a bad time, and
# asked him to leave. When the contractor expressed reluctance, the Tenant called
# 911 and the contractor left immediately. That was about 7 p.m. on February 17,
# 2018.
# 21. Section 25 of the Act says a landlord can only
# enter a rental unit in accordance with the Act. Section 26 details examples of
# when notice is not required. In this situation none of the provisions of s. 26
# apply. The mice were not an emergency despite the Tenant’s insistence that 48
# hours was too long to wait, and the Tenant did not let the contractor into the
# unit at the time of entry. As notice of entry was not served in accordance with
# s. 27 of the Act, the entry was not in compliance with the Act. As the Landlord
# is responsible for the acts of his contractors and agents, this means I am
# satisfied that on February 17, 2018 the Landlord breached s. 25 of the Act.
# 22. With respect to the Landlord calling the Tenant
# a “bitch” and a “little wife”, the Landlord does not deny that occurred so I am
# satisfied that it did. Name calling like that is unprofessional behaviour. A
# landlord is a business professional selling a vital service to a customer so
# the Landlord here ought to have known that such remarks were inappropriate and
# would be most unwelcome to the average tenant. In other words, the Landlord’s
# remarks constitute a breach of s. 23 of the Act.
# 23. During this series of events the Landlord
# actually left the City to go to the United States. He left February 17, 2018
# and was away until February 23, 2018.
# 24. About three hours after the Tenant got the
# contractor to leave, the Tenant went outside to smoke and found the tires of
# his car slashed. He called the police and told them he believed the contractor
# was responsible but the police told them there was insufficient evidence to
# establish that.
# 25. That is also true for my purposes here. The
# evidence is insufficient to establish it is more likely than not the contractor
# slashed the Tenant’s tires. Even if I was prepared to make a finding the
# contractor did it, that behaviour was clearly outside of the scope of his
# authority from the Landlord. The Landlord hired the contractor to deal with the
# mice issue not to slash the Tenant’s tires, so even if the contractor did do it
# the evidence is insufficient to establish the Landlord should be held liable
# for the contractor’s behaviour.
# 26. With respect to the Landlord’s breaches of the
# Act as found above, remedy is discussed below.
# THE LANDLORD’S
# NOTICES OF TERMINATION
# 27. After the Tenant discovered his tires slashed he
# became very angry. He blamed the Landlord for what happened. He broke into the
# Landlord’s private space upstairs. He broke the bedroom door, damaged the
# ceiling, and made a mess throwing plants around.
# 28. The Tenant attempted to clean up and apologised
# to the Landlord. He offered to pay $100.00 for the damage. But when the
# Landlord returned from the United States, the Landlord called the police.
# 29. The police came to the residential complex on or
# about February 25, 2018 and interviewed the parties. By that point in time the
# Landlord just wanted the Tenant to move out. He says his wife did not want to
# stay there as long as the Tenant remained in the rental unit below. So the
# police suggested that the Tenant could avoid criminal charges if he agreed to
# move out.
# 30. As far as I can tell from the Tenant’s
# testimony, he thought better of his initial agreement to this offer and called
# the police station. The officers present at the house returned the Tenant’s
# keys to him and he was arrested and charged with mischief.
# 31. On March 9, 2018 the Landlord served two notices
# of termination on the Tenant, an N6 for illegal act pursuant to s. 61(2)(b) and
# a voidable N5 pursuant to both ss. 62 and 64.
# 32. At the hearing before the Board I pointed out to
# the parties that the Landlord’s application for an eviction order was
# essentially moot because the parties agree that the Landlord changed the code
# for the front door lock on April 21, 2018, and refused to give the Tenant the
# replacement code. In other words, the Tenant was for all intents and purposes
# illegally evicted on April 21, 2018. As the Tenant’s amended application seeks
# an order terminating the tenancy effective April 21, 2018, an order is going to
# issue terminating the tenancy on the Tenant’s application effective April 21,
# 2018.
# 33. In other words, it was unnecessary to hear
# evidence in support of the allegations contained in the Landlord’s notices of
# termination.
# THE LANDLORD’S
# DAMAGE CLAIM
# 34. The Landlord’s application as filed seeks
# compensation of $1,300.00 for negligent or wilful damage to the residential
# complex pursuant to s. 89(1) of the Act. However, the application contains no
# particulars.
# 35. On the day of the hearing before the Board the
# Landlord filed a request to amend his damage claim and served it on the Tenant.
# The Tenant consented to the Board amending the application as requested by the
# Landlord so I proceeded to hear the amended damage claim.
# 36. The Landlord’s evidence establishes that he paid
# his contractor $1,469.00 to repair the stucco on his bedroom ceiling, prime and
# paint the room, and replace the door and lock.
# 37. The Tenant questions the reasonableness of this
# amount, but led no evidence in support of the proposition that another
# contractor would have charged less, or in support of the possibility the
# Landlord did not in fact pay that amount to his contractor.
# 38. According to the Landlord he received a second
# quote that was similar.
# 39. In the end result the Landlord’s evidence is
# sufficient to establish that it is more likely than not that he paid $1,469.00
# to repair the wilful damage the Tenant did to the Landlord’s bedroom and that
# amount represents the reasonable cost of repair.
# 40. The second part of the Landlord’s claim is more
# problematic. It claims $226.00 for cleaning out the basement and disposing of
# the contents. It also claims $1,356.00 for “sanitizing” the basement, cleaning
# the graffiti and priming and painting the rental unit.
# 41. Damage claims under the Act are brought pursuant
# to s. 89(1) which says:
# A landlord may
# apply to the Board for an order requiring a tenant to pay reasonable costs that
# the landlord has incurred or will incur for the repair of or, where repairing
# is not reasonable, the replacement of damaged property, if the tenant, another
# occupant of the rental unit or a person whom the tenant permits in the
# residential complex wilfully or negligently causes undue damage to the rental
# unit or the residential complex and the tenant is in possession of the rental
# unit.
# 42. As can be seen from this provision it is about
# physical damage to the property and not cleaning or sanitizing.
# 43. More importantly perhaps, the Landlord’s
# behaviour in removing the Tenant’s possessions from the rental unit was
# actually an illegal act for the reasons stated below in the context of the
# Tenant application. The Landlord cannot be entitled to claim against the Tenant
# costs he incurred as a result of the Landlord’s own illegal behaviour.
# 44. Given the above, the $226.00 claimed by the
# Landlord for cleaning out the basement and disposing of the contents is denied.
# 45. The Tenant does not deny that what the Landlord
# calls graffiti on the walls of the rental unit is decoration the Tenant added
# to the rental unit. Nor does he deny the unit needed to be painted as a result.
# 46. But the Tenant says that he offered to paint the
# unit himself once he removed his possessions. That was always the plan for when
# the Tenant moved out prior to the disintegration of the relationship. At that
# point the Landlord refused to let the Tenant do the work himself and the Tenant
# never had a chance to do it anyway because of the illegal eviction. The
# Landlord does not dispute this.
# 47. The Tenant and the Landlord agree that before
# the Tenant moved in the Landlord paid the Tenant to paint the unit himself. The
# Landlord says he paid the Tenant $1,000.00. The Tenant says he was paid
# $500.00.
# 48. The reason this is important is because s. 16 of
# the Act says:
# When a landlord
# or a tenant becomes liable to pay any amount as a result of a breach of a
# tenancy agreement, the person entitled to claim the amount has a duty to take
# reasonable steps to minimize the person’s losses.
# 49. In this context s. 16 means the Landlord was obligated
# to take reasonable steps to minimize the cost of repainting the unit. As the
# Tenant had apparently done an acceptable job in exchange for good consideration
# before, it is not clear to me that it was particularly reasonable for the
# Landlord to refuse to let him paint it again. The is particularly true here
# because if the Landlord had simply followed the process in the Act to obtain a
# legal eviction order from the Board, the undisputed evidence of the Tenant
# suggests the Tenant would have returned the unit to its original condition.
# 50. As a result, I am not prepared to find that the
# Landlord reasonably mitigated the Tenant’s losses or that the costs the
# Landlord incurred in hiring a contractor to paint the unit were reasonable. So
# that part of the Landlord’s damage claim is also denied.
# MISCELLANEOUS
# OTHER CLAIMS BY THE TENANT
# 51. After the police became involved in February and
# the Landlord started serving notices of termination in March, the Tenant filed
# this application with the Board on March 23, 2018. He subsequently filed and
# served a request to amend the application on April 25, 2018. As the Landlord
# was properly served I granted the Tenant’s request to amend his application.
# 52. What appears to have happened after the police
# became involved and notices of termination served is that the parties’
# relationship and behaviour deteriorated further.
# 53. The Tenant says that on March 28, 2018, the Landlord
# turned on the music in his part of the residential complex, turned it up very
# loud, and went out. The Landlord says this was not true; he was home, it did
# not happen.
# 54. As the Tenant bears the burden of proof with
# respect to this allegation and the evidence of the parties is essentially equal
# but opposite I find that the Tenant has led insufficient evidence to establish
# the Landlord harassed him on March 28, 2018 by playing music loudly and leaving
# it on while he went out.
# 55. The Tenant says the Landlord did this a second
# time on March 29, 2018. So the Tenant turned off the electricity to stop the
# noise. That caused a malfunction in an alarm in the basement triggering an
# annoying intermittent beeping. When the beeping did not stop the Tenant told
# the Landlord he could not live like that. The Tenant says the Landlord told him
# it was his own fault and flipped him the middle finger.
# 56. The Landlord acknowledges the Tenant turned off
# the electricity because the Landlord was playing music. He did not dispute the
# Tenant’s evidence that the Landlord told him it was his fault nor does the
# Landlord deny flipping him the middle finger.
# 57. There can be no excuse for a landlord “flipping
# the finger” at a tenant. Any reasonable landlord knows or ought to know that
# such behaviour is unprofessional and would be unwelcome to any reasonable
# tenant. So I am satisfied that in doing so the Landlord breached s. 23 of the
# Act.
# 58. Because of the beeping the Tenant rented
# alternative accommodation and stayed there from March 29, 2018 to April 22,
# 2018. He paid $685.00 for that alternative accommodation.
# 59. Although I would agree with the Landlord that
# the Tenant is partially responsible for the annoying beeping because he turned
# off the electricity, I am satisfied that the Tenant did so because of the
# Landlord’s behaviour in playing loud music. That being said, the reasonable
# thing the Tenant should have done, but did not, was ask the Landlord to turn
# the music down.
# 60. Given all of the above, I do not believe the
# Landlord can be held financially responsible for the disturbance caused by the
# beeping. The Tenant is not entitled to an order for $685.00 for the place he
# stayed in from March 29, 2018 to April 22, 2018.
# 61. During this period the Tenant went back and
# forth to the rental unit.
# 62. He says that on April 3, 2018 he noticed $150.00
# was missing from his coffee table indicating someone was in his unit. The Landlord
# says “why would I take the Tenant’s money?” which I took to mean the Landlord
# denies entering the rental unit or stealing money from the Tenant.
# 63. The evidence with respect to this money and the
# alleged illegal entry is simply insufficient to meet the Tenant’s burden of
# proof. He may have had money go missing; but he may not have. So that part of
# the Tenant’s application must also be dismissed.
# 64. On April 17, 2018 the beeping noise was
# repaired.
# THE CHANGING
# OF THE LOCKS
# 65. On April 21, 2018 the Tenant discovered the key
# pad code to the front door had been changed but he was able to get into the
# residential complex because the cleaner was there. The Tenant says when he
# asked the Landlord for the new code, the Landlord refused so the Tenant
# threatened to turn the power off again. The Tenant says the Landlord was in his
# face yelling at that point so the Tenant called 911 again.
# 66. The Landlord confirms he refused to give the
# Tenant the new code because the Tenant had not paid rent for the month of
# April, 2018.
# 67. Section 24 of the Act says:
# A landlord
# shall not alter the locking system on a door giving entry to a rental unit or
# residential complex or cause the locking system to be altered during the
# tenant’s occupancy of the rental unit without giving the tenant replacement
# keys.
# 68. By changing the key pad code and refusing to
# give him the new one the Landlord breached s. 24 of the Act. Remedy with
# respect to this breach is discussed below.
# 69. According to the Tenant, when the police arrived
# they told him that nothing was in writing so he had to leave. The Tenant was
# given four hours to remove all of his possessions which was not sufficient
# time. He also says the Landlord refused to let him access his stored
# possessions in the garage.
# 70. The Landlord confirms the police gave the Tenant
# four hours to remove his possessions but says the Landlord offered him more
# time. According to the Landlord the Tenant returned on April 30, 2018 to remove
# more of his possessions but the stuff left in the unit downstairs after that was
# garbage. So the Landlord put it out in bags and the Tenant did not come to
# retrieve it. However, the Landlord admits that he told the Tenant he would not
# let the Tenant access possessions in the garage unless the Tenant cleaned out
# the rental unit first.
# 71. I would note at this point that the police had
# no right to tell the Tenant he had four hours to collect his possessions and
# leave. Subsection 168(2) of the Act says:
# The Board has
# exclusive jurisdiction to determine all applications under this Act and with
# respect to all matters in which jurisdiction is conferred on it by this Act.
# 72. Moreover, s. 37(1) says:
# A tenancy may
# be terminated only in accordance with this Act.
# 73. This means that only the Board had the authority
# to tell the Tenant when and if he had to move out.
# 74. At that point in time the Landlord had filed an
# application with the Board for eviction but that application had not been
# heard. Even if the Landlord had obtained an eviction order, the Board’s orders
# cannot be enforced by a landlord or by the police; they are enforceable only
# through the Court Enforcement Office (Sheriff) as they are the legal equivalent
# of writs of possession. The Sheriff gives tenants notice as to when they are
# coming and a tenant has 72 hours after a legal eviction to recover his or her
# possessions.
# 75. Further, the Tenant here had clearly not
# abandoned the unit. His possessions were there. He was returning to the unit on
# a regular basis.
# 76. So what happened to the Tenant on April 21, 2018
# was also an illegal eviction. By putting the Tenant out of possession, clearing
# out the unit of the Tenant’s remaining items, and refusing the Tenant’s request
# to recover his possessions in the garage, the Landlord breached sections 22 and
# 23 of the Act. Again, remedy is discussed further below.
# 77. On May 3, 2018 the Landlord put the Tenant’s
# remaining possessions out on the curb and sent the Tenant a text showing the
# Tenant the bags sitting outside.
# 78. The Tenant says he found a new place to live and
# was able to get possession of his new rental unit on April 22, 2018.
# REMEDIES FOR
# THE LANDLORD’S BREACHES
# 79. The Tenant’s application seeks: abatement of the
# rent; a cease and desist order; compensation for out of pocket expenses; an
# administrative fine; and termination of the tenancy.
# 80. The request for a cease and desist order is with
# respect to the illegal entry and is no longer relevant as the Tenant no longer
# lives in the rental unit.
# 81. However, the amended application also seeks an
# order requiring the Landlord to return to the Tenant any of his possessions still
# in the garage. The Tenant is entitled to such an order.
# 82. The request for compensation for out of pocket
# expenses is for rat poison, traps and door “scrapes”. No evidence was led in
# support of these claims but even if it had been they would have been denied. As
# I stated at the hearing, this application is not based on the rights and
# obligations set out in s. 20(1) of the Act. The breaches by the Landlord of the
# Act as set out above, are not connected to these claims so they are denied
# accordingly.
# 83. In the amended application the Tenant seeks
# $500.00 for moving costs plus the cost of staying elsewhere for the period
# March 29, 2018 and April 22, 2018. No evidence was led that the Tenant incurred
# moving expenses and for the reasons already stated above, the Tenant is not
# entitled to a remedy for the cost of staying elsewhere due to the beeping.
# 84. As stated above, the tenancy shall be terminated
# effective April 21, 2018. The Landlord’s behaviour in changing the locks and
# illegally evicting the Tenant justifies such an order.
# 85. That leaves the claims for abatement and an
# administrative fine.
# 86. Abatement of the rent is a contractual remedy
# entitled to reflect the idea that the Tenant is paying for a bundle of goods
# and services and if the Tenant is not receiving those goods and services the
# rent should be abated proportional to the difference between what is being paid
# for and what is being received.
# 87. The Tenant here is clearly entitled to abatement
# of the rent.
# 88. With respect to the illegal entry by the
# Landlord’s contractor on February 17, 2018, although the entry was illegal and
# the Tenant was entitled to notice of a specific date and time at least 24 hours
# in advance, one of the reasons the Tenant did not receive proper notice is
# because he insisted the mice problem be addressed quickly. The 48 hours’ notice
# he was given was not quick enough. So it seems to me to be somewhat
# unreasonable to award the Tenant any significant abatement for the entry as the
# Landlord was simply trying to acquiesce to the Tenant’s demands. As a result,
# only a minimal abatement is warranted which I fix at $50.00.
# 89. With respect to the name calling on February 17,
# 2018, and the Landlord flipping the Tenant the finger on March 29, 2018,
# abatement of the rent is justified. The Tenant led little evidence as to how
# these events impacted him but he does say he felt belittled and depressed.
# Given all of the evidence before me and my knowledge of similar like cases
# before the Board, it seems to me that a reasonable abatement of the rent for
# these two breaches would be $200.00 each for a total of $400.00.
# 90. With respect to the changing of the locks, the
# disposal of the Tenant’s possessions, the refusal to let the Tenant access the
# garage, and the illegal eviction, I believe a reasonable abatement of the rent
# would be two month’s rent or $1,600.00. I say this based on similar like cases
# before the Board and because even though the Tenant found another place to live
# the day following the illegal eviction, the sequence of events described above
# was clearly distressing to the Tenant.
# 91. The final request in the amended application is
# for an administrative fine.
# 92. With respect to the request for an
# administrative fine the Board’s Interpretation Guideline # 16 on Administrative
# Fines says:
# An
# administrative fine is a remedy to be used by the Board to encourage compliance
# with the Residential Tenancies Act, 2006 (the “RTA”), and to deter
# landlords from engaging in similar activity in the future. This remedy is not
# normally imposed unless a landlord has shown a blatant disregard for the RTA
# and other remedies will not provide adequate deterrence and compliance.
# 93. The Landlord here has clearly shown a blatant
# disregard for the Act. Changing the locks, illegal evicting the Tenant, and
# refusing to give him access to his possessions all demonstrate an utter
# disregard for the Tenant’s rights and the law.
# 94. In terms of quantum for the fine, the remedies
# granted above to the Tenant are relatively minor. Further, the nature of the
# behaviour in question is such that a substantial fine is warranted. Given all
# of the above, and my knowledge of similar like circumstances I am satisfied an
# administrative fine of $5,000.00 is warranted. An order shall issue
# accordingly.
# 95. This order contains all of the reasons for the
# decision within it. No further reasons shall be issued.
# It is ordered that:
# 1.
# On or before August 15,
# 2018, the Landlord shall deliver to the Tenant any of the Tenant’s possessions
# still in the Landlord’s control and give the Tenant access to the garage at the
# residential complex on a date and time of the Tenant’s choosing.
# 2.
# The Tenant shall pay to the
# Landlord $4,336.08. This amount represents rent arrears and daily compensation
# owing up to April 21, 2018, plus compensation for undue damage to the
# residential complex caused by the Tenant’s wilful or negligent behaviour, less
# the Tenant’s last month’s rent deposit and interest owing on the deposit and
# the amount the Landlord owes the Tenant for abatements of the rent.
# 3.
# The Tenant shall also pay to
# the Landlord $190.00 for the cost of filing the application.
# 4.
# The total amount the Tenant
# owes the Landlord under this order is $4,526.08.
# 5.
# If the Tenant does not pay
# the Landlord the full amount owing by August 3, 2018, the Tenant will owe
# interest. This will be simple interest calculated from August 4, 2018 at 3.00%
# annually on the balance outstanding.
# 6.
# The Landlord shall pay
# $5,000.00 to the Board as an administrative fine on or before August 31, 2018.
# July 23, 2018                       _______________________
# Date Issued                        Ruth
# Carey
# Vice
# Chair, Landlord and Tenant Board
# Toronto East-RO
# 2275 Midland Avenue,
# Unit 2
# Toronto ON M1P3E7
# If you have any
# questions about this order, call 416-645-8080 or toll free at 1-888-332-3234.
# Payment
# of the fine must be made to the Board by the deadline set out above. The fine
# can be paid by certified cheque, bank draft or money order made payable to the
# Minister of Finance. If paying in person, the debt can also be paid by cash,
# credit card or debit card.

# %% [markdown]
# # Step 3: File Number + Citation

# %%
import re

def get_case_citation(metadata_list):
    """
    Extracts the case citation from a list of metadata lines.

    This function searches through the metadata lines for a line containing "Citation:" or "Référence:"
    and extracts the citation information from that line.

    Parameters
    ----------
    metadata_list : list of str
        A list of metadata lines.

    Returns
    -------
    str or None
        The extracted case citation, or None if no citation is found.

    Examples
    --------
    >>> metadata = ["Title: Example Case", "Citation: ABC123 (LTB)"]
    >>> get_case_citation(metadata)
    'ABC123 (LTB)'

    >>> metadata = ["Title: Another Case", "Référence: XYZ789 (LTB)"]
    >>> get_case_citation(metadata)
    'XYZ789 (LTB)'
    """
    if isinstance(metadata_list, str):
        metadata_list = metadata_list.split("\n")

    for line in metadata_list:
        if "Citation:" in line:
            citation_start = line.find("Citation: ")
            citation_end = line.find("LTB)") + 4
            return line[citation_start:citation_end].replace("Citation: ", "").strip()
        elif "Référence: " in line:
            citation_start = line.find("Référence: ")
            citation_end = line.find("LTB)") + 4
            return line[citation_start:citation_end].replace("Référence: ", "").strip()
    return None

def get_file_number(metadata_list):
    """
    Extracts the file number from a list of metadata lines.

    This function concatenates the metadata lines into a single string and extracts the file number
    from that string. The file number is obtained either after "File number:" or "Numéro de dossier:".

    Parameters
    ----------
    metadata_list : list of str
        A list of metadata lines.

    Returns
    -------
    str or None
        The extracted file number, or None if no file number is found.

    Examples
    --------
    >>> metadata = ["File number: TNL-10001-18", "Citation: ABC123 (LTB)"]
    >>> get_file_number(metadata)
    'TNL-10001-18'

    >>> metadata = ["Numéro de dossier: XYZ789", "Référence: DEF456 (LTB)"]
    >>> get_file_number(metadata)
    'XYZ789'
    """
    if isinstance(metadata_list, list):
        metadata_str = " ".join(metadata_list)
    else:
        metadata_str = metadata_list

    if "Citation: " in metadata_str:
        file_nums = metadata_str[metadata_str.find("File number: ") + len("File number: ") : metadata_str.find("Citation:")].strip()
    elif "Référence: " in metadata_str:
        file_nums = metadata_str[metadata_str.find("Numéro de dossier: ") + len("Numéro de dossier: ") : metadata_str.find("Référence")].strip()

    if len(file_nums) == 0:
        return None

    file_nums = file_nums.replace(";", " ")

    file_num = list(set(file_nums.split()))
    file_num = ";".join(file_num)
    file_num = re.sub(r'[^\w\s]$', '', file_num)

    if ";" in file_num:
        file_num = list(set(file_num.split(";")))
        file_num = [re.sub(r'[\(\)]', '', num) for num in file_num]
        file_num = ";".join(file_num)

    file_num = re.sub(r'[\(\)]', '', file_num)

    return file_num

# %%
for row in data_df.index:
    data_df.loc[row, 'citation'] = get_case_citation(data_df.loc[row, 'metadata'])
    data_df.loc[row, 'file_number'] = get_file_number(data_df.loc[row, 'metadata'])

data_df
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
# 5  Metadata:\nDate: 2019-11-20\nFile number:\nTSL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
# 5  Metadata: Date: 2019-11-20 File number: TSL-07...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
# 5  Date: 2019-11-20 File number: TSL-07666-19-RV ...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
# 5  Order under Section 21.2 of the Statutory Powe...
#
#                                             citation  \
# 0     TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)
# 1     TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)
# 2     HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)
# 3      SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)
# 4      SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)
# 5  TSL-07666-19-RV (Re), 2019 CanLII 134569 (ON LTB)
#
#                  file_number
# 0               TET-89650-18
# 1               TNL-04435-18
# 2  HOT-02146-17;HOL-02144-17
# 3  SWL-08112-17;SWL-08113-17
# 4  SWT-14627-18;SWL-13901-18
# 5            TSL-07666-19-RV

# %% [markdown]
# # Step 4: Detect Language
# - not necessary for anything in the pipeline, just a fun extra point of data

# %%
# !pip install langdetect
from langdetect import detect

def is_mostly_french(text, threshold):
    try:
        detected_language = detect(text)
        if detected_language == 'fr':
            return True
        else:
            return False
    except:
        return False

def is_french(text, threshold):
    try:
        detected_language = detect(text)
        if detected_language == 'fr':
            return True
        language_probabilities = detect_langs(text)
        for lang in language_probabilities:
            if lang.lang == 'fr' and lang.prob > threshold:
                return True
        return False
    except:
        return False

# %%
for row in data_df.itertuples():

    # adding to 'language' column
    if is_french(data_df.loc[row.Index, "raw_file_str"], 0.7) == True:
        data_df.at[row.Index, 'language'] = "French"
    else:
        data_df.at[row.Index, 'language'] = "English"

data_df
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
# 5  Metadata:\nDate: 2019-11-20\nFile number:\nTSL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
# 5  Metadata: Date: 2019-11-20 File number: TSL-07...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
# 5  Date: 2019-11-20 File number: TSL-07666-19-RV ...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
# 5  Order under Section 21.2 of the Statutory Powe...
#
#                                             citation  \
# 0     TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)
# 1     TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)
# 2     HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)
# 3      SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)
# 4      SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)
# 5  TSL-07666-19-RV (Re), 2019 CanLII 134569 (ON LTB)
#
#                  file_number language
# 0               TET-89650-18  English
# 1               TNL-04435-18  English
# 2  HOT-02146-17;HOL-02144-17  English
# 3  SWL-08112-17;SWL-08113-17  English
# 4  SWT-14627-18;SWL-13901-18  English
# 5            TSL-07666-19-RV  English

# %% [markdown]
# # Step 5: Year
# - also not necessary for anything in the pipeline, just another datapoint for the corpus

# %%
year_pattern = r"\b(\d{4})\b"

for row in data_df.itertuples():

    year_match = re.search(year_pattern, data_df.loc[row.Index, "metadata"])
    if year_match:
        year = year_match.group(1)
        data_df.loc[row.Index, "year"] = year
    else:
        data_df.loc[row.Index, "year"] = "year not found"

data_df
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
# 5  Metadata:\nDate: 2019-11-20\nFile number:\nTSL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
# 5  Metadata: Date: 2019-11-20 File number: TSL-07...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
# 5  Date: 2019-11-20 File number: TSL-07666-19-RV ...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
# 5  Order under Section 21.2 of the Statutory Powe...
#
#                                             citation  \
# 0     TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)
# 1     TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)
# 2     HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)
# 3      SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)
# 4      SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)
# 5  TSL-07666-19-RV (Re), 2019 CanLII 134569 (ON LTB)
#
#                  file_number language  year
# 0               TET-89650-18  English  2018
# 1               TNL-04435-18  English  2018
# 2  HOT-02146-17;HOL-02144-17  English  2018
# 3  SWL-08112-17;SWL-08113-17  English  2018
# 4  SWT-14627-18;SWL-13901-18  English  2018
# 5            TSL-07666-19-RV  English  2019

# %% [markdown]
# # Step 6: LTB Location
# - there are a few different methods and things to try, so I run them in succession to make sure to capture SOMETHING

# %%
import re

def find_all_positions(text: str, keyword: str):
    """
    Finds all positions of a keyword in a given text.

    This function searches for a keyword in a given text and returns a list of positions where the keyword is found.

    Parameters
    ----------
    text : str
        The text to search within.
    keyword : str
        The keyword to find in the text.

    Returns
    -------
    list
        A list of integers representing the positions of the keyword in the text.

    Examples
    --------
    >>> find_all_positions("This is an example sentence.", "example")
    [11]
    """
    positions = []
    start = 0
    while True:
        index = text.find(keyword, start)
        if index == -1:
            break
        positions.append(index)
        start = index + 1
    return positions

def get_postal_code(text: str):
    """
    Finds a postal code in the format "L4Z2G5" within the given text.

    Args:
        text (str): The input text to search for a postal code.

    Returns:
        str: The postal code found in the text. Returns an empty string if no postal code is found.

    Examples:
        >>> find_postal_code("This is a sample text with a postal code L4Z2G5.")
        "L4Z2G5"
    """

    pattern = r"\b[A-Za-z]\d[A-Za-z]\d[A-Za-z]\d\b"
    match = re.search(pattern, text)

    if match:
        return match.group()
    else:
        return None

def find_closest_subset(text: str, keywords: list):
    """
    Finds a subset of the given text where a date and any of the given keywords appear with the smallest distance between them,
    but only if the subset appears before the word "determination" in the lowercase text and does not contain the word "member".

    Args:
        text (str): The input text to search for the subset.
        keywords (list): The list of keywords to search for.

    Returns:
        tuple: A tuple containing the subset of the text where the date and keyword appear with the smallest distance between them,
               and the corresponding keyword. Returns an empty string and None if no match is found or if the subset appears after "determination"
               or contains the word "member".

    Examples:
        >>> find_closest_subset("The event will take place on April 23, 2018. The application was heard on April 25, 2018.", ["heard", "event"])
        ("The event will take place on April 23, 2018.", "event")

    """

    pattern = r"\b[A-Z][a-z]+ \d{1,2}, \d{4}\b"
    date_matches = re.findall(pattern, text)
    keyword_positions = [(m.start(), m.end(), keyword) for keyword in keywords for m in re.finditer(keyword, text)]

    if not date_matches or not keyword_positions:
        return "", None

    smallest_distance = float('inf')
    best_subset = ""
    best_keyword = None
    
    for date in date_matches:
        for start, end, keyword in keyword_positions:
            distance = abs(start - text.find(date))
            subset = text[min(start, text.find(date)): max(end, text.find(date))]

            if distance < smallest_distance and text.lower().find(best_subset.lower()) < (text.lower().find("determination") or text.lower().find("it is determinatined that")) and ("member" or "with the request to review") not in subset.lower():
                smallest_distance = distance
                best_subset = subset
                best_keyword = keyword

    if text.lower().find(best_subset.lower()) >= text.lower().find("determination") or "member" in best_subset.lower():
        return "", None

    return best_subset, best_keyword


def get_ltb_location_by_postal_code(case_content_str: str):
    """
    Helps to extract the location information from the given case content string using postal code lookup.

    Args:
        case_content_str (str): The case content string to extract the location from.

    Returns:
        str or None: Subset of text from the passed case string wherein the location appears near the postal code.

    Examples:
        >>> get_ltb_location_by_postal_code("The application was heard at L4Z 2G5.")
        "Mississauga"
    """

    # if there isn't a postal code, return None right away
    if not get_postal_code(case_content_str):
        return None

    pc_idx = case_content_str.find(get_postal_code(case_content_str))
    subset = case_content_str[pc_idx - 30 : pc_idx]

    if "ON" in subset:
        subset = subset.split("ON")[:-1]
    elif "Ontario" in subset:
        subset = subset.split("Ontario")[:-1]

    subset = " ".join(subset)
    
    if "floor" in subset.lower():
        floor_idx = subset.lower().find("floor")
        # print(floor_idx)
        subset = subset[floor_idx + len("floor") :].strip()
    
    return subset

def get_ltb_location(case_content_str: str):
    """
    Extracts the location information from the given case content string.

    Args:
        case_content_str (str): The case content string to extract the location from.

    Returns:
        str or None: The extracted location information if found, otherwise None.

    Examples:
        >>> get_ltb_location("The application was heard in Newmarket.")
        "Newmarket"
    """

    keywords = ["application was heard", "applications were heard", "was heard", "were heard together",
                "was held", "set to be heard",
                # "heard by telephone", "heard by teleconference", "heard via teleconference",
                "heard by", "heard by", "heard via",
                "motion were heard", "motion was heard", "came before the board in",
                "was then heard in", "were then heard in"]

    subset, keyword = find_closest_subset(text = case_content_str, keywords = keywords)

    if subset:
        subset = subset.replace(keyword, "")
        subset = subset.split()
        subset = [tok for tok in subset if tok not in ['in', 'on', 'via', 'together', 'by']]
        subset = " ".join(subset).strip()
        subset = subset.replace("With The Request To Review", "")

    if subset: # sometimes the hearing location is redacted and replaced with [CITY]
        if str(subset) != "[CITY]":
            return subset.title().replace("And Avenue, Unit 2 ", "").strip()

    # otherwise, go by postal code
    subset = get_ltb_location_by_postal_code(case_content_str = case_content_str)
    if subset:
        return subset.title().replace("And Avenue, Unit 2 ", "").strip()
    else:
        return None

# %%
for row in data_df.itertuples():

    try:
        location = get_ltb_location(data_df.loc[row.Index, 'content'])#.title() # returns the string in title case

        if location:
            data_df.at[row.Index, 'ltb_location'] = location
        else:
            data_df.at[row.Index, 'ltb_location'] = "LOCATION NOT FOUND"

    except Exception as any_error:
        data_df.at[row.Index, 'ltb_location'] = "LOCATION NOT FOUND"

data_df.head()
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location
# 0  English  2018      Toronto
# 1  English  2018    Newmarket
# 2  English  2018      Toronto
# 3  English  2018      Windsor
# 4  English  2018       London

# %% [markdown]
# # Step 7: Hearing Date

# %%
def find_date(text: str):
    """
    Finds a date in the format "Month Day, Year" within the given text.

    Args:
        text (str): The input text to search for a date.

    Returns:
        str: The date found in the text. Returns an empty string if no date is found.

    Examples:
        >>> find_date("The event will take place on April 23, 2018.")
        "April 23, 2018"
    """

    pattern = r"\b[A-Z][a-z]+ \d{1,2}, \d{4}\b"
    match = re.search(pattern, text)

    if match:
        return match.group()
    else:
        return ""

def get_hearing_date(case_content_str: str):
    """
    Extracts the hearing date from the given case content string.

    Args:
        case_content_str (str): The case content string to extract the hearing date from.

    Returns:
        str or None: The extracted hearing date in the format "Month Day, Year" if found, otherwise None.

    Examples:
        >>> get_hearing_date("The application was heard on April 23, 2018. It is determined that...")
        "April 23, 2018"
    """

    for keyword in ["determinations:", "it is determined"]:
        if keyword in case_content_str.lower():
            kw_idx = case_content_str.find(keyword)
            break
        else:
            kw_idx = -1

    subset = case_content_str[case_content_str.lower().find("application") : kw_idx].strip()
    date = find_date(subset)

    if date:
        return date.strip()
        
    # otherwise return None
    return None

# %%
for row in data_df.itertuples():

    try:
        data_df.at[row.Index, 'hearing_date'] = get_hearing_date(data_df.loc[row.Index, 'content']) # is already a str
    except Exception as any_error:
        data_df.at[row.Index, 'hearing_date'] = "HEARING DATE NOT FOUND"

data_df.head()
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location      hearing_date
# 0  English  2018      Toronto      May 25, 2018
# 1  English  2018    Newmarket      May 30, 2018
# 2  English  2018      Toronto      May 30, 2018
# 3  English  2018      Windsor  January 17, 2018
# 4  English  2018       London      May 23, 2018

# %% [markdown]
# # Step 8: Decision Date

# %%
import re
from dateutil.parser import parse
import spacy
nlp = spacy.load("en_core_web_sm")

def find_date(text: str):
    """
    Finds a date in the format "Month Day, Year" within the given text.

    Args:
        text (str): The input text to search for a date.

    Returns:
        str: The date found in the text. Returns an empty string if no date is found.

    Examples:
        >>> find_date("The event will take place on April 23, 2018.")
        "April 23, 2018"
    """

    pattern = r"\b[A-Z][a-z]+ \d{1,2}, \d{4}\b"
    match = re.search(pattern, text)

    if match:
        return match.group()
    else:
        return ""

def extract_date(text, nlp = nlp):
    """
    Extracts a date from a string of text using spaCy's entity recognition.

    Args:
        text (str): The text to extract the date from.

    Returns:
        str: The extracted date string, or an empty string if no date is found.

    Examples:
        >>> extract_date("The event will take place on April 23, 2018.")
        "April 23, 2018"
    """

    doc = nlp(text)

    for entity in doc.ents:
        if entity.label_ == "DATE":
            return entity.text

    return ""

def convert_date(date_str):
    """
    Parses a date string in any format and converts it to the format "Month Day, Year".

    Args:
        date_str (str): The date string to parse.

    Returns:
        str: The parsed date string in the format "Month Day, Year", or an empty string if parsing fails.

    Examples:
        >>> convert_date("2022-05-31")
        "May 31, 2022"

        >>> convert_date("05/31/2018")
        "May 31, 2018"
    """

    try:
        parsed_date = parse(date_str)
        formatted_date = parsed_date.strftime("%B %d, %Y")
        return formatted_date
    except ValueError:
        return ""

def get_decision_date(case_content_str: str):
    """
    Extracts the decision date from the given case content string.

    Args:
        case_content_str (str): The case content string to extract the decision date from.

    Returns:
        str or None: The extracted decision date in the format "Month Day, Year" if found, otherwise None.

    Examples:
        >>> get_decision_date("The date order issued on April 23, 2018 states...")
        "April 23, 2018"
    """

    # intentionally searches these in this order. Any amendment would be the most recent date
    for keyword in ['date order amended', 'date issued', 'date order issued']: 
        if keyword in case_content_str.lower():
            di_idx = case_content_str.lower().find(keyword)
            subset = case_content_str[di_idx - 18 : di_idx].strip().split(". ")[-1]
            return subset.strip()
    
    else:
        if "date" in case_content_str.lower()[: 500]:
            subset = case_content_str[: 500]
            date_idx = case_content_str.lower().find('date')
            subset = case_content_str[date_idx + len('date') : date_idx + len('date') + 50].strip()
            subset = extract_date(subset).strip()
            return convert_date(subset).strip()
    
    # otherwise return None
    return None
# Out:
# 2023-06-17 14:41:28.335020: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
for row in data_df.itertuples():

    try:
        data_df.at[row.Index, 'decision_date'] = get_decision_date(data_df.loc[row.Index, 'content']) # is already a str
    except Exception as any_error:
        data_df.at[row.Index, 'decision_date'] = "DECISION DATE NOT FOUND"

data_df.head()
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location      hearing_date     decision_date
# 0  English  2018      Toronto      May 25, 2018     July 23, 2018
# 1  English  2018    Newmarket      May 30, 2018      June 4, 2018
# 2  English  2018      Toronto      May 30, 2018     July 24, 2018
# 3  English  2018      Windsor  January 17, 2018  February 2, 2018
# 4  English  2018       London      May 23, 2018      June 8, 2018

# %% [markdown]
# # Step 9: Case URL
# - also not necessary for any other part of the pipeline. good for corpus

# %%
import re

def get_url_from_citation_string(text: str):
    """
    Returns URL to case file given a list of strings of metadata from a case file.
    String must begin with "Citation: " and URL must be within angle brackets.

    Parameters
    ----------
    text : str
        A string of metadata from a case file.

    Returns
    -------
    str
        A string of the URL to the case file.
    """

    pattern = r"<(.*?)>"
    matches = re.findall(pattern, text)
    return matches[0]

def get_url_from_metadata(case_metadata: list):
    """
    Extract URL to case file from a list of strings of metadata from a case file.

    Parameters
    ----------
    case_metadata : list
        A list of strings of metadata from a case file.

    Returns
    -------
    str
        A string of the URL to the case file.
    """

    if isinstance(case_metadata, str):
        case_metadata = case_metadata.split("\n")

    for line in case_metadata:
        if ("Citation:" or "Référence:") in line:
            return get_url_from_citation_string(line)
        
    return None

# %%
for row in data_df.itertuples():

    try:
        data_df.at[row.Index, 'url'] = get_url_from_metadata(data_df.loc[row.Index, 'metadata'])
    except Exception as any_error:
        data_df.at[row.Index, 'url'] = "URL NOT FOUND"

data_df.head()
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location      hearing_date     decision_date  \
# 0  English  2018      Toronto      May 25, 2018     July 23, 2018
# 1  English  2018    Newmarket      May 30, 2018      June 4, 2018
# 2  English  2018      Toronto      May 30, 2018     July 24, 2018
# 3  English  2018      Windsor  January 17, 2018  February 2, 2018
# 4  English  2018       London      May 23, 2018      June 8, 2018
#
#                          url
# 0  https://canlii.ca/t/hwbfs
# 1  https://canlii.ca/t/hwbjl
# 2  https://canlii.ca/t/hw7t8
# 3  https://canlii.ca/t/hs06t
# 4  https://canlii.ca/t/hv7nz

# %% [markdown]
# # Step 10: Adjudicating Member

# %%
def get_adj_member(case_content_str: str):
    """
    Retrieves the adjudicating member(s) mentioned in the given case content string.

    Args:
        case_content_str (str): The input string containing the case content.

    Returns:
        str: The adjudicating member(s) mentioned in the case content. If no adjudicating member is found, returns "nan".

    Examples:
        >>> get_adjudicating_member("This is the entire case file. There are sentences and other text.")
        "Name of Adjudicating Member"

    Notes:
        The function looks for specific keywords in the `case_content_str` to identify the adjudicating member(s).
        The keywords are evaluated in the following order: "date issued", "date of reasons", and "date order issued".
        If multiple instances of the same keyword are found, the function extracts the adjacent text and processes it to retrieve the member(s).
        If only one instance of the keyword is found, the function extracts the adjacent text and processes it to retrieve the member(s).
        If no adjudicating member is found, the function returns "nan".

    Raises:
        TypeError: If `case_content_str` is not a string.

    """

    keyword_1 = "date issued" # this is the most reliable one
    keyword_2 = "date of reasons" # first fallback
    keyword_3 = "date order issued" # second fallback

    # find which is best for the case (in order of best option to worst option)
    if keyword_1 in case_content_str.lower():
        keyword = keyword_1
        # kw_idx = case_content_str.lower().find(keyword_1)
    
    elif keyword_2 in case_content_str.lower():
        keyword = keyword_2
        # kw_idx = case_content_str.lower().find(keyword_2)

    elif keyword_3 in case_content_str.lower():
        keyword = keyword_3
        # kw_idx = case_content_str.lower().find(keyword_3)

    # if nothing is found, better to return nothing than to return something clearly incorrect
    if not keyword:
        return "nan"
    
    # getting index of whichever keyword was found first
    kw_idxs = find_all_positions(text = case_content_str.lower(), keyword = keyword)
    
    
    ### If there are multiple members found ###

    if len(kw_idxs) > 1:

        adj_membs = []

        for kw_idx in kw_idxs:
                
            subset = case_content_str[kw_idx + len(keyword): kw_idx + 100] # subsetting to an arbitrary distance after the keyword location
            subset = subset.split(", ")[0].strip()

            # removing "member" if applicable
            if "member" in subset.lower():
                memb_idx = subset.lower().find("member")
                subset = subset[: memb_idx].strip()

            # removing "vice chair" if applicable
            if "vice chair" in subset.lower():
                memb_idx = subset.lower().find("vice chair")
                subset = subset[: memb_idx].strip()

            # removing "vice chair" if applicable
            if "vice-chair" in subset.lower():
                memb_idx = subset.lower().find("vice-chair")
                subset = subset[: memb_idx].strip()

            # return subset
            adj_membs.append(subset)

        return ", ".join(list(set([memb for memb in adj_membs if memb != ""]))) # removing empty and duplicate items
    
    ### If there's only one member found ###

    kw_idx = case_content_str.lower().find(keyword)

    subset = case_content_str[kw_idx + len(keyword): kw_idx + 100] # subsetting to an arbitrary distance after the keyword location
    subset = subset.split(", ")[0].strip()

    # removing "member" if applicable
    if "member" in subset.lower():
        memb_idx = subset.lower().find("member")
        subset = subset[: memb_idx].strip()

    # removing "vice chair" if applicable
    if "vice chair" in subset.lower():
        memb_idx = subset.lower().find("vice chair")
        subset = subset[: memb_idx].strip()

    # removing "vice chair" if applicable
    if "vice-chair" in subset.lower():
        memb_idx = subset.lower().find("vice-chair")
        subset = subset[: memb_idx].strip()

    return subset

# %%
for row in data_df.itertuples():

    try:
        data_df.at[row.Index, 'adjudicating_member'] = get_adj_member(data_df.loc[row.Index, 'content']).replace("Vice Chair", "").replace("Vice-Chair", "").strip()
    except Exception as any_error:
        data_df.at[row.Index, 'adjudicating_member'] = "MEMBER NOT FOUND"

data_df.head()
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location      hearing_date     decision_date  \
# 0  English  2018      Toronto      May 25, 2018     July 23, 2018
# 1  English  2018    Newmarket      May 30, 2018      June 4, 2018
# 2  English  2018      Toronto      May 30, 2018     July 24, 2018
# 3  English  2018      Windsor  January 17, 2018  February 2, 2018
# 4  English  2018       London      May 23, 2018      June 8, 2018
#
#                          url adjudicating_member
# 0  https://canlii.ca/t/hwbfs          Ruth Carey
# 1  https://canlii.ca/t/hwbjl        Neil Kaufman
# 2  https://canlii.ca/t/hw7t8          Ruth Carey
# 3  https://canlii.ca/t/hs06t    Lorraine Mathers
# 4  https://canlii.ca/t/hv7nz         Kevin Lundy

# %% [markdown]
# # Step 11: Extract Case Outcome Span
# - still need to classify case outcome span

# %%
import re
import itertools

def find_all_positions(text: str, keyword: str):
    """
    Finds all positions of a keyword in a given text.

    This function searches for a keyword in a given text and returns a list of positions where the keyword is found.

    Parameters
    ----------
    text : str
        The text to search within.
    keyword : str
        The keyword to find in the text.

    Returns
    -------
    list
        A list of integers representing the positions of the keyword in the text.

    Examples
    --------
    >>> find_all_positions("This is an example sentence.", "example")
    [11]
    """
    positions = []
    start = 0
    while True:
        index = text.find(keyword, start)
        if index == -1:
            break
        positions.append(index)
        start = index + 1
    return positions

def get_outcome_span(text: str, return_truncated: bool = True):
    """
    Extracts the outcome span from a given text using different methods.

    This function extracts the outcome span from a given text using multiple methods. It first attempts to find
    the span between occurrences of the phrases "accordance with" and "ordered". If that method fails, it then
    tries to find the span after the phrase "it is ordered". If that also fails, it looks for the span after the
    phrase "find". The function returns the extracted outcome span as a cleaned string.

    Parameters
    ----------
    text : str
        The text from which to extract the outcome span.

    Returns
    -------
    str or None
        The extracted outcome span as a cleaned string, or None if no span is found.

    Examples
    --------
    >>> get_outcome_span(unstructured_case_file)
    "In accordance with the order, it is ordered that the defendant pays a fine."
    """

    ############### FIRST METHOD ################

    for keyword in ['in accordance with', 'grant', 'relief', 'fair']: # these all seem common but none seem to exist in 100% of cases

        if keyword in text:

            # find all occurrences of 'in accordance with' and 'ordered'
            accordance_with_indices = [m.end() for m in re.finditer(keyword, text)]
            ordered_indices = [m.start() for m in re.finditer("ordered", text)]

            # generate all possible pairs of indices
            index_pairs = list(itertools.product(accordance_with_indices, ordered_indices))

            # filter pairs where 'accordance with' index is less than 'ordered' index
            index_pairs = [(i, j) for (i, j) in index_pairs if i < j]
            if index_pairs:
                # find the pair with the shortest distance between indices
                min_distance_pair = min(index_pairs, key = lambda x: x[1] - x[0])
                try:
                    best_subset = text[min_distance_pair[0] - 300 : min_distance_pair[1] + 400].strip()
                except IndexError:
                    best_subset = text[min_distance_pair[0] - 600 : min_distance_pair[1]].strip()

                best_subset = best_subset.split(". ")

                if not best_subset:
                    continue # to next match of all matches of the keyword

                sent_id = [idx for idx, i in enumerate(best_subset) if keyword in i.lower()][0]

                clean_outcome = best_subset[sent_id]

                # return JUST the (presumably) most relevant outcome span (after cleaning it up a bit)
                if return_truncated:
                    clean_outcome = re.sub(r'\[\d+\]', '', clean_outcome)
                    clean_outcome = re.sub(r'^\d+\.\s*', '', clean_outcome).strip() # removes numbers from the start of the string such as "16. " from start of string

                    if ")" in clean_outcome[:10] and "(" not in clean_outcome[:10]:
                        clean_outcome = clean_outcome.split(")")[1].strip()
                    return clean_outcome

                # return all case file text until the end of the outcome span
                else:
                    return text[: text.find(clean_outcome) + len(clean_outcome)].strip()

    ################ SECOND METHOD ################

    keyword = "it is ordered"
    if keyword in text.lower():
        matches = find_all_positions(text.lower(), keyword)

        for match in matches:
            try: # match + 400 chars
                clean_outcome = ". ".join(text[match - 400 : match + 400].split(". ")[1:-1]) 
            except IndexError: # match idx until end of string (+ 400 is sometimes out of range)
                clean_outcome = ". ".join(text[match - 600 :].split(". ")[1:-1])

            # return None
            # print("METHOD 2")
            if not clean_outcome:
                continue # to next match of all matches of the keyword

            if return_truncated:
                clean_outcome = re.sub(r'\[\d+\]', '', clean_outcome)
                clean_outcome = re.sub(r'^\d+\.\s*', '', clean_outcome).strip() # removes numbers from the start of the string such as "16. " from start of string

                if ")" in clean_outcome[:10] and "(" not in clean_outcome[:10]:
                    clean_outcome = clean_outcome.split(")")[1].strip()
                return clean_outcome

            # return all case file text until the end of the outcome span
            else:
                return text[: text.find(clean_outcome) + len(clean_outcome)].strip()

    ############### THIRD METHOD ################

    keyword = " find " # spaces to prevent "finding" or other derivations from being included -- specifically looking for statements like "I find that..."
    if keyword in text.lower():
        matches = find_all_positions(text.lower(), keyword)
        for match in matches:

            try: # match + 400 chars
                clean_outcome = ". ".join(text[match - 400 : match + 400].split(". ")[1:-1]) 
            except IndexError: # match idx until end of string (+ 400 is sometimes out of range)
                clean_outcome = ". ".join(text[match - 600 :].split(". ")[1:-1])

            if not clean_outcome:
                continue # to next match of all matches of the keyword
            
            if return_truncated:
                clean_outcome = re.sub(r'\[\d+\]', '', clean_outcome)
                clean_outcome = re.sub(r'^\d+\.\s*', '', clean_outcome).strip() # removes numbers from the start of the string such as "16. " from start of string

                if ")" in clean_outcome[:10] and "(" not in clean_outcome[:10]:
                    clean_outcome = clean_outcome.split(")")[1].strip()
                return clean_outcome
            else:
                return text[: text.find(clean_outcome) + len(clean_outcome)].strip()

    # if absolutely nothing works, return none and try Longformer or something idk
    return None

# %%
for row in data_df.itertuples():

    try:
        pass
        content_str = data_df.at[row.Index, 'content']
        data_df.at[row.Index, 'outcome_span'] = get_outcome_span(content_str, return_truncated = True)
    except Exception as any_error:
        print(f"{any_error} with file at Df row: ", row.Index)

print(data_df.shape)
data_df.head()
# Out:
# (6, 15)
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
#
#                                              content  \
# 0  Order under Sections 31, 69 and 89 Residential...
# 1  Order under Sections 69 and 77  Residential Te...
# 2  Order under Sections 31, 69 and 89 Residential...
# 3  Order under Section 69 Residential Tenancies A...
# 4  Order under Sections 30, 31 and 69 Residential...
#
#                                          citation                file_number  \
# 0  TET-89650-18 (Re), 2018 CanLII 113792 (ON LTB)               TET-89650-18
# 1  TNL-04435-18 (Re), 2018 CanLII 113807 (ON LTB)               TNL-04435-18
# 2  HOL-02144-17 (Re), 2018 CanLII 111686 (ON LTB)  HOT-02146-17;HOL-02144-17
# 3   SWL-08112-17 (Re), 2018 CanLII 42485 (ON LTB)  SWL-08112-17;SWL-08113-17
# 4   SWL-13901-18 (Re), 2018 CanLII 88630 (ON LTB)  SWT-14627-18;SWL-13901-18
#
#   language  year ltb_location      hearing_date     decision_date  \
# 0  English  2018      Toronto      May 25, 2018     July 23, 2018
# 1  English  2018    Newmarket      May 30, 2018      June 4, 2018
# 2  English  2018      Toronto      May 30, 2018     July 24, 2018
# 3  English  2018      Windsor  January 17, 2018  February 2, 2018
# 4  English  2018       London      May 23, 2018      June 8, 2018
#
#                          url adjudicating_member  \
# 0  https://canlii.ca/t/hwbfs          Ruth Carey
# 1  https://canlii.ca/t/hwbjl        Neil Kaufman
# 2  https://canlii.ca/t/hw7t8          Ruth Carey
# 3  https://canlii.ca/t/hs06t    Lorraine Mathers
# 4  https://canlii.ca/t/hv7nz         Kevin Lundy
#
#                                         outcome_span
# 0  37(1) says: A tenancy may be terminated only i...
# 1  I have considered all of the disclosed circums...
# 2  200(1) an applicant may amend an application t...
# 3  However, this was a onetime incident and the i...
# 4  I have considered all of the disclosed circums...

# %% [markdown]
# # Grace -- Add your stuff here

# %% [markdown]
# # Write All Predictions to CSV as final output

# %%
data_df.to_csv("pipeline_output/extracted_info.csv", index = False)

# %%
pd.read_csv("pipeline_output/extracted_info.csv")
# Out:
#                                         raw_file_str  \
# 0  Metadata:\nDate:\t2018-07-23\nFile number:\t\n...
# 1  Metadata:\nDate:\t2018-06-04\nFile number:\t\n...
# 2  Metadata:\nDate:\t2018-07-24\nFile number:\t\n...
# 3  Metadata:\nDate:\t2018-02-02\nFile number:\t\n...
# 4  Metadata:\nDate:\t2018-06-08\nFile number:\t\n...
# 5  Metadata:\nDate:\t2019-11-20\nFile number:\t\n...
#
#                           cleaned_case_with_newlines  \
# 0  Metadata:\nDate: 2018-07-23\nFile number:\nTET...
# 1  Metadata:\nDate: 2018-06-04\nFile number:\nTNL...
# 2  Metadata:\nDate: 2018-07-24\nFile number:\nHOL...
# 3  Metadata:\nDate: 2018-02-02\nFile number:\nSWL...
# 4  Metadata:\nDate: 2018-06-08\nFile number:\nSWL...
# 5  Metadata:\nDate: 2019-11-20\nFile number:\nTSL...
#
#                                            full_file  \
# 0  Metadata: Date: 2018-07-23 File number: TET-89...
# 1  Metadata: Date: 2018-06-04 File number: TNL-04...
# 2  Metadata: Date: 2018-07-24 File number: HOL-02...
# 3  Metadata: Date: 2018-02-02 File number: SWL-08...
# 4  Metadata: Date: 2018-06-08 File number: SWL-13...
# 5  Metadata: Date: 2019-11-20 File number: TSL-07...
#
#                                             metadata  \
# 0  Date: 2018-07-23 File number: TET-89650-18  Ci...
# 1  Date: 2018-06-04 File number: TNL-04435-18  Ci...
# 2  Date: 2018-07-24 File number: HOL-02144-17; HO...
# 3  Date: 2018-02-02 File number: SWL-08112-17; SW...
# 4  Date: 2018-06-08 File number: SWL-13901-18; SW...
# 5  Date: 2019-11-20 File number: TSL-07666-19-RV ...
#
#                                              content language  year  \
# 0  Order under Sections 31, 69 and 89 Residential...  English  2018
# 1  Order under Sections 69 and 77  Residential Te...  English  2018
# 2  Order under Sections 31, 69 and 89 Residential...  English  2018
# 3  Order under Section 69 Residential Tenancies A...  English  2018
# 4  Order under Sections 30, 31 and 69 Residential...  English  2018
# 5  Order under Section 21.2 of the Statutory Powe...  English  2019
#
#   ltb_location      hearing_date      decision_date  \
# 0      Toronto      May 25, 2018      July 23, 2018
# 1    Newmarket      May 30, 2018       June 4, 2018
# 2      Toronto      May 30, 2018      July 24, 2018
# 3      Windsor  January 17, 2018   February 2, 2018
# 4       London      May 23, 2018       June 8, 2018
# 5      Toronto   August 30, 2019  November 20, 2019
#
#                          url adjudicating_member  \
# 0  https://canlii.ca/t/hwbfs          Ruth Carey
# 1  https://canlii.ca/t/hwbjl        Neil Kaufman
# 2  https://canlii.ca/t/hw7t8          Ruth Carey
# 3  https://canlii.ca/t/hs06t    Lorraine Mathers
# 4  https://canlii.ca/t/hv7nz         Kevin Lundy
# 5  https://canlii.ca/t/j6vxc        Anna Solomon
#
#                                         outcome_span
# 0  37(1) says: A tenancy may be terminated only i...
# 1  I have considered all of the disclosed circums...
# 2  200(1) an applicant may amend an application t...
# 3  However, this was a onetime incident and the i...
# 4  I have considered all of the disclosed circums...
# 5  I have considered all of the disclosed circums...

# %%
data_df.columns
# Out:
# Index(['raw_file_str', 'cleaned_case_with_newlines', 'full_file', 'metadata',
#        'content', 'citation', 'file_number', 'language', 'year',
#        'ltb_location', 'hearing_date', 'decision_date', 'url',
#        'adjudicating_member', 'outcome_span'],
#       dtype='object')
